# %%
"""PostgreSQL schema statistics utility.

Connects to a PostgreSQL database, discovers all tables in a given schema,
and computes descriptive statistics for each column based on its data type.

Usage (CLI):
    python -m scripts.pg_schema_stats \
        --host localhost --port 5432 --dbname mydb --user myuser --password mypass \
        --schema public --output stats.json

The script supports either a full DSN via --dsn or individual connection params.
"""

from __future__ import annotations

import argparse
import json
import os
import sys
from dataclasses import dataclass
from typing import Any, Dict, Iterable, List, Optional, Tuple

import psycopg2
from psycopg2 import sql

# %%
@dataclass
class ConnectionParams:
    host: Optional[str] = None
    port: Optional[int] = None
    dbname: Optional[str] = None
    user: Optional[str] = None
    password: Optional[str] = None
    dsn: Optional[str] = None


def connect(params: ConnectionParams):
    """Create a psycopg2 connection from provided parameters or DSN."""
    if params.dsn:
        return psycopg2.connect(params.dsn)
    conn_kwargs: Dict[str, Any] = {}
    if params.host:
        conn_kwargs["host"] = params.host
    if params.port:
        conn_kwargs["port"] = params.port
    if params.dbname:
        conn_kwargs["dbname"] = params.dbname
    if params.user:
        conn_kwargs["user"] = params.user
    if params.password:
        conn_kwargs["password"] = params.password
    return psycopg2.connect(**conn_kwargs)


def list_tables(conn, schema: str) -> List[str]:
    """Return all base table names for a given schema."""
    query = (
        """
        SELECT table_name
        FROM information_schema.tables
        WHERE table_schema = %s AND table_type = 'BASE TABLE'
        ORDER BY table_name
        """
    )
    with conn.cursor() as cur:
        cur.execute(query, (schema,))
        rows = cur.fetchall()
    return [r[0] for r in rows]

def list_views(conn, schemas: List[str]) -> List[str]:
    """Return all view names for a given schema."""
    query = (
        """
        SELECT table_schema, table_name
        FROM information_schema.views
        WHERE table_schema = ANY(%s)
        ORDER BY table_schema, table_name
        """
    )
    with conn.cursor() as cur:
        cur.execute(query, (schemas,))
        rows = cur.fetchall()
        print(f"Rows: {rows}")
    # result contains tuples of (table_schema, table_name)
    return [f"{r[0]}.{r[1]}" for r in rows]


def list_columns(conn, schema: str, table: str) -> List[Tuple[str, str, str]]:
    """Return list of (column_name, data_type, udt_name) for table."""
    query = (
        """
        SELECT column_name, data_type, udt_name
        FROM information_schema.columns
        WHERE table_schema = %s AND table_name = %s
        ORDER BY ordinal_position
        """
    )
    with conn.cursor() as cur:
        cur.execute(query, (schema, table))
        rows = cur.fetchall()
    return [(r[0], r[1], r[2]) for r in rows]


def categorize_type(data_type: str, udt_name: str) -> str:
    """Map PostgreSQL data types to a coarse category for statistics."""
    dt = (data_type or "").lower()
    udt = (udt_name or "").lower()

    numeric_types = {
        "smallint",
        "integer",
        "bigint",
        "decimal",
        "numeric",
        "real",
        "double precision",
        "smallserial",
        "serial",
        "bigserial",
        "money",
    }
    text_types = {"text", "character varying", "character", "varchar", "char", "citext"}
    bool_types = {"boolean"}
    date_types = {"date"}
    timestamp_types = {"timestamp without time zone", "timestamp with time zone"}
    time_types = {"time without time zone", "time with time zone"}
    json_types = {"json", "jsonb"}

    if dt in numeric_types or udt in {"int2", "int4", "int8", "float4", "float8"}:
        return "numeric"
    if dt in bool_types:
        return "boolean"
    if dt in date_types:
        return "date"
    if dt in timestamp_types:
        return "timestamp"
    if dt in time_types:
        return "time"
    if dt in json_types:
        return "json"
    if dt in text_types:
        return "text"
    # Default to text-like for unknowns
    return "text"


def fetchone_dict(cur) -> Dict[str, Any]:
    """Convert a single-row cursor result into a dict keyed by column names."""
    row = cur.fetchone()
    if row is None:
        return {}
    desc = cur.description or []
    return {desc[i].name: row[i] for i in range(len(desc))}


def compute_numeric_stats(conn, schema: str, table: str, column: str) -> Dict[str, Any]:
    query = sql.SQL(
        """
        SELECT
            COUNT(*)::bigint AS total_rows,
            COUNT({col})::bigint AS non_null_rows,
            (COUNT(*) - COUNT({col}))::bigint AS null_rows,
            COUNT(DISTINCT {col})::bigint AS distinct_values,
            AVG({col}) AS avg_value,
            MIN({col}) AS min_value,
            MAX({col}) AS max_value,
            STDDEV_SAMP({col}) AS stddev,
            PERCENTILE_CONT(0.25) WITHIN GROUP (ORDER BY {col}) AS p25,
            PERCENTILE_CONT(0.50) WITHIN GROUP (ORDER BY {col}) AS median,
            PERCENTILE_CONT(0.75) WITHIN GROUP (ORDER BY {col}) AS p75
        FROM {sch}.{tbl}
        """
    ).format(
        col=sql.Identifier(column),
        sch=sql.Identifier(schema),
        tbl=sql.Identifier(table),
    )
    with conn.cursor() as cur:
        cur.execute(query)
        return fetchone_dict(cur)


def compute_boolean_stats(conn, schema: str, table: str, column: str) -> Dict[str, Any]:
    query = sql.SQL(
        """
        SELECT
            COUNT(*)::bigint AS total_rows,
            SUM(CASE WHEN {col} = TRUE THEN 1 ELSE 0 END)::bigint AS true_count,
            SUM(CASE WHEN {col} = FALSE THEN 1 ELSE 0 END)::bigint AS false_count,
            SUM(CASE WHEN {col} IS NULL THEN 1 ELSE 0 END)::bigint AS null_count,
            COUNT(DISTINCT {col})::bigint AS distinct_values
        FROM {sch}.{tbl}
        """
    ).format(
        col=sql.Identifier(column),
        sch=sql.Identifier(schema),
        tbl=sql.Identifier(table),
    )
    with conn.cursor() as cur:
        cur.execute(query)
        base = fetchone_dict(cur)

    top_values = top_value_counts(conn, schema, table, column, limit=3)
    base["top_values"] = top_values
    return base


def compute_text_stats(conn, schema: str, table: str, column: str) -> Dict[str, Any]:
    query = sql.SQL(
        """
        SELECT
            COUNT(*)::bigint AS total_rows,
            COUNT({col})::bigint AS non_null_rows,
            (COUNT(*) - COUNT({col}))::bigint AS null_rows,
            COUNT(DISTINCT {col})::bigint AS distinct_values,
            AVG(LENGTH({col})) AS avg_length,
            MIN(LENGTH({col})) AS min_length,
            MAX(LENGTH({col})) AS max_length
        FROM {sch}.{tbl}
        """
    ).format(
        col=sql.Identifier(column),
        sch=sql.Identifier(schema),
        tbl=sql.Identifier(table),
    )
    with conn.cursor() as cur:
        cur.execute(query)
        base = fetchone_dict(cur)

    base["top_values"] = top_value_counts(conn, schema, table, column, limit=10)
    return base


def compute_date_like_stats(conn, schema: str, table: str, column: str) -> Dict[str, Any]:
    query = sql.SQL(
        """
        SELECT
            COUNT(*)::bigint AS total_rows,
            COUNT({col})::bigint AS non_null_rows,
            (COUNT(*) - COUNT({col}))::bigint AS null_rows,
            MIN({col}) AS min_value,
            MAX({col}) AS max_value,
            COUNT(DISTINCT {col})::bigint AS distinct_values
        FROM {sch}.{tbl}
        """
    ).format(
        col=sql.Identifier(column),
        sch=sql.Identifier(schema),
        tbl=sql.Identifier(table),
    )
    with conn.cursor() as cur:
        cur.execute(query)
        base = fetchone_dict(cur)

    base["top_values"] = top_value_counts(conn, schema, table, column, limit=10)
    return base


def compute_json_stats(conn, schema: str, table: str, column: str) -> Dict[str, Any]:
    query = sql.SQL(
        """
        SELECT
            COUNT(*)::bigint AS total_rows,
            COUNT({col})::bigint AS non_null_rows,
            (COUNT(*) - COUNT({col}))::bigint AS null_rows
        FROM {sch}.{tbl}
        """
    ).format(
        col=sql.Identifier(column),
        sch=sql.Identifier(schema),
        tbl=sql.Identifier(table),
    )
    with conn.cursor() as cur:
        cur.execute(query)
        base = fetchone_dict(cur)
    return base


def top_value_counts(
    conn, schema: str, table: str, column: str, limit: int = 10
) -> List[Dict[str, Any]]:
    """Return top-N value counts for a column. NULLs are excluded."""
    query = sql.SQL(
        """
        SELECT {col} AS value, COUNT(*)::bigint AS count
        FROM {sch}.{tbl}
        WHERE {col} IS NOT NULL
        GROUP BY {col}
        ORDER BY COUNT(*) DESC
        LIMIT {lim}
        """
    ).format(
        col=sql.Identifier(column),
        sch=sql.Identifier(schema),
        tbl=sql.Identifier(table),
        lim=sql.Literal(limit),
    )
    with conn.cursor() as cur:
        cur.execute(query)
        rows = cur.fetchall()
        desc = cur.description or []
        headings = [d.name for d in desc]
    results: List[Dict[str, Any]] = []
    for row in rows:
        item: Dict[str, Any] = {}
        for i in range(len(headings)):
            # Convert non-JSON-serializable values to string
            value = row[i]
            if isinstance(value, (bytes, memoryview)):
                value = value.tobytes().decode("utf-8", errors="replace")
            try:
                json.dumps(value)
                item[headings[i]] = value
            except TypeError:
                item[headings[i]] = str(value)
        results.append(item)
    return results

# %%
def get_table_statistics(conn, schema: str, table: str) -> Dict[str, Any]:
    """Generate statistics for all columns in a table."""
    print(f"Processing table: {schema}.{table}")
    cols = list_columns(conn, schema, table)
    print(f"  Found {len(cols)} columns")
    results: Dict[str, Any] = {}
    for i, (column_name, data_type, udt_name) in enumerate(cols, 1):
        print(f"  Processing column {i}/{len(cols)}: {column_name} ({data_type})")
        category = categorize_type(data_type, udt_name)
        if category == "numeric":
            stats = compute_numeric_stats(conn, schema, table, column_name)
        elif category == "boolean":
            stats = compute_boolean_stats(conn, schema, table, column_name)
        elif category in {"date", "timestamp", "time"}:
            stats = compute_date_like_stats(conn, schema, table, column_name)
        elif category == "json":
            stats = compute_json_stats(conn, schema, table, column_name)
        else:
            stats = compute_text_stats(conn, schema, table, column_name)

        results[column_name] = {
            "data_type": data_type,
            "udt_name": udt_name,
            "category": category,
            "stats": stats,
        }
    print(f"  Completed table: {schema}.{table}")
    return results


def get_schema_statistics(
    conn, schemas: List[str], include_tables: Optional[Iterable[str]] = None, exclude_tables: Optional[Iterable[str]] = None
) -> Dict[str, Any]:
    """Compute statistics for all (or selected) tables in a schema."""
    import time
    
    start_time = time.time()
    print(f"Starting schema statistics for: {schemas}")
    include = set(include_tables or [])
    exclude = set(exclude_tables or [])
    tables = list_views(conn, schemas)
    to_process = [t for t in tables if (not include or t in include) and (t not in exclude)]
    print(f"Found {len(tables)} total tables, processing {len(to_process)} tables")

    results: Dict[str, Any] = {}
    for i, full_table_name in enumerate(to_process, 1):
        table_start_time = time.time()
        table_schema, table_name = full_table_name.split(".")
        print(f"Table {i}/{len(to_process)}: {full_table_name}")
        results[full_table_name] = get_table_statistics(conn, table_schema, table_name)
        table_elapsed = time.time() - table_start_time
        print(f"  Completed {full_table_name} in {table_elapsed:.2f}s")
        
        # Show overall progress
        elapsed_time = time.time() - start_time
        avg_time_per_table = elapsed_time / i
        estimated_remaining = avg_time_per_table * (len(to_process) - i)
        print(f"  Progress: {i}/{len(to_process)} ({i/len(to_process)*100:.1f}%) - Elapsed: {elapsed_time:.1f}s - ETA: {estimated_remaining:.1f}s")
    
    total_elapsed = time.time() - start_time
    print(f"Completed schema statistics for: {schemas} in {total_elapsed:.2f}s")
    return results

# %%
import dotenv
dotenv.load_dotenv("../.env")

params = ConnectionParams(
        host=os.getenv("DB_HOST"),
        port=os.getenv("DB_PORT"),
        dbname=os.getenv("DB_NAME"),
        user=os.getenv("DB_USER"),
        password=os.getenv("DB_PASSWORD"),
        dsn=os.getenv("DB_DSN"),
    )

conn = connect(params)
print(conn)
# Out:
# <connection object at 0x00000202EE7AF780; dsn: 'user=postgres.mrmlzpkjfosavipxrwct password=xxx dbname=postgres host=aws-0-us-east-1.pooler.supabase.com port=5432', closed: 0>

# %%
schemas = [
    # "sp_api_thrive_2", 
    "amazon_ads_thrive"
]
views = list_views(conn, schemas)
views
# Out:
# Rows: [('amazon_ads_thrive', 'ad_group_history_view'), ('amazon_ads_thrive', 'ad_group_level_report_view'), ('amazon_ads_thrive', 'ad_group_serving_status_detail_view'), ('amazon_ads_thrive', 'ad_group_suggested_keyword_view'), ('amazon_ads_thrive', 'advertised_product_report_view'), ('amazon_ads_thrive', 'asin_bid_recommendation_value_view'), ('amazon_ads_thrive', 'asin_suggested_keyword_view'), ('amazon_ads_thrive', 'asin_theme_based_bid_recommendation_view'), ('amazon_ads_thrive', 'campaign_history_view'), ('amazon_ads_thrive', 'campaign_level_report_view'), ('amazon_ads_thrive', 'campaign_negative_keyword_history_view'), ('amazon_ads_thrive', 'campaign_negative_keyword_serving_status_detail_view'), ('amazon_ads_thrive', 'campaign_placement_bidding_view'), ('amazon_ads_thrive', 'campaign_placement_report_view'), ('amazon_ads_thrive', 'campaign_serving_status_detail_view'), ('amazon_ads_thrive', 'keyword_history_view'), ('amazon_ads_thrive', 'keyword_serving_status_detail_view'), ('amazon_ads_thrive', 'negative_keyword_history_view'), ('amazon_ads_thrive', 'negative_keyword_serving_status_detail_view'), ('amazon_ads_thrive', 'negative_targeting_clause_history_view'), ('amazon_ads_thrive', 'negative_targeting_expression_view'), ('amazon_ads_thrive', 'negative_targeting_resolved_expression_view'), ('amazon_ads_thrive', 'negative_targeting_serving_status_detail_view'), ('amazon_ads_thrive', 'portfolio_history_view'), ('amazon_ads_thrive', 'product_ad_history_view'), ('amazon_ads_thrive', 'product_ad_serving_status_detail_view'), ('amazon_ads_thrive', 'profile_view'), ('amazon_ads_thrive', 'purchased_product_keyword_report_view'), ('amazon_ads_thrive', 'purchased_product_targeting_report_view'), ('amazon_ads_thrive', 'sb_ad_group_history_view'), ('amazon_ads_thrive', 'sb_ad_group_report_view'), ('amazon_ads_thrive', 'sb_ad_history_view'), ('amazon_ads_thrive', 'sb_ad_report_view'), ('amazon_ads_thrive', 'sb_ad_sub_page_view'), ('amazon_ads_thrive', 'sb_benchmark_brand_and_category_view'), ('amazon_ads_thrive', 'sb_brand_view'), ('amazon_ads_thrive', 'sb_budget_recommendation_view'), ('amazon_ads_thrive', 'sb_budget_rule_recommendation_view'), ('amazon_ads_thrive', 'sb_budget_usage_history_view'), ('amazon_ads_thrive', 'sb_campaign_bid_adjustments_by_placement_view'), ('amazon_ads_thrive', 'sb_campaign_history_view'), ('amazon_ads_thrive', 'sb_campaign_moderation_view'), ('amazon_ads_thrive', 'sb_campaign_report_view'), ('amazon_ads_thrive', 'sb_creative_asin_view'), ('amazon_ads_thrive', 'sb_creative_custom_image_view'), ('amazon_ads_thrive', 'sb_creative_history_view'), ('amazon_ads_thrive', 'sb_creative_original_video_asset_view'), ('amazon_ads_thrive', 'sb_creative_video_asset_view'), ('amazon_ads_thrive', 'sb_keyword_report_view'), ('amazon_ads_thrive', 'sb_keyword_view'), ('amazon_ads_thrive', 'sb_negative_keyword_view'), ('amazon_ads_thrive', 'sb_placement_report_view'), ('amazon_ads_thrive', 'sb_product_target_expression_view'), ('amazon_ads_thrive', 'sb_product_target_resolved_expression_view'), ('amazon_ads_thrive', 'sb_product_target_view'), ('amazon_ads_thrive', 'sb_product_targeting_category_view'), ('amazon_ads_thrive', 'sb_purchased_product_view'), ('amazon_ads_thrive', 'sb_search_term_report_view'), ('amazon_ads_thrive', 'sb_store_asset_view'), ('amazon_ads_thrive', 'sb_store_page_info_view'), ('amazon_ads_thrive', 'sb_store_view'), ('amazon_ads_thrive', 'sb_target_report_view'), ('amazon_ads_thrive', 'sb_targeting_recommendation_brand_category_view'), ('amazon_ads_thrive', 'sb_targeting_recommendation_category_view'), ('amazon_ads_thrive', 'sb_targeting_recommendation_product_view'), ('amazon_ads_thrive', 'sd_ad_group_history_view'), ('amazon_ads_thrive', 'sd_ad_group_report_view'), ('amazon_ads_thrive', 'sd_bid_recommendation_view'), ('amazon_ads_thrive', 'sd_budget_usage_history_view'), ('amazon_ads_thrive', 'sd_campaign_history_view'), ('amazon_ads_thrive', 'sd_campaign_report_view'), ('amazon_ads_thrive', 'sd ...
# ['amazon_ads_thrive.ad_group_history_view',
#  'amazon_ads_thrive.ad_group_level_report_view',
#  'amazon_ads_thrive.ad_group_serving_status_detail_view',
#  'amazon_ads_thrive.ad_group_suggested_keyword_view',
#  'amazon_ads_thrive.advertised_product_report_view',
#  'amazon_ads_thrive.asin_bid_recommendation_value_view',
#  'amazon_ads_thrive.asin_suggested_keyword_view',
#  'amazon_ads_thrive.asin_theme_based_bid_recommendation_view',
#  'amazon_ads_thrive.campaign_history_view',
#  'amazon_ads_thrive.campaign_level_report_view',
#  'amazon_ads_thrive.campaign_negative_keyword_history_view',
#  'amazon_ads_thrive.campaign_negative_keyword_serving_status_detail_view',
#  'amazon_ads_thrive.campaign_placement_bidding_view',
#  'amazon_ads_thrive.campaign_placement_report_view',
#  'amazon_ads_thrive.campaign_serving_status_detail_view',
#  'amazon_ads_thrive.keyword_history_view',
#  'amazon_ads_thrive.keyword_serving_status_detail_view',
#  'amazon_ads_thrive.negative_keyword_history_view',
#  'amazon_ads_thrive.negative_keyword_serving_status_detail_view',
#  'amazon_ads_thrive.negative_targeting_clause_history_view',
#  'amazon_ads_thrive.negative_targeting_expression_view',
#  'amazon_ads_thrive.negative_targeting_resolved_expression_view',
#  'amazon_ads_thrive.negative_targeting_serving_status_detail_view',
#  'amazon_ads_thrive.portfolio_history_view',
#  'amazon_ads_thrive.product_ad_history_view',
#  'amazon_ads_thrive.product_ad_serving_status_detail_view',
#  'amazon_ads_thrive.profile_view',
#  'amazon_ads_thrive.purchased_product_keyword_report_view',
#  'amazon_ads_thrive.purchased_product_targeting_report_view',
#  'amazon_ads_thrive.sb_ad_group_history_view',
#  'amazon_ads_thrive.sb_ad_group_report_view',
#  'amazon_ads_thrive.sb_ad_history_view',
#  'amazon_ads_thrive.sb_ad_report_view',
#  'amazon_ads_thrive.sb_ad_sub_page_view',
#  'amazon_ads_thrive.sb_benchmark_brand_and_category_view',
#  'amazon_ads_thrive.sb_brand_view',
#  'amazon_ads_thrive.sb_budget_recommendation_view',
#  'amazon_ads_thrive.sb_budget_rule_recommendation_view',
#  'amazon_ads_thrive.sb_budget_usage_history_view',
#  'amazon_ads_thrive.sb_campaign_bid_adjustments_by_placement_view',
#  'amazon_ads_thrive.sb_campaign_history_view',
#  'amazon_ads_thrive.sb_campaign_moderation_view',
#  'amazon_ads_thrive.sb_campaign_report_view',
#  'amazon_ads_thrive.sb_creative_asin_view',
#  'amazon_ads_thrive.sb_creative_custom_image_view',
#  'amazon_ads_thrive.sb_creative_history_view',
#  'amazon_ads_thrive.sb_creative_original_video_asset_view',
#  'amazon_ads_thrive.sb_creative_video_asset_view',
#  'amazon_ads_thrive.sb_keyword_report_view',
#  'amazon_ads_thrive.sb_keyword_view',
#  'amazon_ads_thrive.sb_negative_keyword_view',
#  'amazon_ads_thrive.sb_placement_report_view',
#  'amazon_ads_thrive.sb_product_target_expression_view',
#  'amazon_ads_thrive.sb_product_target_resolved_expression_view',
#  'amazon_ads_thrive.sb_product_target_view',
#  'amazon_ads_thrive.sb_product_targeting_category_view',
#  'amazon_ads_thrive.sb_purchased_product_view',
#  'amazon_ads_thrive.sb_search_term_report_view',
#  'amazon_ads_thrive.sb_store_asset_view',
#  'amazon_ads_thrive.sb_store_page_info_view',
#  'amazon_ads_thrive.sb_store_view',
#  'amazon_ads_thrive.sb_target_report_view',
#  'amazon_ads_thrive.sb_targeting_recommendation_brand_category_view',
#  'amazon_ads_thrive.sb_targeting_recommendation_category_view',
#  'amazon_ads_thrive.sb_targeting_recommendation_product_view',
#  'amazon_ads_thrive.sd_ad_group_history_view',
#  'amazon_ads_thrive.sd_ad_group_report_view',
#  'amazon_ads_thrive.sd_bid_recommendation_view',
#  'amazon_ads_thrive.sd_budget_usage_history_view',
#  'amazon_ads_thrive.sd_campaign_history_view',
#  'amazon_ads_thrive.sd_campaign_report_view',
#  'amazon_ads_thrive.sd_creative_moderation_view',
#  'amazon_ads_thrive.sd_creative_view',
#  'amazon_ads_thrive.sd_matched_target_report_view',
#  'amazon_ads_thrive.sd_product_ad_history_view',
#  'amazon_ads_thrive.sd_product_ad_report_view',
#  'amazon_ads_thrive.sd_purchased_products_reports_view',
#  'amazon_ads_thrive.sd_target_report_view',
#  'amazon_ads_thrive.sd_targeting_expression_view',
#  'amazon_ads_thrive.sd_targeting_history_view',
#  'amazon_ads_thrive.sd_targeting_recommendation_audience_view',
#  'amazon_ads_thrive.sd_targeting_recommendation_category_view',
#  'amazon_ads_thrive.sd_targeting_recommendation_product_view',
#  'amazon_ads_thrive.sd_targeting_resolved_expression_view',
#  'amazon_ads_thrive.search_term_ad_keyword_report_view',
#  'amazon_ads_thrive.search_term_targeting_report_view',
#  'amazon_ads_thrive.targeting_clause_history_view',
#  'amazon_ads_thrive.targeting_expression_view',
#  'amazon_ads_thrive.targeting_keyword_report_view',
#  'amazon_ads_thrive.targeting_report_view',
#  'amazon_ads_thrive.targeting_resolved_expression_view',
#  'amazon_ads_thrive.targeting_serving_status_detail_view']

# %%
stats = get_schema_statistics(conn, schemas)

print(stats)
# Out:
# Starting schema statistics for: ['amazon_ads_thrive']
# Rows: [('amazon_ads_thrive', 'ad_group_history_view'), ('amazon_ads_thrive', 'ad_group_level_report_view'), ('amazon_ads_thrive', 'ad_group_serving_status_detail_view'), ('amazon_ads_thrive', 'ad_group_suggested_keyword_view'), ('amazon_ads_thrive', 'advertised_product_report_view'), ('amazon_ads_thrive', 'asin_bid_recommendation_value_view'), ('amazon_ads_thrive', 'asin_suggested_keyword_view'), ('amazon_ads_thrive', 'asin_theme_based_bid_recommendation_view'), ('amazon_ads_thrive', 'campaign_history_view'), ('amazon_ads_thrive', 'campaign_level_report_view'), ('amazon_ads_thrive', 'campaign_negative_keyword_history_view'), ('amazon_ads_thrive', 'campaign_negative_keyword_serving_status_detail_view'), ('amazon_ads_thrive', 'campaign_placement_bidding_view'), ('amazon_ads_thrive', 'campaign_placement_report_view'), ('amazon_ads_thrive', 'campaign_serving_status_detail_view'), ('amazon_ads_thrive', 'keyword_history_view'), ('amazon_ads_thrive', 'keyword_serving_status_detail_view'), ('amazon_ads_thrive', 'negative_keyword_history_view'), ('amazon_ads_thrive', 'negative_keyword_serving_status_detail_view'), ('amazon_ads_thrive', 'negative_targeting_clause_history_view'), ('amazon_ads_thrive', 'negative_targeting_expression_view'), ('amazon_ads_thrive', 'negative_targeting_resolved_expression_view'), ('amazon_ads_thrive', 'negative_targeting_serving_status_detail_view'), ('amazon_ads_thrive', 'portfolio_history_view'), ('amazon_ads_thrive', 'product_ad_history_view'), ('amazon_ads_thrive', 'product_ad_serving_status_detail_view'), ('amazon_ads_thrive', 'profile_view'), ('amazon_ads_thrive', 'purchased_product_keyword_report_view'), ('amazon_ads_thrive', 'purchased_product_targeting_report_view'), ('amazon_ads_thrive', 'sb_ad_group_history_view'), ('amazon_ads_thrive', 'sb_ad_group_report_view'), ('amazon_ads_thrive', 'sb_ad_history_view'), ('amazon_ads_thrive', 'sb_ad_report_view'), ('amazon_ads_thrive', 'sb_ad_sub_page_view'), ('amazon_ads_thrive', 'sb_benchmark_brand_and_category_view'), ('amazon_ads_thrive', 'sb_brand_view'), ('amazon_ads_thrive', 'sb_budget_recommendation_view'), ('amazon_ads_thrive', 'sb_budget_rule_recommendation_view'), ('amazon_ads_thrive', 'sb_budget_usage_history_view'), ('amazon_ads_thrive', 'sb_campaign_bid_adjustments_by_placement_view'), ('amazon_ads_thrive', 'sb_campaign_history_view'), ('amazon_ads_thrive', 'sb_campaign_moderation_view'), ('amazon_ads_thrive', 'sb_campaign_report_view'), ('amazon_ads_thrive', 'sb_creative_asin_view'), ('amazon_ads_thrive', 'sb_creative_custom_image_view'), ('amazon_ads_thrive', 'sb_creative_history_view'), ('amazon_ads_thrive', 'sb_creative_original_video_asset_view'), ('amazon_ads_thrive', 'sb_creative_video_asset_view'), ('amazon_ads_thrive', 'sb_keyword_report_view'), ('amazon_ads_thrive', 'sb_keyword_view'), ('amazon_ads_thrive', 'sb_negative_keyword_view'), ('amazon_ads_thrive', 'sb_placement_report_view'), ('amazon_ads_thrive', 'sb_product_target_expression_view'), ('amazon_ads_thrive', 'sb_product_target_resolved_expression_view'), ('amazon_ads_thrive', 'sb_product_target_view'), ('amazon_ads_thrive', 'sb_product_targeting_category_view'), ('amazon_ads_thrive', 'sb_purchased_product_view'), ('amazon_ads_thrive', 'sb_search_term_report_view'), ('amazon_ads_thrive', 'sb_store_asset_view'), ('amazon_ads_thrive', 'sb_store_page_info_view'), ('amazon_ads_thrive', 'sb_store_view'), ('amazon_ads_thrive', 'sb_target_report_view'), ('amazon_ads_thrive', 'sb_targeting_recommendation_brand_category_view'), ('amazon_ads_thrive', 'sb_targeting_recommendation_category_view'), ('amazon_ads_thrive', 'sb_targeting_recommendation_product_view'), ('amazon_ads_thrive', 'sd_ad_group_history_view'), ('amazon_ads_thrive', 'sd_ad_group_report_view'), ('amazon_ads_thrive', 'sd_bid_recommendation_view'), ('amazon_ads_thrive', 'sd_budget_usage_history_view'), ('amazon_ads_thrive', 'sd_campaign_history_view'), ('amazon_ads_thrive', 'sd_campaign_report_view'), ('amazon_ads_thrive', 'sd ...
# Found 92 total tables, processing 92 tables
# Table 1/92: amazon_ads_thrive.ad_group_history_view
# Processing table: amazon_ads_thrive.ad_group_history_view
#   Found 9 columns
#   Processing column 1/9: id (character varying)
#   Processing column 2/9: last_updated_date (timestamp with time zone)
#   Processing column 3/9: serving_status (character varying)
#   Processing column 4/9: creation_date (timestamp with time zone)
#   Processing column 5/9: campaign_id (character varying)
#   Processing column 6/9: name (character varying)
#   Processing column 7/9: default_bid (double precision)
#   Processing column 8/9: state (character varying)
#   Processing column 9/9: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.ad_group_history_view
#   Completed amazon_ads_thrive.ad_group_history_view in 0.55s
#   Progress: 1/92 (1.1%) - Elapsed: 0.6s - ETA: 52.4s
# Table 2/92: amazon_ads_thrive.ad_group_level_report_view
# Processing table: amazon_ads_thrive.ad_group_level_report_view
#   Found 39 columns
#   Processing column 1/39: ad_group_id (bigint)
#   Processing column 2/39: date (date)
#   Processing column 3/39: impressions (bigint)
#   Processing column 4/39: clicks (integer)
#   Processing column 5/39: cost (double precision)
#   Processing column 6/39: cost_per_click (double precision)
#   Processing column 7/39: campaign_bidding_strategy (character varying)
#   Processing column 8/39: click_through_rate (double precision)
#   Processing column 9/39: spend (double precision)
#   Processing column 10/39: add_to_list (integer)
#   Processing column 11/39: qualified_borrows (integer)
#   Processing column 12/39: royalty_qualified_borrows (integer)
#   Processing column 13/39: purchases_1_d (integer)
#   Processing column 14/39: purchases_7_d (integer)
#   Processing column 15/39: purchases_14_d (integer)
#   Processing column 16/39: purchases_30_d (integer)
#   Processing column 17/39: purchases_same_sku_1_d (integer)
#   Processing column 18/39: purchases_same_sku_7_d (integer)
#   Processing column 19/39: purchases_same_sku_14_d (integer)
#   Processing column 20/39: purchases_same_sku_30_d (integer)
#   Processing column 21/39: units_sold_clicks_1_d (integer)
#   Processing column 22/39: units_sold_clicks_7_d (integer)
#   Processing column 23/39: units_sold_clicks_14_d (integer)
#   Processing column 24/39: units_sold_clicks_30_d (integer)
#   Processing column 25/39: sales_1_d (double precision)
#   Processing column 26/39: sales_7_d (double precision)
#   Processing column 27/39: sales_14_d (double precision)
#   Processing column 28/39: sales_30_d (double precision)
#   Processing column 29/39: attributed_sales_same_sku_1_d (double precision)
#   Processing column 30/39: attributed_sales_same_sku_7_d (double precision)
#   Processing column 31/39: attributed_sales_same_sku_14_d (double precision)
#   Processing column 32/39: attributed_sales_same_sku_30_d (double precision)
#   Processing column 33/39: units_sold_same_sku_1_d (integer)
#   Processing column 34/39: units_sold_same_sku_7_d (integer)
#   Processing column 35/39: units_sold_same_sku_14_d (integer)
#   Processing column 36/39: units_sold_same_sku_30_d (integer)
#   Processing column 37/39: kindle_edition_normalized_pages_read_14_d (integer)
#   Processing column 38/39: kindle_edition_normalized_pages_royalties_14_d (double precision)
#   Processing column 39/39: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.ad_group_level_report_view
#   Completed amazon_ads_thrive.ad_group_level_report_view in 1.60s
#   Progress: 2/92 (2.2%) - Elapsed: 2.2s - ETA: 97.8s
# Table 3/92: amazon_ads_thrive.ad_group_serving_status_detail_view
# Processing table: amazon_ads_thrive.ad_group_serving_status_detail_view
#   Found 5 columns
#   Processing column 1/5: ad_group_id (character varying)
#   Processing column 2/5: name (character varying)
#   Processing column 3/5: help_url (character varying)
#   Processing column 4/5: message (character varying)
#   Processing column 5/5: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.ad_group_serving_status_detail_view
#   Completed amazon_ads_thrive.ad_group_serving_status_detail_view in 0.32s
#   Progress: 3/92 (3.3%) - Elapsed: 2.5s - ETA: 74.1s
# Table 4/92: amazon_ads_thrive.ad_group_suggested_keyword_view
# Processing table: amazon_ads_thrive.ad_group_suggested_keyword_view
#   Found 8 columns
#   Processing column 1/8: _fivetran_id (character varying)
#   Processing column 2/8: ad_group_id (bigint)
#   Processing column 3/8: campaign_id (bigint)
#   Processing column 4/8: keyword_text (character varying)
#   Processing column 5/8: match_type (character varying)
#   Processing column 6/8: state (character varying)
#   Processing column 7/8: _fivetran_deleted (boolean)
#   Processing column 8/8: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.ad_group_suggested_keyword_view
#   Completed amazon_ads_thrive.ad_group_suggested_keyword_view in 2.47s
#   Progress: 4/92 (4.3%) - Elapsed: 5.0s - ETA: 109.1s
# Table 5/92: amazon_ads_thrive.advertised_product_report_view
# Processing table: amazon_ads_thrive.advertised_product_report_view
#   Found 51 columns
#   Processing column 1/51: ad_group_id (bigint)
#   Processing column 2/51: ad_id (bigint)
#   Processing column 3/51: campaign_id (bigint)
#   Processing column 4/51: date (date)
#   Processing column 5/51: impressions (integer)
#   Processing column 6/51: clicks (integer)
#   Processing column 7/51: cost_per_click (double precision)
#   Processing column 8/51: cost (double precision)
#   Processing column 9/51: click_through_rate (double precision)
#   Processing column 10/51: spend (double precision)
#   Processing column 11/51: campaign_budget_currency_code (character varying)
#   Processing column 12/51: campaign_budget_amount (double precision)
#   Processing column 13/51: campaign_budget_type (character varying)
#   Processing column 14/51: advertised_asin (character varying)
#   Processing column 15/51: advertised_sku (character varying)
#   Processing column 16/51: add_to_list (integer)
#   Processing column 17/51: qualified_borrows (integer)
#   Processing column 18/51: royalty_qualified_borrows (integer)
#   Processing column 19/51: purchases_1_d (integer)
#   Processing column 20/51: purchases_7_d (integer)
#   Processing column 21/51: purchases_14_d (integer)
#   Processing column 22/51: purchases_30_d (integer)
#   Processing column 23/51: purchases_same_sku_1_d (integer)
#   Processing column 24/51: purchases_same_sku_7_d (integer)
#   Processing column 25/51: purchases_same_sku_14_d (integer)
#   Processing column 26/51: purchases_same_sku_30_d (integer)
#   Processing column 27/51: units_sold_clicks_1_d (integer)
#   Processing column 28/51: units_sold_clicks_7_d (integer)
#   Processing column 29/51: units_sold_clicks_14_d (integer)
#   Processing column 30/51: units_sold_clicks_30_d (integer)
#   Processing column 31/51: sales_1_d (double precision)
#   Processing column 32/51: sales_7_d (double precision)
#   Processing column 33/51: sales_14_d (double precision)
#   Processing column 34/51: sales_30_d (double precision)
#   Processing column 35/51: attributed_sales_same_sku_1_d (double precision)
#   Processing column 36/51: attributed_sales_same_sku_7_d (double precision)
#   Processing column 37/51: attributed_sales_same_sku_14_d (double precision)
#   Processing column 38/51: attributed_sales_same_sku_30_d (double precision)
#   Processing column 39/51: sales_other_sku_7_d (bigint)
#   Processing column 40/51: units_sold_same_sku_1_d (integer)
#   Processing column 41/51: units_sold_same_sku_7_d (integer)
#   Processing column 42/51: units_sold_same_sku_14_d (integer)
#   Processing column 43/51: units_sold_same_sku_30_d (integer)
#   Processing column 44/51: units_sold_other_sku_7_d (integer)
#   Processing column 45/51: kindle_edition_normalized_pages_read_14_d (integer)
#   Processing column 46/51: kindle_edition_normalized_pages_royalties_14_d (double precision)
#   Processing column 47/51: acos_clicks_7_d (double precision)
#   Processing column 48/51: acos_clicks_14_d (double precision)
#   Processing column 49/51: roas_clicks_7_d (double precision)
#   Processing column 50/51: roas_clicks_14_d (double precision)
#   Processing column 51/51: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.advertised_product_report_view
#   Completed amazon_ads_thrive.advertised_product_report_view in 2.21s
#   Progress: 5/92 (5.4%) - Elapsed: 7.2s - ETA: 124.8s
# Table 6/92: amazon_ads_thrive.asin_bid_recommendation_value_view
# Processing table: amazon_ads_thrive.asin_bid_recommendation_value_view
#   Found 4 columns
#   Processing column 1/4: parent_id (character varying)
#   Processing column 2/4: index (integer)
#   Processing column 3/4: suggested_bid (double precision)
#   Processing column 4/4: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.asin_bid_recommendation_value_view
#   Completed amazon_ads_thrive.asin_bid_recommendation_value_view in 0.28s
#   Progress: 6/92 (6.5%) - Elapsed: 7.4s - ETA: 106.8s
# Table 7/92: amazon_ads_thrive.asin_suggested_keyword_view
# Processing table: amazon_ads_thrive.asin_suggested_keyword_view
#   Found 6 columns
#   Processing column 1/6: _fivetran_id (character varying)
#   Processing column 2/6: asin (character varying)
#   Processing column 3/6: keyword_text (character varying)
#   Processing column 4/6: match_type (character varying)
#   Processing column 5/6: _fivetran_deleted (boolean)
#   Processing column 6/6: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.asin_suggested_keyword_view
#   Completed amazon_ads_thrive.asin_suggested_keyword_view in 0.50s
#   Progress: 7/92 (7.6%) - Elapsed: 8.0s - ETA: 96.6s
# Table 8/92: amazon_ads_thrive.asin_theme_based_bid_recommendation_view
# Processing table: amazon_ads_thrive.asin_theme_based_bid_recommendation_view
#   Found 9 columns
#   Processing column 1/9: _fivetran_id (character varying)
#   Processing column 2/9: asin (character varying)
#   Processing column 3/9: strategy (character varying)
#   Processing column 4/9: theme (character varying)
#   Processing column 5/9: estimated_impression_upper (integer)
#   Processing column 6/9: estimated_impression_lower (integer)
#   Processing column 7/9: profile_id (bigint)
#   Processing column 8/9: targeting_type (character varying)
#   Processing column 9/9: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.asin_theme_based_bid_recommendation_view
#   Completed amazon_ads_thrive.asin_theme_based_bid_recommendation_view in 0.46s
#   Progress: 8/92 (8.7%) - Elapsed: 8.4s - ETA: 88.3s
# Table 9/92: amazon_ads_thrive.campaign_history_view
# Processing table: amazon_ads_thrive.campaign_history_view
#   Found 16 columns
#   Processing column 1/16: id (character varying)
#   Processing column 2/16: last_updated_date (timestamp with time zone)
#   Processing column 3/16: serving_status (character varying)
#   Processing column 4/16: creation_date (timestamp with time zone)
#   Processing column 5/16: portfolio_id (character varying)
#   Processing column 6/16: profile_id (bigint)
#   Processing column 7/16: name (character varying)
#   Processing column 8/16: targeting_type (character varying)
#   Processing column 9/16: state (character varying)
#   Processing column 10/16: bidding_strategy (character varying)
#   Processing column 11/16: start_date (date)
#   Processing column 12/16: end_date (date)
#   Processing column 13/16: budget_type (character varying)
#   Processing column 14/16: budget (double precision)
#   Processing column 15/16: effective_budget (double precision)
#   Processing column 16/16: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.campaign_history_view
#   Completed amazon_ads_thrive.campaign_history_view in 0.82s
#   Progress: 9/92 (9.8%) - Elapsed: 9.2s - ETA: 85.1s
# Table 10/92: amazon_ads_thrive.campaign_level_report_view
# Processing table: amazon_ads_thrive.campaign_level_report_view
#   Found 46 columns
#   Processing column 1/46: campaign_id (bigint)
#   Processing column 2/46: date (date)
#   Processing column 3/46: impressions (bigint)
#   Processing column 4/46: clicks (integer)
#   Processing column 5/46: cost (double precision)
#   Processing column 6/46: cost_per_click (double precision)
#   Processing column 7/46: campaign_bidding_strategy (character varying)
#   Processing column 8/46: click_through_rate (double precision)
#   Processing column 9/46: spend (double precision)
#   Processing column 10/46: add_to_list (integer)
#   Processing column 11/46: qualified_borrows (integer)
#   Processing column 12/46: royalty_qualified_borrows (integer)
#   Processing column 13/46: purchases_1_d (integer)
#   Processing column 14/46: purchases_7_d (integer)
#   Processing column 15/46: purchases_14_d (integer)
#   Processing column 16/46: purchases_30_d (integer)
#   Processing column 17/46: purchases_same_sku_1_d (integer)
#   Processing column 18/46: purchases_same_sku_7_d (integer)
#   Processing column 19/46: purchases_same_sku_14_d (integer)
#   Processing column 20/46: purchases_same_sku_30_d (integer)
#   Processing column 21/46: units_sold_clicks_1_d (integer)
#   Processing column 22/46: units_sold_clicks_7_d (integer)
#   Processing column 23/46: units_sold_clicks_14_d (integer)
#   Processing column 24/46: units_sold_clicks_30_d (integer)
#   Processing column 25/46: sales_1_d (double precision)
#   Processing column 26/46: sales_7_d (double precision)
#   Processing column 27/46: sales_14_d (double precision)
#   Processing column 28/46: sales_30_d (double precision)
#   Processing column 29/46: attributed_sales_same_sku_1_d (double precision)
#   Processing column 30/46: attributed_sales_same_sku_7_d (double precision)
#   Processing column 31/46: attributed_sales_same_sku_14_d (double precision)
#   Processing column 32/46: attributed_sales_same_sku_30_d (double precision)
#   Processing column 33/46: units_sold_same_sku_1_d (integer)
#   Processing column 34/46: units_sold_same_sku_7_d (integer)
#   Processing column 35/46: units_sold_same_sku_14_d (integer)
#   Processing column 36/46: units_sold_same_sku_30_d (integer)
#   Processing column 37/46: kindle_edition_normalized_pages_read_14_d (integer)
#   Processing column 38/46: kindle_edition_normalized_pages_royalties_14_d (double precision)
#   Processing column 39/46: campaign_budget_amount (double precision)
#   Processing column 40/46: campaign_budget_type (character varying)
#   Processing column 41/46: campaign_rule_based_budget_amount (double precision)
#   Processing column 42/46: campaign_applicable_budget_rule_id (character varying)
#   Processing column 43/46: campaign_applicable_budget_rule_name (character varying)
#   Processing column 44/46: campaign_budget_currency_code (character varying)
#   Processing column 45/46: top_of_search_impression_share (double precision)
#   Processing column 46/46: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.campaign_level_report_view
#   Completed amazon_ads_thrive.campaign_level_report_view in 1.86s
#   Progress: 10/92 (10.9%) - Elapsed: 11.1s - ETA: 91.0s
# Table 11/92: amazon_ads_thrive.campaign_negative_keyword_history_view
# Processing table: amazon_ads_thrive.campaign_negative_keyword_history_view
#   Found 9 columns
#   Processing column 1/9: id (character varying)
#   Processing column 2/9: last_updated_date (timestamp with time zone)
#   Processing column 3/9: campaign_id (character varying)
#   Processing column 4/9: keyword_text (character varying)
#   Processing column 5/9: state (character varying)
#   Processing column 6/9: match_type (character varying)
#   Processing column 7/9: serving_status (character varying)
#   Processing column 8/9: creation_date (timestamp with time zone)
#   Processing column 9/9: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.campaign_negative_keyword_history_view
#   Completed amazon_ads_thrive.campaign_negative_keyword_history_view in 0.72s
#   Progress: 11/92 (12.0%) - Elapsed: 11.8s - ETA: 87.0s
# Table 12/92: amazon_ads_thrive.campaign_negative_keyword_serving_status_detail_view
# Processing table: amazon_ads_thrive.campaign_negative_keyword_serving_status_detail_view
#   Found 5 columns
#   Processing column 1/5: keyword_id (character varying)
#   Processing column 2/5: name (character varying)
#   Processing column 3/5: help_url (character varying)
#   Processing column 4/5: message (character varying)
#   Processing column 5/5: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.campaign_negative_keyword_serving_status_detail_view
#   Completed amazon_ads_thrive.campaign_negative_keyword_serving_status_detail_view in 0.42s
#   Progress: 12/92 (13.0%) - Elapsed: 12.2s - ETA: 81.5s
# Table 13/92: amazon_ads_thrive.campaign_placement_bidding_view
# Processing table: amazon_ads_thrive.campaign_placement_bidding_view
#   Found 4 columns
#   Processing column 1/4: campaign_id (character varying)
#   Processing column 2/4: placement (character varying)
#   Processing column 3/4: percentage (integer)
#   Processing column 4/4: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.campaign_placement_bidding_view
#   Completed amazon_ads_thrive.campaign_placement_bidding_view in 0.21s
#   Progress: 13/92 (14.1%) - Elapsed: 12.4s - ETA: 75.6s
# Table 14/92: amazon_ads_thrive.campaign_placement_report_view
# Processing table: amazon_ads_thrive.campaign_placement_report_view
#   Found 40 columns
#   Processing column 1/40: campaign_id (bigint)
#   Processing column 2/40: date (date)
#   Processing column 3/40: placement (character varying)
#   Processing column 4/40: impressions (bigint)
#   Processing column 5/40: clicks (integer)
#   Processing column 6/40: cost (double precision)
#   Processing column 7/40: cost_per_click (double precision)
#   Processing column 8/40: campaign_bidding_strategy (character varying)
#   Processing column 9/40: click_through_rate (double precision)
#   Processing column 10/40: spend (double precision)
#   Processing column 11/40: add_to_list (integer)
#   Processing column 12/40: qualified_borrows (integer)
#   Processing column 13/40: royalty_qualified_borrows (integer)
#   Processing column 14/40: purchases_1_d (integer)
#   Processing column 15/40: purchases_7_d (integer)
#   Processing column 16/40: purchases_14_d (integer)
#   Processing column 17/40: purchases_30_d (integer)
#   Processing column 18/40: purchases_same_sku_1_d (integer)
#   Processing column 19/40: purchases_same_sku_7_d (integer)
#   Processing column 20/40: purchases_same_sku_14_d (integer)
#   Processing column 21/40: purchases_same_sku_30_d (integer)
#   Processing column 22/40: units_sold_clicks_1_d (integer)
#   Processing column 23/40: units_sold_clicks_7_d (integer)
#   Processing column 24/40: units_sold_clicks_14_d (integer)
#   Processing column 25/40: units_sold_clicks_30_d (integer)
#   Processing column 26/40: sales_1_d (double precision)
#   Processing column 27/40: sales_7_d (double precision)
#   Processing column 28/40: sales_14_d (double precision)
#   Processing column 29/40: sales_30_d (double precision)
#   Processing column 30/40: attributed_sales_same_sku_1_d (double precision)
#   Processing column 31/40: attributed_sales_same_sku_7_d (double precision)
#   Processing column 32/40: attributed_sales_same_sku_14_d (double precision)
#   Processing column 33/40: attributed_sales_same_sku_30_d (double precision)
#   Processing column 34/40: units_sold_same_sku_1_d (integer)
#   Processing column 35/40: units_sold_same_sku_7_d (integer)
#   Processing column 36/40: units_sold_same_sku_14_d (integer)
#   Processing column 37/40: units_sold_same_sku_30_d (integer)
#   Processing column 38/40: kindle_edition_normalized_pages_read_14_d (integer)
#   Processing column 39/40: kindle_edition_normalized_pages_royalties_14_d (double precision)
#   Processing column 40/40: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.campaign_placement_report_view
#   Completed amazon_ads_thrive.campaign_placement_report_view in 2.17s
#   Progress: 14/92 (15.2%) - Elapsed: 14.6s - ETA: 81.4s
# Table 15/92: amazon_ads_thrive.campaign_serving_status_detail_view
# Processing table: amazon_ads_thrive.campaign_serving_status_detail_view
#   Found 5 columns
#   Processing column 1/5: campaign_id (character varying)
#   Processing column 2/5: name (character varying)
#   Processing column 3/5: help_url (character varying)
#   Processing column 4/5: message (character varying)
#   Processing column 5/5: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.campaign_serving_status_detail_view
#   Completed amazon_ads_thrive.campaign_serving_status_detail_view in 0.32s
#   Progress: 15/92 (16.3%) - Elapsed: 14.9s - ETA: 76.6s
# Table 16/92: amazon_ads_thrive.keyword_history_view
# Processing table: amazon_ads_thrive.keyword_history_view
#   Found 13 columns
#   Processing column 1/13: id (character varying)
#   Processing column 2/13: last_updated_date (timestamp with time zone)
#   Processing column 3/13: campaign_id (character varying)
#   Processing column 4/13: keyword_text (character varying)
#   Processing column 5/13: state (character varying)
#   Processing column 6/13: match_type (character varying)
#   Processing column 7/13: serving_status (character varying)
#   Processing column 8/13: creation_date (timestamp with time zone)
#   Processing column 9/13: ad_group_id (character varying)
#   Processing column 10/13: native_language_keyword (character varying)
#   Processing column 11/13: native_language_locale (character varying)
#   Processing column 12/13: bid (double precision)
#   Processing column 13/13: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.keyword_history_view
#   Completed amazon_ads_thrive.keyword_history_view in 3.84s
#   Progress: 16/92 (17.4%) - Elapsed: 18.8s - ETA: 89.1s
# Table 17/92: amazon_ads_thrive.keyword_serving_status_detail_view
# Processing table: amazon_ads_thrive.keyword_serving_status_detail_view
#   Found 5 columns
#   Processing column 1/5: keyword_id (character varying)
#   Processing column 2/5: name (character varying)
#   Processing column 3/5: help_url (character varying)
#   Processing column 4/5: message (character varying)
#   Processing column 5/5: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.keyword_serving_status_detail_view
#   Completed amazon_ads_thrive.keyword_serving_status_detail_view in 3.53s
#   Progress: 17/92 (18.5%) - Elapsed: 22.3s - ETA: 98.4s
# Table 18/92: amazon_ads_thrive.negative_keyword_history_view
# Processing table: amazon_ads_thrive.negative_keyword_history_view
#   Found 12 columns
#   Processing column 1/12: id (character varying)
#   Processing column 2/12: last_updated_date (timestamp with time zone)
#   Processing column 3/12: campaign_id (character varying)
#   Processing column 4/12: keyword_text (character varying)
#   Processing column 5/12: state (character varying)
#   Processing column 6/12: match_type (character varying)
#   Processing column 7/12: serving_status (character varying)
#   Processing column 8/12: creation_date (timestamp with time zone)
#   Processing column 9/12: ad_group_id (character varying)
#   Processing column 10/12: native_language_keyword (character varying)
#   Processing column 11/12: native_language_locale (character varying)
#   Processing column 12/12: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.negative_keyword_history_view
#   Completed amazon_ads_thrive.negative_keyword_history_view in 0.89s
#   Progress: 18/92 (19.6%) - Elapsed: 23.2s - ETA: 95.4s
# Table 19/92: amazon_ads_thrive.negative_keyword_serving_status_detail_view
# Processing table: amazon_ads_thrive.negative_keyword_serving_status_detail_view
#   Found 5 columns
#   Processing column 1/5: keyword_id (character varying)
#   Processing column 2/5: name (character varying)
#   Processing column 3/5: help_url (character varying)
#   Processing column 4/5: message (character varying)
#   Processing column 5/5: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.negative_keyword_serving_status_detail_view
#   Completed amazon_ads_thrive.negative_keyword_serving_status_detail_view in 0.59s
#   Progress: 19/92 (20.7%) - Elapsed: 23.8s - ETA: 91.4s
# Table 20/92: amazon_ads_thrive.negative_targeting_clause_history_view
# Processing table: amazon_ads_thrive.negative_targeting_clause_history_view
#   Found 9 columns
#   Processing column 1/9: last_updated_date (timestamp with time zone)
#   Processing column 2/9: target_id (character varying)
#   Processing column 3/9: campaign_id (character varying)
#   Processing column 4/9: ad_group_id (character varying)
#   Processing column 5/9: state (character varying)
#   Processing column 6/9: expression_type (character varying)
#   Processing column 7/9: serving_status (character varying)
#   Processing column 8/9: creation_date (timestamp with time zone)
#   Processing column 9/9: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.negative_targeting_clause_history_view
#   Completed amazon_ads_thrive.negative_targeting_clause_history_view in 0.50s
#   Progress: 20/92 (21.7%) - Elapsed: 24.3s - ETA: 87.4s
# Table 21/92: amazon_ads_thrive.negative_targeting_expression_view
# Processing table: amazon_ads_thrive.negative_targeting_expression_view
#   Found 6 columns
#   Processing column 1/6: _fivetran_id (character varying)
#   Processing column 2/6: target_id (character varying)
#   Processing column 3/6: value (character varying)
#   Processing column 4/6: type (character varying)
#   Processing column 5/6: _fivetran_deleted (boolean)
#   Processing column 6/6: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.negative_targeting_expression_view
#   Completed amazon_ads_thrive.negative_targeting_expression_view in 0.36s
#   Progress: 21/92 (22.8%) - Elapsed: 24.6s - ETA: 83.3s
# Table 22/92: amazon_ads_thrive.negative_targeting_resolved_expression_view
# Processing table: amazon_ads_thrive.negative_targeting_resolved_expression_view
#   Found 6 columns
#   Processing column 1/6: _fivetran_id (character varying)
#   Processing column 2/6: target_id (character varying)
#   Processing column 3/6: value (character varying)
#   Processing column 4/6: type (character varying)
#   Processing column 5/6: _fivetran_deleted (boolean)
#   Processing column 6/6: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.negative_targeting_resolved_expression_view
#   Completed amazon_ads_thrive.negative_targeting_resolved_expression_view in 0.35s
#   Progress: 22/92 (23.9%) - Elapsed: 25.0s - ETA: 79.5s
# Table 23/92: amazon_ads_thrive.negative_targeting_serving_status_detail_view
# Processing table: amazon_ads_thrive.negative_targeting_serving_status_detail_view
#   Found 5 columns
#   Processing column 1/5: target_id (character varying)
#   Processing column 2/5: name (character varying)
#   Processing column 3/5: help_url (character varying)
#   Processing column 4/5: message (character varying)
#   Processing column 5/5: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.negative_targeting_serving_status_detail_view
#   Completed amazon_ads_thrive.negative_targeting_serving_status_detail_view in 0.31s
#   Progress: 23/92 (25.0%) - Elapsed: 25.3s - ETA: 75.9s
# Table 24/92: amazon_ads_thrive.portfolio_history_view
# Processing table: amazon_ads_thrive.portfolio_history_view
#   Found 14 columns
#   Processing column 1/14: id (bigint)
#   Processing column 2/14: last_updated_date (timestamp with time zone)
#   Processing column 3/14: profile_id (bigint)
#   Processing column 4/14: name (character varying)
#   Processing column 5/14: in_budget (boolean)
#   Processing column 6/14: state (character varying)
#   Processing column 7/14: serving_status (character varying)
#   Processing column 8/14: creation_date (timestamp with time zone)
#   Processing column 9/14: budget_amount (double precision)
#   Processing column 10/14: budget_currency_code (character varying)
#   Processing column 11/14: budget_policy (character varying)
#   Processing column 12/14: budget_start_date (date)
#   Processing column 13/14: budget_end_date (date)
#   Processing column 14/14: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.portfolio_history_view
#   Completed amazon_ads_thrive.portfolio_history_view in 0.67s
#   Progress: 24/92 (26.1%) - Elapsed: 26.0s - ETA: 73.6s
# Table 25/92: amazon_ads_thrive.product_ad_history_view
# Processing table: amazon_ads_thrive.product_ad_history_view
#   Found 11 columns
#   Processing column 1/11: id (character varying)
#   Processing column 2/11: last_updated_date (timestamp with time zone)
#   Processing column 3/11: campaign_id (character varying)
#   Processing column 4/11: ad_group_id (character varying)
#   Processing column 5/11: custom_text (character varying)
#   Processing column 6/11: sku (character varying)
#   Processing column 7/11: asin (character varying)
#   Processing column 8/11: state (character varying)
#   Processing column 9/11: serving_status (character varying)
#   Processing column 10/11: creation_date (timestamp with time zone)
#   Processing column 11/11: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.product_ad_history_view
#   Completed amazon_ads_thrive.product_ad_history_view in 0.68s
#   Progress: 25/92 (27.2%) - Elapsed: 26.7s - ETA: 71.4s
# Table 26/92: amazon_ads_thrive.product_ad_serving_status_detail_view
# Processing table: amazon_ads_thrive.product_ad_serving_status_detail_view
#   Found 5 columns
#   Processing column 1/5: product_ad_id (character varying)
#   Processing column 2/5: name (character varying)
#   Processing column 3/5: help_url (character varying)
#   Processing column 4/5: message (character varying)
#   Processing column 5/5: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.product_ad_serving_status_detail_view
#   Completed amazon_ads_thrive.product_ad_serving_status_detail_view in 0.37s
#   Progress: 26/92 (28.3%) - Elapsed: 27.0s - ETA: 68.6s
# Table 27/92: amazon_ads_thrive.profile_view
# Processing table: amazon_ads_thrive.profile_view
#   Found 13 columns
#   Processing column 1/13: id (bigint)
#   Processing column 2/13: country_code (character varying)
#   Processing column 3/13: currency_code (character varying)
#   Processing column 4/13: daily_budget (bigint)
#   Processing column 5/13: timezone (character varying)
#   Processing column 6/13: account_marketplace_string_id (character varying)
#   Processing column 7/13: account_id (character varying)
#   Processing column 8/13: account_type (character varying)
#   Processing column 9/13: account_name (character varying)
#   Processing column 10/13: account_sub_type (character varying)
#   Processing column 11/13: account_valid_payment_method (boolean)
#   Processing column 12/13: _fivetran_deleted (boolean)
#   Processing column 13/13: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.profile_view
#   Completed amazon_ads_thrive.profile_view in 0.65s
#   Progress: 27/92 (29.3%) - Elapsed: 27.7s - ETA: 66.6s
# Table 28/92: amazon_ads_thrive.purchased_product_keyword_report_view
# Processing table: amazon_ads_thrive.purchased_product_keyword_report_view
#   Found 39 columns
#   Processing column 1/39: ad_group_id (bigint)
#   Processing column 2/39: campaign_id (bigint)
#   Processing column 3/39: date (date)
#   Processing column 4/39: keyword_id (bigint)
#   Processing column 5/39: purchased_asin (character varying)
#   Processing column 6/39: match_type (character varying)
#   Processing column 7/39: campaign_budget_currency_code (character varying)
#   Processing column 8/39: advertised_asin (character varying)
#   Processing column 9/39: advertised_sku (character varying)
#   Processing column 10/39: add_to_list (integer)
#   Processing column 11/39: qualified_borrows (integer)
#   Processing column 12/39: royalty_qualified_borrows (integer)
#   Processing column 13/39: purchases_other_sku_14_d (integer)
#   Processing column 14/39: purchases_other_sku_1_d (integer)
#   Processing column 15/39: purchases_other_sku_30_d (integer)
#   Processing column 16/39: purchases_other_sku_7_d (integer)
#   Processing column 17/39: sales_other_sku_1_d (double precision)
#   Processing column 18/39: sales_other_sku_7_d (double precision)
#   Processing column 19/39: sales_other_sku_14_d (double precision)
#   Processing column 20/39: sales_other_sku_30_d (double precision)
#   Processing column 21/39: units_sold_other_sku_1_d (integer)
#   Processing column 22/39: units_sold_other_sku_7_d (integer)
#   Processing column 23/39: units_sold_other_sku_14_d (integer)
#   Processing column 24/39: units_sold_other_sku_30_d (integer)
#   Processing column 25/39: purchases_1_d (integer)
#   Processing column 26/39: purchases_7_d (integer)
#   Processing column 27/39: purchases_14_d (integer)
#   Processing column 28/39: purchases_30_d (integer)
#   Processing column 29/39: units_sold_clicks_1_d (integer)
#   Processing column 30/39: units_sold_clicks_7_d (integer)
#   Processing column 31/39: units_sold_clicks_14_d (integer)
#   Processing column 32/39: units_sold_clicks_30_d (integer)
#   Processing column 33/39: sales_1_d (double precision)
#   Processing column 34/39: sales_7_d (double precision)
#   Processing column 35/39: sales_14_d (double precision)
#   Processing column 36/39: sales_30_d (double precision)
#   Processing column 37/39: kindle_edition_normalized_pages_read_14_d (integer)
#   Processing column 38/39: kindle_edition_normalized_pages_royalties_14_d (double precision)
#   Processing column 39/39: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.purchased_product_keyword_report_view
#   Completed amazon_ads_thrive.purchased_product_keyword_report_view in 1.25s
#   Progress: 28/92 (30.4%) - Elapsed: 28.9s - ETA: 66.1s
# Table 29/92: amazon_ads_thrive.purchased_product_targeting_report_view
# Processing table: amazon_ads_thrive.purchased_product_targeting_report_view
#   Found 39 columns
#   Processing column 1/39: ad_group_id (bigint)
#   Processing column 2/39: campaign_id (bigint)
#   Processing column 3/39: date (date)
#   Processing column 4/39: keyword_id (bigint)
#   Processing column 5/39: purchased_asin (character varying)
#   Processing column 6/39: match_type (character varying)
#   Processing column 7/39: campaign_budget_currency_code (character varying)
#   Processing column 8/39: advertised_asin (character varying)
#   Processing column 9/39: advertised_sku (character varying)
#   Processing column 10/39: add_to_list (integer)
#   Processing column 11/39: qualified_borrows (integer)
#   Processing column 12/39: royalty_qualified_borrows (integer)
#   Processing column 13/39: purchases_other_sku_14_d (integer)
#   Processing column 14/39: purchases_other_sku_1_d (integer)
#   Processing column 15/39: purchases_other_sku_30_d (integer)
#   Processing column 16/39: purchases_other_sku_7_d (integer)
#   Processing column 17/39: sales_other_sku_1_d (double precision)
#   Processing column 18/39: sales_other_sku_7_d (double precision)
#   Processing column 19/39: sales_other_sku_14_d (double precision)
#   Processing column 20/39: sales_other_sku_30_d (double precision)
#   Processing column 21/39: units_sold_other_sku_1_d (integer)
#   Processing column 22/39: units_sold_other_sku_7_d (integer)
#   Processing column 23/39: units_sold_other_sku_14_d (integer)
#   Processing column 24/39: units_sold_other_sku_30_d (integer)
#   Processing column 25/39: purchases_1_d (integer)
#   Processing column 26/39: purchases_7_d (integer)
#   Processing column 27/39: purchases_14_d (integer)
#   Processing column 28/39: purchases_30_d (integer)
#   Processing column 29/39: units_sold_clicks_1_d (integer)
#   Processing column 30/39: units_sold_clicks_7_d (integer)
#   Processing column 31/39: units_sold_clicks_14_d (integer)
#   Processing column 32/39: units_sold_clicks_30_d (integer)
#   Processing column 33/39: sales_1_d (double precision)
#   Processing column 34/39: sales_7_d (double precision)
#   Processing column 35/39: sales_14_d (double precision)
#   Processing column 36/39: sales_30_d (double precision)
#   Processing column 37/39: kindle_edition_normalized_pages_read_14_d (integer)
#   Processing column 38/39: kindle_edition_normalized_pages_royalties_14_d (double precision)
#   Processing column 39/39: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.purchased_product_targeting_report_view
#   Completed amazon_ads_thrive.purchased_product_targeting_report_view in 1.25s
#   Progress: 29/92 (31.5%) - Elapsed: 30.2s - ETA: 65.5s
# Table 30/92: amazon_ads_thrive.sb_ad_group_history_view
# Processing table: amazon_ads_thrive.sb_ad_group_history_view
#   Found 8 columns
#   Processing column 1/8: id (character varying)
#   Processing column 2/8: last_update_date (timestamp with time zone)
#   Processing column 3/8: campaign_id (character varying)
#   Processing column 4/8: name (character varying)
#   Processing column 5/8: state (character varying)
#   Processing column 6/8: creation_date (timestamp with time zone)
#   Processing column 7/8: serving_status (character varying)
#   Processing column 8/8: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.sb_ad_group_history_view
#   Completed amazon_ads_thrive.sb_ad_group_history_view in 0.43s
#   Progress: 30/92 (32.6%) - Elapsed: 30.6s - ETA: 63.3s
# Table 31/92: amazon_ads_thrive.sb_ad_group_report_view
# Processing table: amazon_ads_thrive.sb_ad_group_report_view
#   Found 33 columns
#   Processing column 1/33: ad_group_id (bigint)
#   Processing column 2/33: report_date (date)
#   Processing column 3/33: clicks (integer)
#   Processing column 4/33: cost (double precision)
#   Processing column 5/33: impressions (integer)
#   Processing column 6/33: vctr (double precision)
#   Processing column 7/33: video_5_second_view_rate (double precision)
#   Processing column 8/33: video_5_second_views (integer)
#   Processing column 9/33: video_complete_views (integer)
#   Processing column 10/33: video_first_quartile_views (integer)
#   Processing column 11/33: video_midpoint_views (integer)
#   Processing column 12/33: video_third_quartile_views (integer)
#   Processing column 13/33: video_unmutes (integer)
#   Processing column 14/33: viewable_impressions (integer)
#   Processing column 15/33: vtr (double precision)
#   Processing column 16/33: currency (character varying)
#   Processing column 17/33: units_sold_14_d (integer)
#   Processing column 18/33: attributed_conversions_14_d (integer)
#   Processing column 19/33: attributed_conversions_14_d_same_sku (integer)
#   Processing column 20/33: attributed_detail_page_views_clicks_14_d (integer)
#   Processing column 21/33: attributed_order_rate_new_to_brand_14_d (double precision)
#   Processing column 22/33: attributed_orders_new_to_brand_14_d (integer)
#   Processing column 23/33: attributed_orders_new_to_brand_percentage_14_d (double precision)
#   Processing column 24/33: attributed_sales_14_d (double precision)
#   Processing column 25/33: attributed_sales_14_d_same_sku (double precision)
#   Processing column 26/33: attributed_sales_new_to_brand_14_d (double precision)
#   Processing column 27/33: attributed_sales_new_to_brand_percentage_14_d (double precision)
#   Processing column 28/33: attributed_units_ordered_new_to_brand_14_d (integer)
#   Processing column 29/33: attributed_units_ordered_new_to_brand_percentage_14_d (double precision)
#   Processing column 30/33: attributed_branded_searches_14_d (integer)
#   Processing column 31/33: dpv_14_d (integer)
#   Processing column 32/33: campaign_id (character varying)
#   Processing column 33/33: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.sb_ad_group_report_view
#   Completed amazon_ads_thrive.sb_ad_group_report_view in 0.98s
#   Progress: 31/92 (33.7%) - Elapsed: 31.6s - ETA: 62.2s
# Table 32/92: amazon_ads_thrive.sb_ad_history_view
# Processing table: amazon_ads_thrive.sb_ad_history_view
#   Found 12 columns
#   Processing column 1/12: _fivetran_id (character varying)
#   Processing column 2/12: last_update_date (timestamp with time zone)
#   Processing column 3/12: landing_page_page_type (character varying)
#   Processing column 4/12: landing_page_url (character varying)
#   Processing column 5/12: name (character varying)
#   Processing column 6/12: state (character varying)
#   Processing column 7/12: creation_date (timestamp with time zone)
#   Processing column 8/12: serving_status (character varying)
#   Processing column 9/12: id (character varying)
#   Processing column 10/12: ad_group_id (character varying)
#   Processing column 11/12: campaign_id (character varying)
#   Processing column 12/12: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.sb_ad_history_view
#   Completed amazon_ads_thrive.sb_ad_history_view in 0.65s
#   Progress: 32/92 (34.8%) - Elapsed: 32.2s - ETA: 60.4s
# Table 33/92: amazon_ads_thrive.sb_ad_report_view
# Processing table: amazon_ads_thrive.sb_ad_report_view
#   Found 36 columns
#   Processing column 1/36: _fivetran_id (character varying)
#   Processing column 2/36: report_date (date)
#   Processing column 3/36: clicks (integer)
#   Processing column 4/36: cost (double precision)
#   Processing column 5/36: impressions (integer)
#   Processing column 6/36: vctr (double precision)
#   Processing column 7/36: video_5_second_view_rate (double precision)
#   Processing column 8/36: video_5_second_views (integer)
#   Processing column 9/36: video_complete_views (integer)
#   Processing column 10/36: video_first_quartile_views (integer)
#   Processing column 11/36: video_midpoint_views (integer)
#   Processing column 12/36: video_third_quartile_views (integer)
#   Processing column 13/36: video_unmutes (integer)
#   Processing column 14/36: viewable_impressions (integer)
#   Processing column 15/36: vtr (double precision)
#   Processing column 16/36: currency (character varying)
#   Processing column 17/36: units_sold_14_d (integer)
#   Processing column 18/36: attributed_conversions_14_d (integer)
#   Processing column 19/36: attributed_conversions_14_d_same_sku (integer)
#   Processing column 20/36: attributed_detail_page_views_clicks_14_d (integer)
#   Processing column 21/36: attributed_order_rate_new_to_brand_14_d (double precision)
#   Processing column 22/36: attributed_orders_new_to_brand_14_d (integer)
#   Processing column 23/36: attributed_orders_new_to_brand_percentage_14_d (double precision)
#   Processing column 24/36: attributed_sales_14_d (double precision)
#   Processing column 25/36: attributed_sales_14_d_same_sku (double precision)
#   Processing column 26/36: attributed_sales_new_to_brand_14_d (double precision)
#   Processing column 27/36: attributed_sales_new_to_brand_percentage_14_d (double precision)
#   Processing column 28/36: attributed_units_ordered_new_to_brand_14_d (integer)
#   Processing column 29/36: attributed_units_ordered_new_to_brand_percentage_14_d (double precision)
#   Processing column 30/36: attributed_branded_searches_14_d (integer)
#   Processing column 31/36: dpv_14_d (integer)
#   Processing column 32/36: ad_id (character varying)
#   Processing column 33/36: applicable_budget_rule_id (character varying)
#   Processing column 34/36: ad_group_id (character varying)
#   Processing column 35/36: campaign_id (character varying)
#   Processing column 36/36: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.sb_ad_report_view
#   Completed amazon_ads_thrive.sb_ad_report_view in 1.22s
#   Progress: 33/92 (35.9%) - Elapsed: 33.5s - ETA: 59.8s
# Table 34/92: amazon_ads_thrive.sb_ad_sub_page_view
# Processing table: amazon_ads_thrive.sb_ad_sub_page_view
#   Found 5 columns
#   Processing column 1/5: _fivetran_id (character varying)
#   Processing column 2/5: asin (character varying)
#   Processing column 3/5: url (character varying)
#   Processing column 4/5: page_title (character varying)
#   Processing column 5/5: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.sb_ad_sub_page_view
#   Completed amazon_ads_thrive.sb_ad_sub_page_view in 0.32s
#   Progress: 34/92 (37.0%) - Elapsed: 33.8s - ETA: 57.6s
# Table 35/92: amazon_ads_thrive.sb_benchmark_brand_and_category_view
# Processing table: amazon_ads_thrive.sb_benchmark_brand_and_category_view
#   Found 21 columns
#   Processing column 1/21: brand (character varying)
#   Processing column 2/21: category_id (character varying)
# ...
#   Processing column 29/52: units_sold_clicks_7_d (integer)
#   Processing column 30/52: units_sold_clicks_14_d (integer)
#   Processing column 31/52: units_sold_clicks_30_d (integer)
#   Processing column 32/52: sales_1_d (double precision)
#   Processing column 33/52: sales_7_d (double precision)
#   Processing column 34/52: sales_14_d (double precision)
#   Processing column 35/52: sales_30_d (double precision)
#   Processing column 36/52: attributed_sales_same_sku_1_d (double precision)
#   Processing column 37/52: attributed_sales_same_sku_7_d (double precision)
#   Processing column 38/52: attributed_sales_same_sku_14_d (double precision)
#   Processing column 39/52: attributed_sales_same_sku_30_d (double precision)
#   Processing column 40/52: sales_other_sku_7_d (bigint)
#   Processing column 41/52: units_sold_same_sku_1_d (integer)
#   Processing column 42/52: units_sold_same_sku_7_d (integer)
#   Processing column 43/52: units_sold_same_sku_14_d (integer)
#   Processing column 44/52: units_sold_same_sku_30_d (integer)
#   Processing column 45/52: units_sold_other_sku_7_d (integer)
#   Processing column 46/52: kindle_edition_normalized_pages_read_14_d (integer)
#   Processing column 47/52: kindle_edition_normalized_pages_royalties_14_d (double precision)
#   Processing column 48/52: acos_clicks_7_d (double precision)
#   Processing column 49/52: acos_clicks_14_d (double precision)
#   Processing column 50/52: roas_clicks_7_d (double precision)
#   Processing column 51/52: roas_clicks_14_d (double precision)
#   Processing column 52/52: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.search_term_targeting_report_view
#   Completed amazon_ads_thrive.search_term_targeting_report_view in 2.83s
#   Progress: 86/92 (93.5%) - Elapsed: 84.7s - ETA: 5.9s
# Table 87/92: amazon_ads_thrive.targeting_clause_history_view
# Processing table: amazon_ads_thrive.targeting_clause_history_view
#   Found 10 columns
#   Processing column 1/10: last_updated_date (timestamp with time zone)
#   Processing column 2/10: target_id (character varying)
#   Processing column 3/10: campaign_id (character varying)
#   Processing column 4/10: ad_group_id (character varying)
#   Processing column 5/10: state (character varying)
#   Processing column 6/10: expression_type (character varying)
#   Processing column 7/10: serving_status (character varying)
#   Processing column 8/10: creation_date (timestamp with time zone)
#   Processing column 9/10: bid (double precision)
#   Processing column 10/10: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.targeting_clause_history_view
#   Completed amazon_ads_thrive.targeting_clause_history_view in 0.70s
#   Progress: 87/92 (94.6%) - Elapsed: 85.4s - ETA: 4.9s
# Table 88/92: amazon_ads_thrive.targeting_expression_view
# Processing table: amazon_ads_thrive.targeting_expression_view
#   Found 6 columns
#   Processing column 1/6: _fivetran_id (character varying)
#   Processing column 2/6: target_id (character varying)
#   Processing column 3/6: value (character varying)
#   Processing column 4/6: type (character varying)
#   Processing column 5/6: _fivetran_deleted (boolean)
#   Processing column 6/6: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.targeting_expression_view
#   Completed amazon_ads_thrive.targeting_expression_view in 0.49s
#   Progress: 88/92 (95.7%) - Elapsed: 85.9s - ETA: 3.9s
# Table 89/92: amazon_ads_thrive.targeting_keyword_report_view
# Processing table: amazon_ads_thrive.targeting_keyword_report_view
#   Found 54 columns
#   Processing column 1/54: ad_group_id (bigint)
#   Processing column 2/54: campaign_id (bigint)
#   Processing column 3/54: date (date)
#   Processing column 4/54: keyword_id (bigint)
#   Processing column 5/54: ad_keyword_status (character varying)
#   Processing column 6/54: targeting (character varying)
#   Processing column 7/54: match_type (character varying)
#   Processing column 8/54: keyword_type (character varying)
#   Processing column 9/54: keyword_bid (double precision)
#   Processing column 10/54: impressions (integer)
#   Processing column 11/54: clicks (integer)
#   Processing column 12/54: cost_per_click (double precision)
#   Processing column 13/54: cost (double precision)
#   Processing column 14/54: click_through_rate (double precision)
#   Processing column 15/54: campaign_budget_currency_code (character varying)
#   Processing column 16/54: campaign_budget_amount (double precision)
#   Processing column 17/54: campaign_budget_type (character varying)
#   Processing column 18/54: top_of_search_impression_share (double precision)
#   Processing column 19/54: add_to_list (integer)
#   Processing column 20/54: qualified_borrows (integer)
#   Processing column 21/54: royalty_qualified_borrows (integer)
#   Processing column 22/54: purchases_1_d (integer)
#   Processing column 23/54: purchases_7_d (integer)
#   Processing column 24/54: purchases_14_d (integer)
#   Processing column 25/54: purchases_30_d (integer)
#   Processing column 26/54: purchases_same_sku_1_d (integer)
#   Processing column 27/54: purchases_same_sku_7_d (integer)
#   Processing column 28/54: purchases_same_sku_14_d (integer)
#   Processing column 29/54: purchases_same_sku_30_d (integer)
#   Processing column 30/54: units_sold_clicks_1_d (integer)
#   Processing column 31/54: units_sold_clicks_7_d (integer)
#   Processing column 32/54: units_sold_clicks_14_d (integer)
#   Processing column 33/54: units_sold_clicks_30_d (integer)
#   Processing column 34/54: sales_1_d (double precision)
#   Processing column 35/54: sales_7_d (double precision)
#   Processing column 36/54: sales_14_d (double precision)
#   Processing column 37/54: sales_30_d (double precision)
#   Processing column 38/54: attributed_sales_same_sku_1_d (double precision)
#   Processing column 39/54: attributed_sales_same_sku_7_d (double precision)
#   Processing column 40/54: attributed_sales_same_sku_14_d (double precision)
#   Processing column 41/54: attributed_sales_same_sku_30_d (double precision)
#   Processing column 42/54: sales_other_sku_7_d (bigint)
#   Processing column 43/54: units_sold_same_sku_1_d (integer)
#   Processing column 44/54: units_sold_same_sku_7_d (integer)
#   Processing column 45/54: units_sold_same_sku_14_d (integer)
#   Processing column 46/54: units_sold_same_sku_30_d (integer)
#   Processing column 47/54: units_sold_other_sku_7_d (integer)
#   Processing column 48/54: kindle_edition_normalized_pages_read_14_d (integer)
#   Processing column 49/54: kindle_edition_normalized_pages_royalties_14_d (double precision)
#   Processing column 50/54: acos_clicks_7_d (double precision)
#   Processing column 51/54: acos_clicks_14_d (double precision)
#   Processing column 52/54: roas_clicks_7_d (double precision)
#   Processing column 53/54: roas_clicks_14_d (double precision)
#   Processing column 54/54: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.targeting_keyword_report_view
#   Completed amazon_ads_thrive.targeting_keyword_report_view in 11.86s
#   Progress: 89/92 (96.7%) - Elapsed: 97.8s - ETA: 3.3s
# Table 90/92: amazon_ads_thrive.targeting_report_view
# Processing table: amazon_ads_thrive.targeting_report_view
#   Found 54 columns
#   Processing column 1/54: ad_group_id (bigint)
#   Processing column 2/54: campaign_id (bigint)
#   Processing column 3/54: date (date)
#   Processing column 4/54: keyword_id (bigint)
#   Processing column 5/54: ad_keyword_status (character varying)
#   Processing column 6/54: targeting (character varying)
#   Processing column 7/54: match_type (character varying)
#   Processing column 8/54: keyword_type (character varying)
#   Processing column 9/54: keyword_bid (double precision)
#   Processing column 10/54: impressions (integer)
#   Processing column 11/54: clicks (integer)
#   Processing column 12/54: cost_per_click (double precision)
#   Processing column 13/54: cost (double precision)
#   Processing column 14/54: click_through_rate (double precision)
#   Processing column 15/54: campaign_budget_currency_code (character varying)
#   Processing column 16/54: campaign_budget_amount (double precision)
#   Processing column 17/54: campaign_budget_type (character varying)
#   Processing column 18/54: top_of_search_impression_share (double precision)
#   Processing column 19/54: add_to_list (integer)
#   Processing column 20/54: qualified_borrows (integer)
#   Processing column 21/54: royalty_qualified_borrows (integer)
#   Processing column 22/54: purchases_1_d (integer)
#   Processing column 23/54: purchases_7_d (integer)
#   Processing column 24/54: purchases_14_d (integer)
#   Processing column 25/54: purchases_30_d (integer)
#   Processing column 26/54: purchases_same_sku_1_d (integer)
#   Processing column 27/54: purchases_same_sku_7_d (integer)
#   Processing column 28/54: purchases_same_sku_14_d (integer)
#   Processing column 29/54: purchases_same_sku_30_d (integer)
#   Processing column 30/54: units_sold_clicks_1_d (integer)
#   Processing column 31/54: units_sold_clicks_7_d (integer)
#   Processing column 32/54: units_sold_clicks_14_d (integer)
#   Processing column 33/54: units_sold_clicks_30_d (integer)
#   Processing column 34/54: sales_1_d (double precision)
#   Processing column 35/54: sales_7_d (double precision)
#   Processing column 36/54: sales_14_d (double precision)
#   Processing column 37/54: sales_30_d (double precision)
#   Processing column 38/54: attributed_sales_same_sku_1_d (double precision)
#   Processing column 39/54: attributed_sales_same_sku_7_d (double precision)
#   Processing column 40/54: attributed_sales_same_sku_14_d (double precision)
#   Processing column 41/54: attributed_sales_same_sku_30_d (double precision)
#   Processing column 42/54: sales_other_sku_7_d (bigint)
#   Processing column 43/54: units_sold_same_sku_1_d (integer)
#   Processing column 44/54: units_sold_same_sku_7_d (integer)
#   Processing column 45/54: units_sold_same_sku_14_d (integer)
#   Processing column 46/54: units_sold_same_sku_30_d (integer)
#   Processing column 47/54: units_sold_other_sku_7_d (integer)
#   Processing column 48/54: kindle_edition_normalized_pages_read_14_d (integer)
#   Processing column 49/54: kindle_edition_normalized_pages_royalties_14_d (double precision)
#   Processing column 50/54: acos_clicks_7_d (double precision)
#   Processing column 51/54: acos_clicks_14_d (double precision)
#   Processing column 52/54: roas_clicks_7_d (double precision)
#   Processing column 53/54: roas_clicks_14_d (double precision)
#   Processing column 54/54: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.targeting_report_view
#   Completed amazon_ads_thrive.targeting_report_view in 6.57s
#   Progress: 90/92 (97.8%) - Elapsed: 104.3s - ETA: 2.3s
# Table 91/92: amazon_ads_thrive.targeting_resolved_expression_view
# Processing table: amazon_ads_thrive.targeting_resolved_expression_view
#   Found 6 columns
#   Processing column 1/6: _fivetran_id (character varying)
#   Processing column 2/6: target_id (character varying)
#   Processing column 3/6: value (character varying)
#   Processing column 4/6: type (character varying)
#   Processing column 5/6: _fivetran_deleted (boolean)
#   Processing column 6/6: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.targeting_resolved_expression_view
#   Completed amazon_ads_thrive.targeting_resolved_expression_view in 0.49s
#   Progress: 91/92 (98.9%) - Elapsed: 104.8s - ETA: 1.2s
# Table 92/92: amazon_ads_thrive.targeting_serving_status_detail_view
# Processing table: amazon_ads_thrive.targeting_serving_status_detail_view
#   Found 5 columns
#   Processing column 1/5: target_id (character varying)
#   Processing column 2/5: name (character varying)
#   Processing column 3/5: help_url (character varying)
#   Processing column 4/5: message (character varying)
#   Processing column 5/5: _fivetran_synced (timestamp with time zone)
#   Completed table: amazon_ads_thrive.targeting_serving_status_detail_view
#   Completed amazon_ads_thrive.targeting_serving_status_detail_view in 0.37s
#   Progress: 92/92 (100.0%) - Elapsed: 105.2s - ETA: 0.0s
# Completed schema statistics for: ['amazon_ads_thrive'] in 105.20s
# {'amazon_ads_thrive.ad_group_history_view': {'id': {'data_type': 'character varying', 'udt_name': 'varchar', 'category': 'text', 'stats': {'total_rows': 728, 'non_null_rows': 728, 'null_rows': 0, 'distinct_values': 728, 'avg_length': Decimal('14.6304945054945055'), 'min_length': 12, 'max_length': 15, 'top_values': [{'value': '101180574487644', 'count': 1}, {'value': '101619008626738', 'count': 1}, {'value': '102237366048889', 'count': 1}, {'value': '10228173083157', 'count': 1}, {'value': '10289633950586', 'count': 1}, {'value': '102988116954951', 'count': 1}, {'value': '10298853894571', 'count': 1}, {'value': '103394006819478', 'count': 1}, {'value': '103603063725063', 'count': 1}, {'value': '100843849908948', 'count': 1}]}}, 'last_updated_date': {'data_type': 'timestamp with time zone', 'udt_name': 'timestamptz', 'category': 'timestamp', 'stats': {'total_rows': 728, 'non_null_rows': 728, 'null_rows': 0, 'min_value': datetime.datetime(2016, 10, 18, 1, 17, 41, tzinfo=datetime.timezone.utc), 'max_value': datetime.datetime(2025, 7, 9, 13, 46, 8, 479000, tzinfo=datetime.timezone.utc), 'distinct_values': 555, 'top_values': [{'value': '2017-01-27 16:16:25+00:00', 'count': 34}, {'value': '2019-04-02 19:58:22+00:00', 'count': 19}, {'value': '2022-11-10 14:17:15.863000+00:00', 'count': 18}, {'value': '2019-04-16 22:49:32+00:00', 'count': 13}, {'value': '2018-06-18 22:51:34+00:00', 'count': 10}, {'value': '2022-11-10 14:17:15.864000+00:00', 'count': 10}, {'value': '2022-11-09 16:03:35.818000+00:00', 'count': 10}, {'value': '2021-07-23 02:19:04+00:00', 'count': 7}, {'value': '2018-08-25 13:53:14+00:00', 'count': 7}, {'value': '2018-08-25 13:54:10+00:00', 'count': 6}]}}, 'serving_status': {'data_type': 'character varying', 'udt_name': 'varchar', 'category': 'text', 'stats': {'total_rows': 728, 'non_null_rows': 728, 'null_rows': 0, 'distinct_values': 6, 'avg_length': Decimal('17.1153846153846154'), 'min_length': 15, 'max_length': 23, 'top_values': [{'value': 'CAMPAIGN_PAUSED', 'count': 270}, {'value': 'CAMPAIGN_ARCHIVED', 'count': 226}, {'value': 'AD_GROUP_STATUS_ENABLED', 'count': 89}, {'value': 'PORTFOLIO_ENDED', 'count': 61}, {'value': 'PORTFOLIO_OUT_OF_BUDGET', 'count': 47}, {'value': 'AD_GROUP_PAUSED', 'count': 35}]}}, 'creation_date': {'data_type': 'timestamp with time zone', 'udt_name': 'timestamptz', 'category': 'timestamp', 'stats': {'total_rows': 728, 'non_null_rows': 728, 'null_rows': 0, 'min_value': datetime.datetime(2016, 1, 12, 4, 26, 53, tzinfo=datetime.timezone.utc), 'max_value': datetime.datetime(2025, 5, 30, 16, 45, 38, 733000, tzinfo=datetime.timezone.utc), 'distinct_values': 700, 'top_values': [{'value': '2019-01-26 06:47:29+00:00', 'count': 8}, {'value': '2019-11-21 10:25:17+00:00', 'count': 6}, {'value': '2019-03-18 20:12:52+00:00', 'count': 5}, {'value': '2019-03-18 20:12:58+00:00', 'count': 4}, {'value': '2018-09-09 05:41:19+00:00', 'count': 3}, {'value': '2018-06-07 23:05:26+00:00', 'count': 3}, {'value': '2018-09-09 05:27:08+00:00', 'count': 3}, {'value': '2019-01-26 06:35:04+00:00', 'count': 2}, {'value': '2020-08-02 21:45:59+00:00', 'count': 2}, {'value': '2018-09-14 02:48:47+00:00', 'count': 2}]}}, 'campaign_id': {'data_type': 'character varying', 'udt_name': 'varchar', 'category': 'text', 'stats': {'total_rows': 728, 'non_null_rows': 728, 'null_rows': 0, 'distinct_values': 517, 'avg_length': Decimal('14.6291208791208791'), 'min_length': 12, 'max_length': 15, 'top_values': [{'value': '249828922192343', 'count': 31}, {'value': '207424676495630', 'count': 15}, {'value': '101382915393197', 'count': 15}, {'value': '124952118215796', 'count': 15}, {'value': '25490233158169', 'count': 13}, {'value': '1897516206815', 'count': 11}, {'value': '177756363069478', 'count': 10}, {'value': '69079113002218', 'count': 9}, {'value': '267740021899020', 'count': 8}, {'value': '176191152849437', 'count': 7}]}}, 'name': {'data_type': 'character varying', 'udt_name': 'varchar', 'category': 'text', 'stats': {'total_rows': 728, 'non_ ...

# %%
import json
print(json.dumps(stats, indent=2, default=str))
# Out:
# {
#   "amazon_ads_thrive.ad_group_history_view": {
#     "id": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 728,
#         "non_null_rows": 728,
#         "null_rows": 0,
#         "distinct_values": 728,
#         "avg_length": "14.6304945054945055",
#         "min_length": 12,
#         "max_length": 15,
#         "top_values": [
#           {
#             "value": "101180574487644",
#             "count": 1
#           },
#           {
#             "value": "101619008626738",
#             "count": 1
#           },
#           {
#             "value": "102237366048889",
#             "count": 1
#           },
#           {
#             "value": "10228173083157",
#             "count": 1
#           },
#           {
#             "value": "10289633950586",
#             "count": 1
#           },
#           {
#             "value": "102988116954951",
#             "count": 1
#           },
#           {
#             "value": "10298853894571",
#             "count": 1
#           },
#           {
#             "value": "103394006819478",
#             "count": 1
#           },
#           {
#             "value": "103603063725063",
#             "count": 1
#           },
#           {
#             "value": "100843849908948",
#             "count": 1
#           }
#         ]
#       }
#     },
#     "last_updated_date": {
#       "data_type": "timestamp with time zone",
#       "udt_name": "timestamptz",
#       "category": "timestamp",
#       "stats": {
#         "total_rows": 728,
#         "non_null_rows": 728,
#         "null_rows": 0,
#         "min_value": "2016-10-18 01:17:41+00:00",
#         "max_value": "2025-07-09 13:46:08.479000+00:00",
#         "distinct_values": 555,
#         "top_values": [
#           {
#             "value": "2017-01-27 16:16:25+00:00",
#             "count": 34
#           },
#           {
#             "value": "2019-04-02 19:58:22+00:00",
#             "count": 19
#           },
#           {
#             "value": "2022-11-10 14:17:15.863000+00:00",
#             "count": 18
#           },
#           {
#             "value": "2019-04-16 22:49:32+00:00",
#             "count": 13
#           },
#           {
#             "value": "2018-06-18 22:51:34+00:00",
#             "count": 10
#           },
#           {
#             "value": "2022-11-10 14:17:15.864000+00:00",
#             "count": 10
#           },
#           {
#             "value": "2022-11-09 16:03:35.818000+00:00",
#             "count": 10
#           },
#           {
#             "value": "2021-07-23 02:19:04+00:00",
#             "count": 7
#           },
#           {
#             "value": "2018-08-25 13:53:14+00:00",
#             "count": 7
#           },
#           {
#             "value": "2018-08-25 13:54:10+00:00",
#             "count": 6
#           }
#         ]
#       }
#     },
#     "serving_status": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 728,
#         "non_null_rows": 728,
#         "null_rows": 0,
#         "distinct_values": 6,
#         "avg_length": "17.1153846153846154",
#         "min_length": 15,
#         "max_length": 23,
#         "top_values": [
#           {
#             "value": "CAMPAIGN_PAUSED",
#             "count": 270
#           },
#           {
#             "value": "CAMPAIGN_ARCHIVED",
#             "count": 226
#           },
#           {
#             "value": "AD_GROUP_STATUS_ENABLED",
#             "count": 89
#           },
#           {
#             "value": "PORTFOLIO_ENDED",
#             "count": 61
#           },
#           {
#             "value": "PORTFOLIO_OUT_OF_BUDGET",
#             "count": 47
#           },
#           {
#             "value": "AD_GROUP_PAUSED",
#             "count": 35
#           }
#         ]
#       }
#     },
#     "creation_date": {
#       "data_type": "timestamp with time zone",
#       "udt_name": "timestamptz",
#       "category": "timestamp",
#       "stats": {
#         "total_rows": 728,
#         "non_null_rows": 728,
#         "null_rows": 0,
#         "min_value": "2016-01-12 04:26:53+00:00",
#         "max_value": "2025-05-30 16:45:38.733000+00:00",
#         "distinct_values": 700,
#         "top_values": [
#           {
#             "value": "2019-01-26 06:47:29+00:00",
#             "count": 8
#           },
#           {
#             "value": "2019-11-21 10:25:17+00:00",
#             "count": 6
#           },
#           {
#             "value": "2019-03-18 20:12:52+00:00",
#             "count": 5
#           },
#           {
#             "value": "2019-03-18 20:12:58+00:00",
#             "count": 4
#           },
#           {
#             "value": "2018-09-09 05:41:19+00:00",
#             "count": 3
#           },
#           {
#             "value": "2018-06-07 23:05:26+00:00",
#             "count": 3
#           },
#           {
#             "value": "2018-09-09 05:27:08+00:00",
#             "count": 3
#           },
#           {
#             "value": "2019-01-26 06:35:04+00:00",
#             "count": 2
#           },
#           {
#             "value": "2020-08-02 21:45:59+00:00",
#             "count": 2
#           },
#           {
#             "value": "2018-09-14 02:48:47+00:00",
#             "count": 2
#           }
#         ]
#       }
#     },
#     "campaign_id": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 728,
#         "non_null_rows": 728,
#         "null_rows": 0,
#         "distinct_values": 517,
#         "avg_length": "14.6291208791208791",
#         "min_length": 12,
#         "max_length": 15,
#         "top_values": [
#           {
#             "value": "249828922192343",
#             "count": 31
#           },
#           {
#             "value": "207424676495630",
#             "count": 15
#           },
#           {
#             "value": "101382915393197",
#             "count": 15
#           },
#           {
#             "value": "124952118215796",
#             "count": 15
#           },
#           {
#             "value": "25490233158169",
#             "count": 13
#           },
#           {
#             "value": "1897516206815",
#             "count": 11
#           },
#           {
#             "value": "177756363069478",
#             "count": 10
#           },
#           {
#             "value": "69079113002218",
#             "count": 9
#           },
#           {
#             "value": "267740021899020",
#             "count": 8
#           },
#           {
#             "value": "176191152849437",
#             "count": 7
#           }
#         ]
#       }
#     },
#     "name": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 728,
#         "non_null_rows": 728,
#         "null_rows": 0,
#         "distinct_values": 445,
#         "avg_length": "17.4560439560439560",
#         "min_length": 2,
#         "max_length": 213,
#         "top_values": [
#           {
#             "value": "AdGroup1",
#             "count": 46
#           },
#           {
#             "value": "Face Scrub",
#             "count": 14
#           },
#           {
#             "value": "Face Lotion",
#             "count": 14
#           },
#           {
#             "value": "Face Wash",
#             "count": 12
#           },
#           {
#             "value": "VIP",
#             "count": 12
#           },
#           {
#             "value": "OTD",
#             "count": 12
#           },
#           {
#             "value": "Ad Group 1",
#             "count": 12
#           },
#           {
#             "value": "S&R",
#             "count": 11
#           },
#           {
#             "value": "Renew",
#             "count": 9
#           },
#           {
#             "value": "Spot",
#             "count": 8
#           }
#         ]
#       }
#     },
#     "default_bid": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 728,
#         "non_null_rows": 728,
#         "null_rows": 0,
#         "distinct_values": 126,
#         "avg_value": 1.15776098901099,
#         "min_value": 0.02,
#         "max_value": 4.01,
#         "stddev": 0.666671968537926,
#         "p25": 0.6,
#         "median": 1.0,
#         "p75": 1.5
#       }
#     },
#     "state": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 728,
#         "non_null_rows": 728,
#         "null_rows": 0,
#         "distinct_values": 3,
#         "avg_length": "7.1978021978021978",
#         "min_length": 6,
#         "max_length": 8,
#         "top_values": [
#           {
#             "value": "ENABLED",
#             "count": 390
#           },
#           {
#             "value": "ARCHIVED",
#             "count": 241
#           },
#           {
#             "value": "PAUSED",
#             "count": 97
#           }
#         ]
#       }
#     },
#     "_fivetran_synced": {
#       "data_type": "timestamp with time zone",
#       "udt_name": "timestamptz",
#       "category": "timestamp",
#       "stats": {
#         "total_rows": 728,
#         "non_null_rows": 728,
#         "null_rows": 0,
#         "min_value": "2025-09-01 08:16:14.035000+00:00",
#         "max_value": "2025-09-01 08:22:14.201000+00:00",
#         "distinct_values": 550,
#         "top_values": [
#           {
#             "value": "2025-09-01 08:18:26.845000+00:00",
#             "count": 14
#           },
#           {
#             "value": "2025-09-01 08:16:15.215000+00:00",
#             "count": 13
#           },
#           {
#             "value": "2025-09-01 08:16:24.755000+00:00",
#             "count": 8
#           },
#           {
#             "value": "2025-09-01 08:17:48.921000+00:00",
#             "count": 8
#           },
#           {
#             "value": "2025-09-01 08:17:21.962000+00:00",
#             "count": 7
#           },
#           {
#             "value": "2025-09-01 08:17:21.963000+00:00",
#             "count": 7
#           },
#           {
#             "value": "2025-09-01 08:17:25.869000+00:00",
#             "count": 7
#           },
#           {
#             "value": "2025-09-01 08:16:28.421000+00:00",
#             "count": 6
#           },
#           {
#             "value": "2025-09-01 08:21:00.385000+00:00",
#             "count": 6
#           },
#           {
#             "value": "2025-09-01 08:17:03.051000+00:00",
#             "count": 6
#           }
#         ]
#       }
#     }
#   },
#   "amazon_ads_thrive.ad_group_level_report_view": {
#     "ad_group_id": {
#       "data_type": "bigint",
#       "udt_name": "int8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 74,
#         "avg_value": "259243638308026.6270",
#         "min_value": 3318832287757,
#         "max_value": 561221215009697,
#         "stddev": "165339635773244",
#         "p25": 119977989841433.0,
#         "median": 235473335944983.0,
#         "p75": 433711230327165.0
#       }
#     },
#     "date": {
#       "data_type": "date",
#       "udt_name": "date",
#       "category": "date",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "min_value": "2025-05-14",
#         "max_value": "2025-09-01",
#         "distinct_values": 111,
#         "top_values": [
#           {
#             "value": "2025-06-01",
#             "count": 73
#           },
#           {
#             "value": "2025-06-11",
#             "count": 72
#           },
#           {
#             "value": "2025-05-31",
#             "count": 72
#           },
#           {
#             "value": "2025-06-02",
#             "count": 72
#           },
#           {
#             "value": "2025-06-17",
#             "count": 71
#           },
#           {
#             "value": "2025-06-06",
#             "count": 71
#           },
#           {
#             "value": "2025-06-12",
#             "count": 71
#           },
#           {
#             "value": "2025-06-22",
#             "count": 71
#           },
#           {
#             "value": "2025-05-30",
#             "count": 71
#           },
#           {
#             "value": "2025-06-13",
#             "count": 71
#           }
#         ]
#       }
#     },
#     "impressions": {
#       "data_type": "bigint",
#       "udt_name": "int8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 3268,
#         "avg_value": "4994.5260754272245138",
#         "min_value": 0,
#         "max_value": 458109,
#         "stddev": "17281.03970282",
#         "p25": 96.0,
#         "median": 567.5,
#         "p75": 2893.75
#       }
#     },
#     "clicks": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 218,
#         "avg_value": "11.7388037713612257",
#         "min_value": 0,
#         "max_value": 612,
#         "stddev": "34.4613391432826631",
#         "p25": 0.0,
#         "median": 1.0,
#         "p75": 7.0
#       }
#     },
#     "cost": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 2391,
#         "avg_value": 23.3660047142015,
#         "min_value": 0.0,
#         "max_value": 1729.73,
#         "stddev": 76.8719816242569,
#         "p25": 0.0,
#         "median": 2.4,
#         "p75": 11.515
#       }
#     },
#     "cost_per_click": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 371,
#         "avg_value": 1.14841926929877,
#         "min_value": 0.0,
#         "max_value": 5.0,
#         "stddev": 1.02297362929329,
#         "p25": 0.0,
#         "median": 1.29,
#         "p75": 1.92
#       }
#     },
#     "campaign_bidding_strategy": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 2,
#         "avg_length": "6.0869180907483795",
#         "min_length": 6,
#         "max_length": 16,
#         "top_values": [
#           {
#             "value": "legacy",
#             "count": 6729
#           },
#           {
#             "value": "optimizeForSales",
#             "count": 59
#           }
#         ]
#       }
#     },
#     "click_through_rate": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6694,
#         "null_rows": 94,
#         "distinct_values": 3469,
#         "avg_value": 0.794578036443087,
#         "min_value": 0.0,
#         "max_value": 100.0,
#         "stddev": 4.18456887902616,
#         "p25": 0.0,
#         "median": 0.124843945068664,
#         "p75": 0.488471012701116
#       }
#     },
#     "spend": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 2391,
#         "avg_value": 23.3660047142015,
#         "min_value": 0.0,
#         "max_value": 1729.73,
#         "stddev": 76.8719816242569,
#         "p25": 0.0,
#         "median": 2.4,
#         "p75": 11.515
#       }
#     },
#     "add_to_list": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 1,
#         "avg_value": "0E-20",
#         "min_value": 0,
#         "max_value": 0,
#         "stddev": "0",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 0.0
#       }
#     },
#     "qualified_borrows": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 1,
#         "avg_value": "0E-20",
#         "min_value": 0,
#         "max_value": 0,
#         "stddev": "0",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 0.0
#       }
#     },
#     "royalty_qualified_borrows": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 1,
#         "avg_value": "0E-20",
#         "min_value": 0,
#         "max_value": 0,
#         "stddev": "0",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 0.0
#       }
#     },
#     "purchases_1_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 54,
#         "avg_value": "1.7038892162639953",
#         "min_value": 0,
#         "max_value": 147,
#         "stddev": "5.3722875026247073",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "purchases_7_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 60,
#         "avg_value": "1.9444608131997643",
#         "min_value": 0,
#         "max_value": 164,
#         "stddev": "6.0790197301142526",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "purchases_14_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 62,
#         "avg_value": "2.0017678255745433",
#         "min_value": 0,
#         "max_value": 169,
#         "stddev": "6.2408793481743893",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "purchases_30_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 63,
#         "avg_value": "2.0626104890984090",
#         "min_value": 0,
#         "max_value": 174,
#         "stddev": "6.4188831874032261",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "purchases_same_sku_1_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 46,
#         "avg_value": "1.3040659988214496",
#         "min_value": 0,
#         "max_value": 133,
#         "stddev": "4.5199557157867298",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "purchases_same_sku_7_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 51,
#         "avg_value": "1.4743665291691220",
#         "min_value": 0,
#         "max_value": 148,
#         "stddev": "5.0986516529154481",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "purchases_same_sku_14_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 55,
#         "avg_value": "1.5110489098408957",
#         "min_value": 0,
#         "max_value": 152,
#         "stddev": "5.2184371738824031",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "purchases_same_sku_30_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 54,
#         "avg_value": "1.5490571596935769",
#         "min_value": 0,
#         "max_value": 156,
#         "stddev": "5.3521994168917347",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "units_sold_clicks_1_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 59,
#         "avg_value": "1.8229228049499116",
#         "min_value": 0,
#         "max_value": 176,
#         "stddev": "5.9255131993968741",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "units_sold_clicks_7_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 65,
#         "avg_value": "2.0782262816735415",
#         "min_value": 0,
#         "max_value": 195,
#         "stddev": "6.6849966032267134",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "units_sold_clicks_14_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 64,
#         "avg_value": "2.1396582203889216",
#         "min_value": 0,
#         "max_value": 200,
#         "stddev": "6.8614184761461002",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "units_sold_clicks_30_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 69,
#         "avg_value": "2.2037418974661167",
#         "min_value": 0,
#         "max_value": 205,
#         "stddev": "7.0484988213914093",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "sales_1_d": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 773,
#         "avg_value": 55.08545963465,
#         "min_value": 0.0,
#         "max_value": 4311.92,
#         "stddev": 179.248166101179,
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 26.96
#       }
#     },
#     "sales_7_d": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 854,
#         "avg_value": 62.6817368886278,
#         "min_value": 0.0,
#         "max_value": 4813.96,
#         "stddev": 202.231145427546,
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 29.95
#       }
#     },
#     "sales_14_d": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 885,
#         "avg_value": 64.5488612256931,
#         "min_value": 0.0,
#         "max_value": 4963.71,
#         "stddev": 207.837835182665,
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 29.95
#       }
#     },
#     "sales_30_d": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 928,
#         "avg_value": 66.3819725987044,
#         "min_value": 0.0,
#         "max_value": 5138.46,
#         "stddev": 213.533276024761,
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 29.95
#       }
#     },
#     "attributed_sales_same_sku_1_d": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 289,
#         "avg_value": 38.5434089569832,
#         "min_value": 0.0,
#         "max_value": 3815.63,
#         "stddev": 138.610438255306,
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 17.95
#       }
#     },
#     "attributed_sales_same_sku_7_d": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 343,
#         "avg_value": 43.4967295226876,
#         "min_value": 0.0,
#         "max_value": 4216.96,
#         "stddev": 155.877238885959,
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 17.95
#       }
#     },
#     "attributed_sales_same_sku_14_d": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 362,
#         "avg_value": 44.6228344136717,
#         "min_value": 0.0,
#         "max_value": 4336.76,
#         "stddev": 159.810266889369,
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 17.95
#       }
#     },
#     "attributed_sales_same_sku_30_d": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 391,
#         "avg_value": 45.7101929876258,
#         "min_value": 0.0,
#         "max_value": 4456.56,
#         "stddev": 163.851364843955,
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 17.95
#       }
#     },
#     "units_sold_same_sku_1_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 50,
#         "avg_value": "1.3986446670595168",
#         "min_value": 0,
#         "max_value": 159,
#         "stddev": "5.0232297791672050",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "units_sold_same_sku_7_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 55,
#         "avg_value": "1.5798467884502062",
#         "min_value": 0,
#         "max_value": 176,
#         "stddev": "5.6517693155461076",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "units_sold_same_sku_14_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 60,
#         "avg_value": "1.6200648202710666",
#         "min_value": 0,
#         "max_value": 180,
#         "stddev": "5.7864245588369254",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "units_sold_same_sku_30_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 61,
#         "avg_value": "1.6613140836770772",
#         "min_value": 0,
#         "max_value": 184,
#         "stddev": "5.9302507565377678",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 1.0
#       }
#     },
#     "kindle_edition_normalized_pages_read_14_d": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 1,
#         "avg_value": "0E-20",
#         "min_value": 0,
#         "max_value": 0,
#         "stddev": "0",
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 0.0
#       }
#     },
#     "kindle_edition_normalized_pages_royalties_14_d": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "distinct_values": 1,
#         "avg_value": 0.0,
#         "min_value": 0.0,
#         "max_value": 0.0,
#         "stddev": 0.0,
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 0.0
#       }
#     },
#     "_fivetran_synced": {
#       "data_type": "timestamp with time zone",
#       "udt_name": "timestamptz",
#       "category": "timestamp",
#       "stats": {
#         "total_rows": 6788,
#         "non_null_rows": 6788,
#         "null_rows": 0,
#         "min_value": "2025-08-14 09:39:34.699000+00:00",
#         "max_value": "2025-09-01 20:05:52.899000+00:00",
#         "distinct_values": 285,
#         "top_values": [
#           {
#             "value": "2025-09-01 19:50:24.429000+00:00",
#             "count": 93
#           },
#           {
#             "value": "2025-09-01 19:50:24.428000+00:00",
#             "count": 91
#           },
#           {
#             "value": "2025-09-01 19:34:55.997000+00:00",
#             "count": 90
#           },
#           {
#             "value": "2025-09-01 20:05:52.891000+00:00",
#             "count": 90
#           },
#           {
#             "value": "2025-09-01 20:05:52.897000+00:00",
#             "count": 88
#           },
#           {
#             "value": "2025-09-01 20:05:52.892000+00:00",
#             "count": 86
#           },
#           {
#             "value": "2025-09-01 20:05:52.898000+00:00",
#             "count": 86
#           },
#           {
#             "value": "2025-09-01 20:05:52.893000+00:00",
#             "count": 86
#           },
#           {
#             "value": "2025-09-01 20:05:52.890000+00:00",
#             "count": 84
#           },
#           {
#             "value": "2025-08-15 07:35:13.754000+00:00",
#             "count": 83
#           }
#         ]
#       }
#     }
#   },
#   "amazon_ads_thrive.ad_group_serving_status_detail_view": {
#     "ad_group_id": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 1279,
#         "non_null_rows": 1279,
#         "null_rows": 0,
#         "distinct_values": 728,
#         "avg_length": "14.6270523846755278",
#         "min_length": 12,
#         "max_length": 15,
#         "top_values": [
#           {
#             "value": "89229218625507",
#             "count": 6
#           },
#           {
#             "value": "56294432851953",
#             "count": 5
#           },
#           {
#             "value": "174741294997609",
#             "count": 5
#           },
#           {
#             "value": "230602992818567",
#             "count": 5
#           },
#           {
#             "value": "67947975330346",
#             "count": 5
#           },
#           {
#             "value": "264487612392017",
#             "count": 5
#           },
#           {
#             "value": "239323529799551",
#             "count": 4
#           },
#           {
#             "value": "200817832963452",
#             "count": 4
#           },
#           {
#             "value": "54786651397442",
#             "count": 4
#           },
#           {
#             "value": "168610045380084",
#             "count": 4
#           }
#         ]
#       }
#     },
#     "name": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 1279,
#         "non_null_rows": 1279,
#         "null_rows": 0,
#         "distinct_values": 10,
#         "avg_length": "23.7544956997654418",
#         "min_length": 12,
#         "max_length": 30,
#         "top_values": [
#           {
#             "value": "CAMPAIGN_PAUSED_DETAIL",
#             "count": 369
#           },
#           {
#             "value": "AD_GROUP_ARCHIVED_DETAIL",
#             "count": 241
#           },
#           {
#             "value": "CAMPAIGN_ARCHIVED_DETAIL",
#             "count": 235
#           },
#           {
#             "value": "PORTFOLIO_ENDED_DETAIL",
#             "count": 108
#           },
#           {
#             "value": "AD_GROUP_PAUSED_DETAIL",
#             "count": 97
#           },
#           {
#             "value": "AD_GROUP_STATUS_ENABLED_DETAIL",
#             "count": 89
#           },
#           {
#             "value": "PORTFOLIO_OUT_OF_BUDGET_DETAIL",
#             "count": 47
#           },
#           {
#             "value": "AD_GROUP_INCOMPLETE_DETAIL",
#             "count": 42
#           },
#           {
#             "value": "CAMPAIGN_INCOMPLETE_DETAIL",
#             "count": 39
#           },
#           {
#             "value": "ENDED_DETAIL",
#             "count": 12
#           }
#         ]
#       }
#     },
#     "help_url": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 1279,
#         "non_null_rows": 0,
#         "null_rows": 1279,
#         "distinct_values": 0,
#         "avg_length": null,
#         "min_length": null,
#         "max_length": null,
#         "top_values": []
#       }
#     },
#     "message": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 1279,
#         "non_null_rows": 0,
#         "null_rows": 1279,
#         "distinct_values": 0,
#         "avg_length": null,
#         "min_length": null,
#         "max_length": null,
#         "top_values": []
#       }
#     },
#     "_fivetran_synced": {
#       "data_type": "timestamp with time zone",
#       "udt_name": "timestamptz",
#       "category": "timestamp",
#       "stats": {
#         "total_rows": 1279,
#         "non_null_rows": 1279,
#         "null_rows": 0,
#         "min_value": "2025-09-01 08:16:14.037000+00:00",
#         "max_value": "2025-09-01 08:22:14.201000+00:00",
#         "distinct_values": 553,
#         "top_values": [
#           {
#             "value": "2025-09-01 08:16:15.215000+00:00",
#             "count": 31
#           },
#           {
#             "value": "2025-09-01 08:18:26.845000+00:00",
#             "count": 24
#           },
#           {
#             "value": "2025-09-01 08:17:48.921000+00:00",
#             "count": 16
#           },
#           {
#             "value": "2025-09-01 08:17:21.963000+00:00",
#             "count": 14
#           },
#           {
#             "value": "2025-09-01 08:16:24.755000+00:00",
#             "count": 14
#           },
#           {
#             "value": "2025-09-01 08:17:21.962000+00:00",
#             "count": 13
#           },
#           {
#             "value": "2025-09-01 08:16:14.182000+00:00",
#             "count": 13
#           },
#           {
#             "value": "2025-09-01 08:21:00.385000+00:00",
#             "count": 12
#           },
#           {
#             "value": "2025-09-01 08:17:49.423000+00:00",
#             "count": 11
#           },
#           {
#             "value": "2025-09-01 08:17:03.051000+00:00",
#             "count": 11
#           }
#         ]
#       }
#     }
#   },
#   "amazon_ads_thrive.ad_group_suggested_keyword_view": {
#     "_fivetran_id": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 45326,
#         "non_null_rows": 45326,
#         "null_rows": 0,
#         "distinct_values": 45326,
#         "avg_length": "28.0000000000000000",
#         "min_length": 28,
#         "max_length": 28,
#         "top_values": [
#           {
#             "value": "008tY7r1B9rFb3uFOjM5aN+XIYs=",
#             "count": 1
#           },
#           {
#             "value": "009VHzCurAk97rqdLA1bE86B97w=",
#             "count": 1
#           },
#           {
#             "value": "00Ayp6y3X+mOgglIpP/Sehsoqb8=",
#             "count": 1
#           },
#           {
#             "value": "00bDQxfTDlqC3FKFUeoSFYQm3lY=",
#             "count": 1
#           },
#           {
#             "value": "00O80LbQ7W81OFd0StS9LVkkHK4=",
#             "count": 1
#           },
#           {
#             "value": "00olO2FgFb3+3mwukSlJ/O9QAeU=",
#             "count": 1
#           },
#           {
#             "value": "00QnizPE+mfHdABgInL/StCGhcQ=",
#             "count": 1
#           },
#           {
#             "value": "00rqlLSuUJLbNa06IIkTdDXK1f4=",
#             "count": 1
#           },
#           {
#             "value": "00soeq9FBmcCrj+TyK/seVF0tbs=",
#             "count": 1
#           },
#           {
#             "value": "00456CUF2Qxd//3sZclsxISRwR4=",
#             "count": 1
#           }
#         ]
#       }
#     },
#     "ad_group_id": {
#       "data_type": "bigint",
#       "udt_name": "int8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 45326,
#         "non_null_rows": 45326,
#         "null_rows": 0,
#         "distinct_values": 389,
#         "avg_value": "186763512124879.6972",
#         "min_value": 1388692406214,
#         "max_value": 561221215009697,
#         "stddev": "134085588231046",
#         "p25": 85683966757173.0,
#         "median": 169103535669866.0,
#         "p75": 250742099470956.0
#       }
#     },
#     "campaign_id": {
#       "data_type": "bigint",
#       "udt_name": "int8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 45326,
#         "non_null_rows": 45326,
#         "null_rows": 0,
#         "distinct_values": 266,
#         "avg_value": "197461486813359.1907",
#         "min_value": 214850410764,
#         "max_value": 557927044665653,
#         "stddev": "134659024511380",
#         "p25": 101382915393197.0,
#         "median": 185447573799646.0,
#         "p75": 249828922192343.0
#       }
#     },
#     "keyword_text": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 45326,
#         "non_null_rows": 45326,
#         "null_rows": 0,
#         "distinct_values": 5146,
#         "avg_length": "19.7119975290120461",
#         "min_length": 3,
#         "max_length": 48,
#         "top_values": [
#           {
#             "value": "thrive skin care",
#             "count": 153
#           },
#           {
#             "value": "thrive face wash",
#             "count": 143
#           },
#           {
#             "value": "thrive face",
#             "count": 138
#           },
#           {
#             "value": "thrive skincare",
#             "count": 111
#           },
#           {
#             "value": "thrive causemetics",
#             "count": 109
#           },
#           {
#             "value": "thrive market",
#             "count": 103
#           },
#           {
#             "value": "sky sol sunscreen",
#             "count": 96
#           },
#           {
#             "value": "organic face wash",
#             "count": 95
#           },
#           {
#             "value": "face wash women",
#             "count": 94
#           },
#           {
#             "value": "sky sol",
#             "count": 93
#           }
#         ]
#       }
#     },
#     "match_type": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 45326,
#         "non_null_rows": 45326,
#         "null_rows": 0,
#         "distinct_values": 1,
#         "avg_length": "5.0000000000000000",
#         "min_length": 5,
#         "max_length": 5,
#         "top_values": [
#           {
#             "value": "broad",
#             "count": 45326
#           }
#         ]
#       }
#     },
#     "state": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 45326,
#         "non_null_rows": 45326,
#         "null_rows": 0,
#         "distinct_values": 1,
#         "avg_length": "7.0000000000000000",
#         "min_length": 7,
#         "max_length": 7,
#         "top_values": [
#           {
#             "value": "enabled",
#             "count": 45326
#           }
#         ]
#       }
#     },
#     "_fivetran_deleted": {
#       "data_type": "boolean",
#       "udt_name": "bool",
#       "category": "boolean",
#       "stats": {
#         "total_rows": 45326,
#         "true_count": 7229,
#         "false_count": 38097,
#         "null_count": 0,
#         "distinct_values": 2,
#         "top_values": [
#           {
#             "value": false,
#             "count": 38097
#           },
#           {
#             "value": true,
#             "count": 7229
#           }
#         ]
#       }
#     },
#     "_fivetran_synced": {
#       "data_type": "timestamp with time zone",
#       "udt_name": "timestamptz",
#       "category": "timestamp",
#       "stats": {
#         "total_rows": 45326,
#         "non_null_rows": 45326,
#         "null_rows": 0,
#         "min_value": "2025-08-12 17:33:39.028000+00:00",
#         "max_value": "2025-09-01 08:22:14.607000+00:00",
#         "distinct_values": 19056,
#         "top_values": [
#           {
#             "value": "2025-09-01 08:22:09.839000+00:00",
#             "count": 5
#           },
#           {
#             "value": "2025-09-01 08:17:50.532000+00:00",
#             "count": 5
#           },
#           {
#             "value": "2025-09-01 08:22:10.658000+00:00",
#             "count": 5
#           },
#           {
#             "value": "2025-09-01 08:17:32.578000+00:00",
#             "count": 5
#           },
#           {
#             "value": "2025-09-01 08:18:01.468000+00:00",
#             "count": 5
#           },
#           {
#             "value": "2025-09-01 08:18:38.393000+00:00",
#             "count": 5
#           },
#           {
#             "value": "2025-09-01 08:17:55.803000+00:00",
#             "count": 5
#           },
#           {
#             "value": "2025-09-01 08:17:32.579000+00:00",
#             "count": 5
#           },
#           {
#             "value": "2025-09-01 08:18:31.356000+00:00",
#             "count": 5
#           },
#           {
#             "value": "2025-09-01 08:21:03.436000+00:00",
#             "count": 5
#           }
#         ]
#       }
#     }
#   },
#   "amazon_ads_thrive.advertised_product_report_view": {
#     "ad_group_id": {
#       "data_type": "bigint",
#       "udt_name": "int8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 8112,
#         "non_null_rows": 8112,
#         "null_rows": 0,
#         "distinct_values": 74,
#         "avg_value": "256472088604451.4438",
#         "min_value": 3318832287757,
#         "max_value": 561221215009697,
#         "stddev": "151552233267633",
#         "p25": 125216568653119.0,
#         "median": 259982630562935.0,
#         "p75": 346321319781378.0
#       }
#     },
#     "ad_id": {
#       "data_type": "bigint",
#       "udt_name": "int8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 8112,
#         "non_null_rows": 8112,
#         "null_rows": 0,
#         "distinct_values": 102,
#         "avg_value": "316642711489373.8188",
#         "min_value": 5128252268878,
#         "max_value": 562802904063178,
#         "stddev": "154350167005978",
#         "p25": 226329626013573.0,
#         "median": 325693301898445.0,
#         "p75": 442812118906152.0
#       }
#     },
#     "campaign_id": {
#       "data_type": "bigint",
#       "udt_name": "int8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 8112,
#         "non_null_rows": 8112,
#         "null_rows": 0,
#         "distinct_values": 51,
#         "avg_value": "240911624602577.5399",
#         "min_value": 2507409170642,
#         "max_value": 551556508125724,
#         "stddev": "145951770806578",
#         "p25": 111310887312462.0,
#         "median": 207424676495630.0,
#         "p75": 331402634335171.0
#       }
#     },
#     "date": {
#       "data_type": "date",
#       "udt_name": "date",
#       "category": "date",
#       "stats": {
#         "total_rows": 8112,
#         "non_null_rows": 8112,
#         "null_rows": 0,
#         "min_value": "2025-05-10",
#         "max_value": "2025-08-31",
#         "distinct_values": 114,
#         "top_values": [
#           {
#             "value": "2025-06-01",
#             "count": 97
#           },
#           {
#             "value": "2025-06-11",
#             "count": 88
#           },
#           {
#             "value": "2025-06-06",
#             "count": 88
#           },
#           {
#             "value": "2025-05-31",
#             "count": 88
#           },
#           {
#             "value": "2025-06-02",
#             "count": 87
#           },
#           {
#             "value": "2025-06-17",
#             "count": 87
#           },
#           {
#             "value": "2025-06-13",
#             "count": 87
#           },
#           {
#             "value": "2025-06-12",
#             "count": 87
#           },
#           {
#             "value": "2025-06-22",
#             "count": 87
#           },
#           {
#             "value": "2025-06-07",
#             "count": 87
#           }
#         ]
#       }
#     },
#     "impressions": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 8112,
#         "non_null_rows": 8112,
#         "null_rows": 0,
#         "distinct_values": 3268,
#         "avg_value": "4072.4765779092702170",
#         "min_value": 0,
#         "max_value": 458109,
#         "stddev": "15798.51314880",
#         "p25": 59.0,
#         "median": 392.0,
#         "p75": 1829.5
#       }
#     },
#     "clicks": {
#       "data_type": "integer",
#       "udt_name": "int4",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 8112,
#         "non_null_rows": 8112,
#         "null_rows": 0,
#         "distinct_values": 214,
#         "avg_value": "9.5284763313609467",
#         "min_value": 0,
#         "max_value": 612,
#         "stddev": "31.1293003479251396",
#         "p25": 0.0,
#         "median": 1.0,
#         "p75": 5.0
#       }
#     },
#     "cost_per_click": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 8112,
#         "non_null_rows": 4824,
#         "null_rows": 3288,
#         "distinct_values": 2650,
#         "avg_value": 1.76967342030796,
#         "min_value": 0.02,
#         "max_value": 5.0,
#         "stddev": 0.679672679780102,
#         "p25": 1.31,
#         "median": 1.70816666666667,
#         "p75": 2.16640350877193
#       }
#     },
#     "cost": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 8112,
#         "non_null_rows": 8112,
#         "null_rows": 0,
#         "distinct_values": 2397,
#         "avg_value": 19.0297596153847,
#         "min_value": 0.0,
#         "max_value": 1729.73,
#         "stddev": 70.0705066271149,
#         "p25": 0.0,
#         "median": 1.71,
#         "p75": 8.2525
#       }
#     },
#     "click_through_rate": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 8112,
#         "non_null_rows": 8011,
#         "null_rows": 101,
#         "distinct_values": 3611,
#         "avg_value": 0.89329581965981,
#         "min_value": 0.0,
#         "max_value": 100.0,
#         "stddev": 4.26038229212649,
#         "p25": 0.0,
#         "median": 0.103698582786035,
#         "p75": 0.480384615384615
#       }
#     },
#     "spend": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 8112,
#         "non_null_rows": 8112,
#         "null_rows": 0,
#         "distinct_values": 2584,
#         "avg_value": 19.0297596153847,
#         "min_value": 0.0,
#         "max_value": 1729.73,
#         "stddev": 70.0705066271149,
#         "p25": 0.0,
#         "median": 1.71,
#         "p75": 8.2525
#       }
#     },
#     "campaign_budget_currency_code": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 8112,
#         "non_null_rows": 8112,
#         "null_rows": 0,
#         "distinct_values": 2,
#         "avg_length": "3.0000000000000000",
#         "min_length": 3,
#         "max_length": 3,
#         "top_values": [
#           {
#             "value": "USD",
#             "count": 7192
#           },
#           {
#             "value": "CAD",
#             "count": 920
#           }
#         ]
#       }
#     },
#     "campaign_budget_amount": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 8112,
#         "non_null_rows": 8112,
#         "null_rows": 0,
#         "distinct_values": 16,
#         "avg_value": 541.245685404339,
#         "min_value": 40.0,
#         "max_value": 3000.0,
# ...
#         "non_null_rows": 84017,
#         "null_rows": 0,
#         "distinct_values": 1,
#         "avg_value": 0.0,
#         "min_value": 0.0,
#         "max_value": 0.0,
#         "stddev": 0.0,
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 0.0
#       }
#     },
#     "acos_clicks_7_d": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 84017,
#         "non_null_rows": 2041,
#         "null_rows": 81976,
#         "distinct_values": 1827,
#         "avg_value": 34.7460012045751,
#         "min_value": 0.0,
#         "max_value": 454.440855874041,
#         "stddev": 33.4622986353411,
#         "p25": 13.9275766016713,
#         "median": 26.2544056392182,
#         "p75": 44.1051835035944
#       }
#     },
#     "acos_clicks_14_d": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 84017,
#         "non_null_rows": 2073,
#         "null_rows": 81944,
#         "distinct_values": 1854,
#         "avg_value": 34.0567227110874,
#         "min_value": 0.0,
#         "max_value": 454.440855874041,
#         "stddev": 33.5249866195652,
#         "p25": 13.9275766016713,
#         "median": 25.8686557624706,
#         "p75": 43.4879406307978
#       }
#     },
#     "roas_clicks_7_d": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 84017,
#         "non_null_rows": 6123,
#         "null_rows": 77894,
#         "distinct_values": 1829,
#         "avg_value": 2.50689006419959,
#         "min_value": 0.0,
#         "max_value": 789.0,
#         "stddev": 13.6632006856603,
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 2.2566850401721
#       }
#     },
#     "roas_clicks_14_d": {
#       "data_type": "double precision",
#       "udt_name": "float8",
#       "category": "numeric",
#       "stats": {
#         "total_rows": 84017,
#         "non_null_rows": 6123,
#         "null_rows": 77894,
#         "distinct_values": 1856,
#         "avg_value": 2.58696531055071,
#         "min_value": 0.0,
#         "max_value": 789.0,
#         "stddev": 13.7182706838804,
#         "p25": 0.0,
#         "median": 0.0,
#         "p75": 2.34793534233772
#       }
#     },
#     "_fivetran_synced": {
#       "data_type": "timestamp with time zone",
#       "udt_name": "timestamptz",
#       "category": "timestamp",
#       "stats": {
#         "total_rows": 84017,
#         "non_null_rows": 84017,
#         "null_rows": 0,
#         "min_value": "2025-08-14 09:39:24.593000+00:00",
#         "max_value": "2025-09-01 21:07:55.856000+00:00",
#         "distinct_values": 2955,
#         "top_values": [
#           {
#             "value": "2025-08-19 18:13:05.067000+00:00",
#             "count": 92
#           },
#           {
#             "value": "2025-08-19 17:39:20.889000+00:00",
#             "count": 91
#           },
#           {
#             "value": "2025-08-19 18:13:05.077000+00:00",
#             "count": 90
#           },
#           {
#             "value": "2025-08-19 18:11:53.890000+00:00",
#             "count": 90
#           },
#           {
#             "value": "2025-08-19 18:11:53.889000+00:00",
#             "count": 90
#           },
#           {
#             "value": "2025-08-19 18:11:53.888000+00:00",
#             "count": 89
#           },
#           {
#             "value": "2025-08-19 17:22:49.605000+00:00",
#             "count": 89
#           },
#           {
#             "value": "2025-08-19 17:22:49.606000+00:00",
#             "count": 89
#           },
#           {
#             "value": "2025-08-19 17:39:20.887000+00:00",
#             "count": 89
#           },
#           {
#             "value": "2025-08-19 17:46:15.839000+00:00",
#             "count": 89
#           }
#         ]
#       }
#     }
#   },
#   "amazon_ads_thrive.targeting_resolved_expression_view": {
#     "_fivetran_id": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 6500,
#         "non_null_rows": 6500,
#         "null_rows": 0,
#         "distinct_values": 6500,
#         "avg_length": "28.0000000000000000",
#         "min_length": 28,
#         "max_length": 28,
#         "top_values": [
#           {
#             "value": "+00PQxXSFuXggIZGxd/HuYpAzcw=",
#             "count": 1
#           },
#           {
#             "value": "01SwEp/3aC/5Eu2FONLb02at8mI=",
#             "count": 1
#           },
#           {
#             "value": "0276Mvqur8N7tH7EiOQW57gX8Qw=",
#             "count": 1
#           },
#           {
#             "value": "02qz8lycs9nZsZUQ2erts6UkfKo=",
#             "count": 1
#           },
#           {
#             "value": "040A745LLxT4a7dv2BbX/lRgQTw=",
#             "count": 1
#           },
#           {
#             "value": "049ebGc1e0lIMQoEggQua7Ws5ac=",
#             "count": 1
#           },
#           {
#             "value": "04L7B4bBNCkEcmavbKy4+bsRvmM=",
#             "count": 1
#           },
#           {
#             "value": "04oZipqGe0sq2NuKxoqTYvRVf4A=",
#             "count": 1
#           },
#           {
#             "value": "0/668uGcJ4wthbj1ukZl/hJZ+r0=",
#             "count": 1
#           },
#           {
#             "value": "0015I/94kN5/zZFzSmu8b8MF2EA=",
#             "count": 1
#           }
#         ]
#       }
#     },
#     "target_id": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 6500,
#         "non_null_rows": 6500,
#         "null_rows": 0,
#         "distinct_values": 6347,
#         "avg_length": "14.8167692307692308",
#         "min_length": 11,
#         "max_length": 15,
#         "top_values": [
#           {
#             "value": "374790104137037",
#             "count": 3
#           },
#           {
#             "value": "245258781853909",
#             "count": 3
#           },
#           {
#             "value": "137009018595039",
#             "count": 3
#           },
#           {
#             "value": "230982411889509",
#             "count": 3
#           },
#           {
#             "value": "13959157277800",
#             "count": 3
#           },
#           {
#             "value": "527593499523872",
#             "count": 3
#           },
#           {
#             "value": "111149332951820",
#             "count": 3
#           },
#           {
#             "value": "206858709741084",
#             "count": 3
#           },
#           {
#             "value": "523020208180085",
#             "count": 3
#           },
#           {
#             "value": "158770980611784",
#             "count": 3
#           }
#         ]
#       }
#     },
#     "value": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 6500,
#         "non_null_rows": 6048,
#         "null_rows": 452,
#         "distinct_values": 2713,
#         "avg_length": "10.4684193121693122",
#         "min_length": 1,
#         "max_length": 49,
#         "top_values": [
#           {
#             "value": "B00PJB95X8",
#             "count": 59
#           },
#           {
#             "value": "B00VVS2PTO",
#             "count": 57
#           },
#           {
#             "value": "B00IFCAWS0",
#             "count": 55
#           },
#           {
#             "value": "B07BR8CWFK",
#             "count": 50
#           },
#           {
#             "value": "B07BRCT9FS",
#             "count": 49
#           },
#           {
#             "value": "B06ZYZ696H",
#             "count": 48
#           },
#           {
#             "value": "B07L7KTVMW",
#             "count": 48
#           },
#           {
#             "value": "B07WH82DZ7",
#             "count": 47
#           },
#           {
#             "value": "B06ZZK3VX3",
#             "count": 46
#           },
#           {
#             "value": "B07CXP2YB4",
#             "count": 43
#           }
#         ]
#       }
#     },
#     "type": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 6500,
#         "non_null_rows": 6500,
#         "null_rows": 0,
#         "distinct_values": 13,
#         "avg_length": "14.9003076923076923",
#         "min_length": 12,
#         "max_length": 28,
#         "top_values": [
#           {
#             "value": "ASIN_SAME_AS",
#             "count": 3986
#           },
#           {
#             "value": "ASIN_EXPANDED_FROM",
#             "count": 1560
#           },
#           {
#             "value": "ASIN_CATEGORY_SAME_AS",
#             "count": 348
#           },
#           {
#             "value": "ASIN_ACCESSORY_RELATED",
#             "count": 113
#           },
#           {
#             "value": "QUERY_BROAD_REL_MATCHES",
#             "count": 113
#           },
#           {
#             "value": "QUERY_HIGH_REL_MATCHES",
#             "count": 113
#           },
#           {
#             "value": "ASIN_SUBSTITUTE_RELATED",
#             "count": 113
#           },
#           {
#             "value": "ASIN_BRAND_SAME_AS",
#             "count": 36
#           },
#           {
#             "value": "ASIN_REVIEW_RATING_LESS_THAN",
#             "count": 33
#           },
#           {
#             "value": "ASIN_PRICE_BETWEEN",
#             "count": 29
#           }
#         ]
#       }
#     },
#     "_fivetran_deleted": {
#       "data_type": "boolean",
#       "udt_name": "bool",
#       "category": "boolean",
#       "stats": {
#         "total_rows": 6500,
#         "true_count": 1,
#         "false_count": 6499,
#         "null_count": 0,
#         "distinct_values": 2,
#         "top_values": [
#           {
#             "value": false,
#             "count": 6499
#           },
#           {
#             "value": true,
#             "count": 1
#           }
#         ]
#       }
#     },
#     "_fivetran_synced": {
#       "data_type": "timestamp with time zone",
#       "udt_name": "timestamptz",
#       "category": "timestamp",
#       "stats": {
#         "total_rows": 6500,
#         "non_null_rows": 6500,
#         "null_rows": 0,
#         "min_value": "2025-08-26 08:24:04.399000+00:00",
#         "max_value": "2025-09-01 08:22:49.438000+00:00",
#         "distinct_values": 4758,
#         "top_values": [
#           {
#             "value": "2025-09-01 08:20:56.299000+00:00",
#             "count": 3
#           },
#           {
#             "value": "2025-09-01 08:22:49.076000+00:00",
#             "count": 3
#           },
#           {
#             "value": "2025-09-01 08:20:56.339000+00:00",
#             "count": 3
#           },
#           {
#             "value": "2025-09-01 08:20:54.830000+00:00",
#             "count": 3
#           },
#           {
#             "value": "2025-09-01 08:20:53.141000+00:00",
#             "count": 3
#           },
#           {
#             "value": "2025-09-01 08:20:56.354000+00:00",
#             "count": 3
#           },
#           {
#             "value": "2025-09-01 08:20:53.473000+00:00",
#             "count": 3
#           },
#           {
#             "value": "2025-09-01 08:20:54.845000+00:00",
#             "count": 3
#           },
#           {
#             "value": "2025-09-01 08:20:54.644000+00:00",
#             "count": 3
#           },
#           {
#             "value": "2025-09-01 08:22:49.055000+00:00",
#             "count": 3
#           }
#         ]
#       }
#     }
#   },
#   "amazon_ads_thrive.targeting_serving_status_detail_view": {
#     "target_id": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 10434,
#         "non_null_rows": 10434,
#         "null_rows": 0,
#         "distinct_values": 6347,
#         "avg_length": "14.7499520797393138",
#         "min_length": 11,
#         "max_length": 15,
#         "top_values": [
#           {
#             "value": "489456376372",
#             "count": 6
#           },
#           {
#             "value": "33194718653349",
#             "count": 6
#           },
#           {
#             "value": "245277098092220",
#             "count": 6
#           },
#           {
#             "value": "154154808332998",
#             "count": 6
#           },
#           {
#             "value": "119250367295543",
#             "count": 5
#           },
#           {
#             "value": "141259322859804",
#             "count": 5
#           },
#           {
#             "value": "76109236549796",
#             "count": 5
#           },
#           {
#             "value": "11176371838890",
#             "count": 5
#           },
#           {
#             "value": "111149332951820",
#             "count": 5
#           },
#           {
#             "value": "270248284384751",
#             "count": 5
#           }
#         ]
#       }
#     },
#     "name": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 10434,
#         "non_null_rows": 10434,
#         "null_rows": 0,
#         "distinct_values": 11,
#         "avg_length": "28.0813686026451984",
#         "min_length": 22,
#         "max_length": 35,
#         "top_values": [
#           {
#             "value": "TARGETING_CLAUSE_PAUSED_DETAIL",
#             "count": 3512
#           },
#           {
#             "value": "TARGETING_CLAUSE_STATUS_LIVE_DETAIL",
#             "count": 1941
#           },
#           {
#             "value": "CAMPAIGN_PAUSED_DETAIL",
#             "count": 1705
#           },
#           {
#             "value": "AD_GROUP_PAUSED_DETAIL",
#             "count": 1020
#           },
#           {
#             "value": "PORTFOLIO_ENDED_DETAIL",
#             "count": 547
#           },
#           {
#             "value": "PORTFOLIO_OUT_OF_BUDGET_DETAIL",
#             "count": 531
#           },
#           {
#             "value": "TARGETING_CLAUSE_ARCHIVED_DETAIL",
#             "count": 436
#           },
#           {
#             "value": "AD_GROUP_ARCHIVED_DETAIL",
#             "count": 369
#           },
#           {
#             "value": "CAMPAIGN_ARCHIVED_DETAIL",
#             "count": 357
#           },
#           {
#             "value": "CAMPAIGN_INCOMPLETE_DETAIL",
#             "count": 8
#           }
#         ]
#       }
#     },
#     "help_url": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 10434,
#         "non_null_rows": 0,
#         "null_rows": 10434,
#         "distinct_values": 0,
#         "avg_length": null,
#         "min_length": null,
#         "max_length": null,
#         "top_values": []
#       }
#     },
#     "message": {
#       "data_type": "character varying",
#       "udt_name": "varchar",
#       "category": "text",
#       "stats": {
#         "total_rows": 10434,
#         "non_null_rows": 0,
#         "null_rows": 10434,
#         "distinct_values": 0,
#         "avg_length": null,
#         "min_length": null,
#         "max_length": null,
#         "top_values": []
#       }
#     },
#     "_fivetran_synced": {
#       "data_type": "timestamp with time zone",
#       "udt_name": "timestamptz",
#       "category": "timestamp",
#       "stats": {
#         "total_rows": 10434,
#         "non_null_rows": 10434,
#         "null_rows": 0,
#         "min_value": "2025-09-01 08:20:53.073000+00:00",
#         "max_value": "2025-09-01 08:22:49.438000+00:00",
#         "distinct_values": 4723,
#         "top_values": [
#           {
#             "value": "2025-09-01 08:20:55.951000+00:00",
#             "count": 12
#           },
#           {
#             "value": "2025-09-01 08:20:53.384000+00:00",
#             "count": 10
#           },
#           {
#             "value": "2025-09-01 08:20:53.393000+00:00",
#             "count": 10
#           },
#           {
#             "value": "2025-09-01 08:20:55.365000+00:00",
#             "count": 10
#           },
#           {
#             "value": "2025-09-01 08:20:53.090000+00:00",
#             "count": 10
#           },
#           {
#             "value": "2025-09-01 08:20:53.397000+00:00",
#             "count": 10
#           },
#           {
#             "value": "2025-09-01 08:20:53.370000+00:00",
#             "count": 10
#           },
#           {
#             "value": "2025-09-01 08:20:53.415000+00:00",
#             "count": 10
#           },
#           {
#             "value": "2025-09-01 08:20:53.446000+00:00",
#             "count": 10
#           },
#           {
#             "value": "2025-09-01 08:20:53.375000+00:00",
#             "count": 10
#           }
#         ]
#       }
#     }
#   }
# }

# %%
import json
import os
from datetime import datetime

# Create output directory if it doesn't exist
output_dir = "../data/schema_stats"
os.makedirs(output_dir, exist_ok=True)

# Generate filename with timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

for schema in schemas:
    output_file = os.path.join(output_dir, f"{schema}_stats_{timestamp}.json")
    
    # Write statistics to file
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(stats, f, default=str, indent=2)
    
    print(f"Statistics written to: {output_file}")
# Out:
# Statistics written to: ../data/schema_stats\amazon_ads_thrive_stats_20250901_223956.json

# %%
from openai import OpenAI

def generate_column_descriptions(table_name: str, stats_text: str) -> Dict[str, str]:
    # Create the prompt for OpenAI
    prompt = f"""
        You are given metadata and descriptive statistics for every column in a Postgres table named "{table_name}", which contains Amazon e-commerce data.

        Your task is to generate a clear, semantically rich description for each column. 
        The purpose of these descriptions is to improve the accuracy of a text-to-SQL agent that will use them to translate natural language questions into SQL queries.

        Guidelines for writing descriptions:
        - Expand any abbreviations or acronyms into full words.
        - Clarify the real-world meaning of the column (e.g., 'asin' → 'Amazon Standard Identification Number, a unique product identifier').
        - Add hints about typical usage in queries (e.g., whether it’s useful for filtering, grouping, or joining).
        - Use the descriptive statistics and sample values provided below to infer semantic meaning 
        (e.g., categorical vs numeric, date fields, booleans, common text patterns).
        - Include representative example values from the column in the description to illustrate its contents.
        - Keep descriptions concise but informative, written in plain English.
        - Emphasize the Amazon e-commerce context (products, sellers, reviews, orders, customers, prices, etc.).

        Descriptive statistics and examples:
        {stats_text}

        Output format (JSON dictionary):
        {{
            "column_name": "description of the column, including semantic meaning, how it may be used in SQL queries, and 1–3 representative example values",
            "column_name2": "description of the column2, including semantic meaning, how it may be used in SQL queries, and 1–3 representative example values",
            ...
        }}
    """

    # Initialize OpenAI client
    client = OpenAI()

    # Call OpenAI API
    response = client.chat.completions.create(
        model="gpt-5",
        messages=[
            {
                "role": "system",
                "content": prompt,
            },
        ],
        reasoning_effort="high",
    )

    # Return the generated markdown
    return response.choices[0].message.content

# %%
views = list(stats.keys())
views
# Out:
# ['amazon_ads_thrive.ad_group_history_view',
#  'amazon_ads_thrive.ad_group_level_report_view',
#  'amazon_ads_thrive.ad_group_serving_status_detail_view',
#  'amazon_ads_thrive.ad_group_suggested_keyword_view',
#  'amazon_ads_thrive.advertised_product_report_view',
#  'amazon_ads_thrive.asin_bid_recommendation_value_view',
#  'amazon_ads_thrive.asin_suggested_keyword_view',
#  'amazon_ads_thrive.asin_theme_based_bid_recommendation_view',
#  'amazon_ads_thrive.campaign_history_view',
#  'amazon_ads_thrive.campaign_level_report_view',
#  'amazon_ads_thrive.campaign_negative_keyword_history_view',
#  'amazon_ads_thrive.campaign_negative_keyword_serving_status_detail_view',
#  'amazon_ads_thrive.campaign_placement_bidding_view',
#  'amazon_ads_thrive.campaign_placement_report_view',
#  'amazon_ads_thrive.campaign_serving_status_detail_view',
#  'amazon_ads_thrive.keyword_history_view',
#  'amazon_ads_thrive.keyword_serving_status_detail_view',
#  'amazon_ads_thrive.negative_keyword_history_view',
#  'amazon_ads_thrive.negative_keyword_serving_status_detail_view',
#  'amazon_ads_thrive.negative_targeting_clause_history_view',
#  'amazon_ads_thrive.negative_targeting_expression_view',
#  'amazon_ads_thrive.negative_targeting_resolved_expression_view',
#  'amazon_ads_thrive.negative_targeting_serving_status_detail_view',
#  'amazon_ads_thrive.portfolio_history_view',
#  'amazon_ads_thrive.product_ad_history_view',
#  'amazon_ads_thrive.product_ad_serving_status_detail_view',
#  'amazon_ads_thrive.profile_view',
#  'amazon_ads_thrive.purchased_product_keyword_report_view',
#  'amazon_ads_thrive.purchased_product_targeting_report_view',
#  'amazon_ads_thrive.sb_ad_group_history_view',
#  'amazon_ads_thrive.sb_ad_group_report_view',
#  'amazon_ads_thrive.sb_ad_history_view',
#  'amazon_ads_thrive.sb_ad_report_view',
#  'amazon_ads_thrive.sb_ad_sub_page_view',
#  'amazon_ads_thrive.sb_benchmark_brand_and_category_view',
#  'amazon_ads_thrive.sb_brand_view',
#  'amazon_ads_thrive.sb_budget_recommendation_view',
#  'amazon_ads_thrive.sb_budget_rule_recommendation_view',
#  'amazon_ads_thrive.sb_budget_usage_history_view',
#  'amazon_ads_thrive.sb_campaign_bid_adjustments_by_placement_view',
#  'amazon_ads_thrive.sb_campaign_history_view',
#  'amazon_ads_thrive.sb_campaign_moderation_view',
#  'amazon_ads_thrive.sb_campaign_report_view',
#  'amazon_ads_thrive.sb_creative_asin_view',
#  'amazon_ads_thrive.sb_creative_custom_image_view',
#  'amazon_ads_thrive.sb_creative_history_view',
#  'amazon_ads_thrive.sb_creative_original_video_asset_view',
#  'amazon_ads_thrive.sb_creative_video_asset_view',
#  'amazon_ads_thrive.sb_keyword_report_view',
#  'amazon_ads_thrive.sb_keyword_view',
#  'amazon_ads_thrive.sb_negative_keyword_view',
#  'amazon_ads_thrive.sb_placement_report_view',
#  'amazon_ads_thrive.sb_product_target_expression_view',
#  'amazon_ads_thrive.sb_product_target_resolved_expression_view',
#  'amazon_ads_thrive.sb_product_target_view',
#  'amazon_ads_thrive.sb_product_targeting_category_view',
#  'amazon_ads_thrive.sb_purchased_product_view',
#  'amazon_ads_thrive.sb_search_term_report_view',
#  'amazon_ads_thrive.sb_store_asset_view',
#  'amazon_ads_thrive.sb_store_page_info_view',
#  'amazon_ads_thrive.sb_store_view',
#  'amazon_ads_thrive.sb_target_report_view',
#  'amazon_ads_thrive.sb_targeting_recommendation_brand_category_view',
#  'amazon_ads_thrive.sb_targeting_recommendation_category_view',
#  'amazon_ads_thrive.sb_targeting_recommendation_product_view',
#  'amazon_ads_thrive.sd_ad_group_history_view',
#  'amazon_ads_thrive.sd_ad_group_report_view',
#  'amazon_ads_thrive.sd_bid_recommendation_view',
#  'amazon_ads_thrive.sd_budget_usage_history_view',
#  'amazon_ads_thrive.sd_campaign_history_view',
#  'amazon_ads_thrive.sd_campaign_report_view',
#  'amazon_ads_thrive.sd_creative_moderation_view',
#  'amazon_ads_thrive.sd_creative_view',
#  'amazon_ads_thrive.sd_matched_target_report_view',
#  'amazon_ads_thrive.sd_product_ad_history_view',
#  'amazon_ads_thrive.sd_product_ad_report_view',
#  'amazon_ads_thrive.sd_purchased_products_reports_view',
#  'amazon_ads_thrive.sd_target_report_view',
#  'amazon_ads_thrive.sd_targeting_expression_view',
#  'amazon_ads_thrive.sd_targeting_history_view',
#  'amazon_ads_thrive.sd_targeting_recommendation_audience_view',
#  'amazon_ads_thrive.sd_targeting_recommendation_category_view',
#  'amazon_ads_thrive.sd_targeting_recommendation_product_view',
#  'amazon_ads_thrive.sd_targeting_resolved_expression_view',
#  'amazon_ads_thrive.search_term_ad_keyword_report_view',
#  'amazon_ads_thrive.search_term_targeting_report_view',
#  'amazon_ads_thrive.targeting_clause_history_view',
#  'amazon_ads_thrive.targeting_expression_view',
#  'amazon_ads_thrive.targeting_keyword_report_view',
#  'amazon_ads_thrive.targeting_report_view',
#  'amazon_ads_thrive.targeting_resolved_expression_view',
#  'amazon_ads_thrive.targeting_serving_status_detail_view']

# %%
# Column Description Generator
import json
import time
from datetime import datetime
import asyncio
from concurrent.futures import ThreadPoolExecutor
import threading

def generate_descriptions_for_table(table_name, table_stats):
    """Generate descriptions for a single table."""
    try:
        # Format statistics into a readable string
        stats_text = f"Table: {table_name}\n"
        stats_text += "="*50 + "\n"
        
        for column_name, column_info in table_stats.items():
            stats_text += f"\nColumn: {column_name}\n"
            stats_text += f"Data Type: {column_info['data_type']}\n"
            stats_text += f"Category: {column_info['category']}\n"
            stats_text += "Statistics:\n"
            
            # Format the statistics nicely
            column_stats = column_info['stats']
            for stat_name, stat_value in column_stats.items():
                if stat_name == 'top_values' and isinstance(stat_value, list):
                    stats_text += f"  {stat_name}:\n"
                    for value_info in stat_value[:5]:  # Show top 5 values
                        stats_text += f"    '{value_info['value']}': {value_info['count']} occurrences\n"
                else:
                    stats_text += f"  {stat_name}: {stat_value}\n"
            stats_text += "-" * 30 + "\n"
        
        # Generate descriptions using the formatted stats
        descriptions = generate_column_descriptions(table_name, stats_text)

        # Convert descriptions to JSON if it's not already a dict
        if isinstance(descriptions, str):
            descriptions = json.loads(descriptions)

        return table_name, descriptions, None
        
    except Exception as e:
        return table_name, None, str(e)

def process_tables_parallel(tables_to_process, stats_dict, descriptions_dict=None, max_workers=5):
    """Process multiple tables in parallel using ThreadPoolExecutor."""
    if descriptions_dict is None:
        descriptions_dict = {}
    
    # Filter out tables that already have descriptions
    tables_to_process_filtered = [
        table for table in tables_to_process 
        if table not in descriptions_dict
    ]
    
    skipped_tables = len(tables_to_process) - len(tables_to_process_filtered)
    
    successful_updates = 0
    failed_updates = 0
    
    print(f"{'='*60}")
    print(f"Column Description Generation Started (Parallel)")
    print(f"{'='*60}")
    print(f"Total tables requested: {len(tables_to_process)}")
    print(f"Tables already processed (skipped): {skipped_tables}")
    print(f"Tables to process: {len(tables_to_process_filtered)}")
    print(f"Max workers: {max_workers}")
    print(f"Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{'='*60}")
    
    if skipped_tables > 0:
        print(f"ℹ️ Skipping {skipped_tables} tables that already have descriptions")
    
    if not tables_to_process_filtered:
        print("ℹ️ No new tables to process - all tables already have descriptions")
        return descriptions_dict
    
    start_time = time.time()
    
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit all tasks
        future_to_table = {
            executor.submit(generate_descriptions_for_table, table_name, stats_dict[table_name]): table_name
            for table_name in tables_to_process_filtered
        }
        
        # Process completed tasks
        for i, future in enumerate(future_to_table, 1):
            table_name = future_to_table[future]
            try:
                table_name_result, descriptions, error = future.result()
                
                if error:
                    failed_updates += 1
                    print(f"[{i}/{len(tables_to_process_filtered)}] ❌ Error processing {table_name}: {error}")
                else:
                    descriptions_dict[table_name_result] = descriptions
                    successful_updates += 1
                    print(f"[{i}/{len(tables_to_process_filtered)}] ✅ Successfully processed {table_name} - {len(descriptions)} columns")
                    
            except Exception as e:
                failed_updates += 1
                print(f"[{i}/{len(tables_to_process_filtered)}] ❌ Unexpected error processing {table_name}: {str(e)}")
    
    # Final statistics
    total_elapsed = time.time() - start_time
    print(f"\n{'='*60}")
    print(f"Column Description Generation Summary:")
    print(f"{'='*60}")
    print(f"Total tables requested: {len(tables_to_process)}")
    print(f"Tables skipped (already processed): {skipped_tables}")
    print(f"Tables processed in this run: {len(tables_to_process_filtered)}")
    print(f"Successful generations: {successful_updates}")
    print(f"Failed generations: {failed_updates}")
    if tables_to_process_filtered:
        print(f"Success rate: {(successful_updates/len(tables_to_process_filtered)*100):.1f}%")
        print(f"Total elapsed time: {total_elapsed:.2f}s")
        print(f"Average time per table: {(total_elapsed/len(tables_to_process_filtered)):.2f}s")
    print(f"Total tables in descriptions_dict: {len(descriptions_dict)}")
    print(f"Completed at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    
    return descriptions_dict

# Process tables in parallel (limit to first table for testing)
tables_to_process = views  # Remove [:1] to process all tables
descriptions_dict = process_tables_parallel(tables_to_process, stats, descriptions_dict, max_workers=4)
# Out:
# ============================================================
# Column Description Generation Started (Parallel)
# ============================================================
# Total tables requested: 92
# Tables already processed (skipped): 20
# Tables to process: 72
# Max workers: 4
# Started at: 2025-09-01 23:16:11
# ============================================================
# ℹ️ Skipping 20 tables that already have descriptions
# [1/72] ✅ Successfully processed amazon_ads_thrive.negative_targeting_expression_view - 6 columns
# [2/72] ✅ Successfully processed amazon_ads_thrive.negative_targeting_resolved_expression_view - 6 columns
# [3/72] ✅ Successfully processed amazon_ads_thrive.negative_targeting_serving_status_detail_view - 5 columns
# [4/72] ✅ Successfully processed amazon_ads_thrive.portfolio_history_view - 14 columns
# [5/72] ✅ Successfully processed amazon_ads_thrive.product_ad_history_view - 11 columns
# [6/72] ✅ Successfully processed amazon_ads_thrive.product_ad_serving_status_detail_view - 5 columns
# [7/72] ✅ Successfully processed amazon_ads_thrive.profile_view - 13 columns
# [8/72] ✅ Successfully processed amazon_ads_thrive.purchased_product_keyword_report_view - 39 columns
# [9/72] ✅ Successfully processed amazon_ads_thrive.purchased_product_targeting_report_view - 39 columns
# [10/72] ✅ Successfully processed amazon_ads_thrive.sb_ad_group_history_view - 8 columns
# [11/72] ✅ Successfully processed amazon_ads_thrive.sb_ad_group_report_view - 33 columns
# [12/72] ✅ Successfully processed amazon_ads_thrive.sb_ad_history_view - 12 columns
# [13/72] ✅ Successfully processed amazon_ads_thrive.sb_ad_report_view - 36 columns
# [14/72] ✅ Successfully processed amazon_ads_thrive.sb_ad_sub_page_view - 5 columns
# [15/72] ✅ Successfully processed amazon_ads_thrive.sb_benchmark_brand_and_category_view - 21 columns
# [16/72] ✅ Successfully processed amazon_ads_thrive.sb_brand_view - 6 columns
# [17/72] ✅ Successfully processed amazon_ads_thrive.sb_budget_recommendation_view - 12 columns
# [18/72] ✅ Successfully processed amazon_ads_thrive.sb_budget_rule_recommendation_view - 8 columns
# [19/72] ✅ Successfully processed amazon_ads_thrive.sb_budget_usage_history_view - 5 columns
# [20/72] ✅ Successfully processed amazon_ads_thrive.sb_campaign_bid_adjustments_by_placement_view - 4 columns
# [21/72] ✅ Successfully processed amazon_ads_thrive.sb_campaign_history_view - 25 columns
# [22/72] ✅ Successfully processed amazon_ads_thrive.sb_campaign_moderation_view - 5 columns
# [23/72] ✅ Successfully processed amazon_ads_thrive.sb_campaign_report_view - 34 columns
# [24/72] ✅ Successfully processed amazon_ads_thrive.sb_creative_asin_view - 3 columns
# [25/72] ✅ Successfully processed amazon_ads_thrive.sb_creative_custom_image_view - 8 columns
# [26/72] ✅ Successfully processed amazon_ads_thrive.sb_creative_history_view - 27 columns
# [27/72] ✅ Successfully processed amazon_ads_thrive.sb_creative_original_video_asset_view - 3 columns
# [28/72] ✅ Successfully processed amazon_ads_thrive.sb_creative_video_asset_view - 3 columns
# [29/72] ✅ Successfully processed amazon_ads_thrive.sb_keyword_report_view - 38 columns
# [30/72] ✅ Successfully processed amazon_ads_thrive.sb_keyword_view - 10 columns
# [31/72] ✅ Successfully processed amazon_ads_thrive.sb_negative_keyword_view - 8 columns
# [32/72] ✅ Successfully processed amazon_ads_thrive.sb_placement_report_view - 34 columns
# [33/72] ✅ Successfully processed amazon_ads_thrive.sb_product_target_expression_view - 4 columns
# [34/72] ✅ Successfully processed amazon_ads_thrive.sb_product_target_resolved_expression_view - 4 columns
# [35/72] ✅ Successfully processed amazon_ads_thrive.sb_product_target_view - 7 columns
# [36/72] ✅ Successfully processed amazon_ads_thrive.sb_product_targeting_category_view - 12 columns
# [37/72] ✅ Successfully processed amazon_ads_thrive.sb_purchased_product_view - 19 columns
# [38/72] ✅ Successfully processed amazon_ads_thrive.sb_search_term_report_view - 24 columns
# [39/72] ✅ Successfully processed amazon_ads_thrive.sb_store_asset_view - 9 columns
# [40/72] ✅ Successfully processed amazon_ads_thrive.sb_store_page_info_view - 5 columns
# [41/72] ✅ Successfully processed amazon_ads_thrive.sb_store_view - 5 columns
# [42/72] ✅ Successfully processed amazon_ads_thrive.sb_target_report_view - 38 columns
# [43/72] ✅ Successfully processed amazon_ads_thrive.sb_targeting_recommendation_brand_category_view - 5 columns
# [44/72] ✅ Successfully processed amazon_ads_thrive.sb_targeting_recommendation_category_view - 11 columns
# [45/72] ✅ Successfully processed amazon_ads_thrive.sb_targeting_recommendation_product_view - 4 columns
# [46/72] ✅ Successfully processed amazon_ads_thrive.sd_ad_group_history_view - 12 columns
# [47/72] ✅ Successfully processed amazon_ads_thrive.sd_ad_group_report_view - 62 columns
# [48/72] ✅ Successfully processed amazon_ads_thrive.sd_bid_recommendation_view - 8 columns
# [49/72] ✅ Successfully processed amazon_ads_thrive.sd_budget_usage_history_view - 5 columns
# [50/72] ✅ Successfully processed amazon_ads_thrive.sd_campaign_history_view - 15 columns
# [51/72] ✅ Successfully processed amazon_ads_thrive.sd_campaign_report_view - 62 columns
# [52/72] ✅ Successfully processed amazon_ads_thrive.sd_creative_moderation_view - 5 columns
# [53/72] ✅ Successfully processed amazon_ads_thrive.sd_creative_view - 26 columns
# [54/72] ✅ Successfully processed amazon_ads_thrive.sd_matched_target_report_view - 58 columns
# [55/72] ✅ Successfully processed amazon_ads_thrive.sd_product_ad_history_view - 13 columns
# [56/72] ✅ Successfully processed amazon_ads_thrive.sd_product_ad_report_view - 63 columns
# [57/72] ✅ Successfully processed amazon_ads_thrive.sd_purchased_products_reports_view - 23 columns
# [58/72] ✅ Successfully processed amazon_ads_thrive.sd_target_report_view - 63 columns
# [59/72] ✅ Successfully processed amazon_ads_thrive.sd_targeting_expression_view - 6 columns
# [60/72] ✅ Successfully processed amazon_ads_thrive.sd_targeting_history_view - 8 columns
# [61/72] ✅ Successfully processed amazon_ads_thrive.sd_targeting_recommendation_audience_view - 6 columns
# [62/72] ✅ Successfully processed amazon_ads_thrive.sd_targeting_recommendation_category_view - 9 columns
# [63/72] ✅ Successfully processed amazon_ads_thrive.sd_targeting_recommendation_product_view - 4 columns
# [64/72] ✅ Successfully processed amazon_ads_thrive.sd_targeting_resolved_expression_view - 6 columns
# [65/72] ✅ Successfully processed amazon_ads_thrive.search_term_ad_keyword_report_view - 52 columns
# [66/72] ✅ Successfully processed amazon_ads_thrive.search_term_targeting_report_view - 52 columns
# [67/72] ✅ Successfully processed amazon_ads_thrive.targeting_clause_history_view - 10 columns
# [68/72] ✅ Successfully processed amazon_ads_thrive.targeting_expression_view - 6 columns
# [69/72] ✅ Successfully processed amazon_ads_thrive.targeting_keyword_report_view - 54 columns
# [70/72] ✅ Successfully processed amazon_ads_thrive.targeting_report_view - 54 columns
# [71/72] ✅ Successfully processed amazon_ads_thrive.targeting_resolved_expression_view - 6 columns
# [72/72] ✅ Successfully processed amazon_ads_thrive.targeting_serving_status_detail_view - 5 columns
#
# ============================================================
# Column Description Generation Summary:
# ============================================================
# Total tables requested: 92
# Tables skipped (already processed): 20
# Tables processed in this run: 72
# Successful generations: 72
# Failed generations: 0
# Success rate: 100.0%
# Total elapsed time: 1568.00s
# Average time per table: 21.78s
# Total tables in descriptions_dict: 92
# Completed at: 2025-09-01 23:42:19

# %%
len(descriptions_dict.keys())
# Out:
# 92

# %%
# Save descriptions to file
import os
import json
from datetime import datetime

def save_descriptions_to_file(descriptions_dict, filename="table_descriptions.json"):
    """Save table descriptions to a JSON file, updating existing descriptions without deleting others."""
    
    # Check if file exists and load existing descriptions
    existing_descriptions = {}
    if os.path.exists(filename):
        try:
            with open(filename, 'r', encoding='utf-8') as f:
                existing_descriptions = json.load(f)
            print(f"  ✓ Loaded existing descriptions from {filename}")
        except Exception as e:
            print(f"  ⚠️ Could not load existing file {filename}: {str(e)}")
            print(f"  ℹ️ Will create new file")
    
    # Update existing descriptions with new ones
    existing_descriptions.update(descriptions_dict)
    
    # Add metadata
    metadata = {
        "_metadata": {
            "last_updated": datetime.now().isoformat(),
            "total_tables": len(existing_descriptions) - 1,  # -1 for metadata
            "updated_tables": list(descriptions_dict.keys()),
            "generator_version": "1.0"
        }
    }
    existing_descriptions.update(metadata)
    
    # Save to file
    try:
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(existing_descriptions, f, indent=2, ensure_ascii=False)
        
        print(f"  ✅ Successfully saved descriptions to {filename}")
        print(f"  ℹ️ File contains {len(existing_descriptions) - 1} tables total")
        print(f"  ℹ️ Updated {len(descriptions_dict)} tables in this run")
        return True
        
    except Exception as e:
        print(f"  ❌ Error saving descriptions to file: {str(e)}")
        return False

# Save the generated descriptions
print(f"\n{'='*60}")
print(f"Saving Descriptions to File:")
print(f"{'='*60}")

save_success = save_descriptions_to_file(descriptions_dict)

if save_success:
    print(f"  📁 Descriptions saved successfully")
else:
    print(f"  ❌ Failed to save descriptions")
# Out:
# ============================================================
# Saving Descriptions to File:
# ============================================================
#   ✓ Loaded existing descriptions from table_descriptions.json
#   ✅ Successfully saved descriptions to table_descriptions.json
#   ℹ️ File contains 109 tables total
#   ℹ️ Updated 92 tables in this run
#   📁 Descriptions saved successfully

# %%
def update_table_column_descriptions(table_name, descriptions_dict, conn):
    """Update column descriptions for a view in the database."""
    if table_name not in descriptions_dict:
        print(f"No descriptions found for table {table_name}")
        return False
    
    descriptions = descriptions_dict[table_name]
    updated_count = 0
    
    try:
        with conn.cursor() as cursor:
            for column_name, description in descriptions.items():
                # Escape single quotes in the description
                escaped_description = description.replace("'", "''")
                
                # Update the column comment on the view
                sql = f"""
                COMMENT ON COLUMN {table_name}.{column_name} IS '{escaped_description}';
                """
                
                try:
                    cursor.execute(sql)
                    updated_count += 1
                    print(f"    ✓ Updated description for {table_name}.{column_name}")
                except Exception as e:
                    print(f"    ❌ Failed to update {table_name}.{column_name}: {str(e)}")
            
            # Commit all changes for this view
            conn.commit()
            print(f"  ✅ Successfully updated {updated_count}/{len(descriptions)} column descriptions for {table_name}")
            return True
            
    except Exception as e:
        print(f"  ❌ Error updating descriptions for {table_name}: {str(e)}")
        conn.rollback()
        return False

# %%
conn = connect(params)

total_tables = len(views)
for i, full_table_name in list(enumerate(views, 1)):
    # Use schema.table_name format for full table name
    print(f"[{i}/{total_tables}] Updating descriptions for {full_table_name}")
        
    # Get column count for progress tracking
    if full_table_name in descriptions_dict:
        column_count = len(descriptions_dict[full_table_name])
        print(f"  - Processing {column_count} columns...")
                
        # Create a modified descriptions dict with full table name
        full_descriptions_dict = {full_table_name: descriptions_dict[full_table_name]}
        update_table_column_descriptions(full_table_name, full_descriptions_dict, conn)
        
        print(f"  Progress: {i}/{total_tables} tables completed ({(i/total_tables)*100:.1f}%)")
    else:
        print(f"  - No descriptions found for {full_table_name}, skipping...")
    print()

print(f"🎉 All {total_tables} tables processed successfully!")
# Out:
# [1/92] Updating descriptions for amazon_ads_thrive.ad_group_history_view
#   - Processing 9 columns...
#     ✓ Updated description for amazon_ads_thrive.ad_group_history_view.id
#     ✓ Updated description for amazon_ads_thrive.ad_group_history_view.last_updated_date
#     ✓ Updated description for amazon_ads_thrive.ad_group_history_view.serving_status
#     ✓ Updated description for amazon_ads_thrive.ad_group_history_view.creation_date
#     ✓ Updated description for amazon_ads_thrive.ad_group_history_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.ad_group_history_view.name
#     ✓ Updated description for amazon_ads_thrive.ad_group_history_view.default_bid
#     ✓ Updated description for amazon_ads_thrive.ad_group_history_view.state
#     ✓ Updated description for amazon_ads_thrive.ad_group_history_view._fivetran_synced
#   ✅ Successfully updated 9/9 column descriptions for amazon_ads_thrive.ad_group_history_view
#   Progress: 1/92 tables completed (1.1%)
#
# [2/92] Updating descriptions for amazon_ads_thrive.ad_group_level_report_view
#   - Processing 39 columns...
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.ad_group_id
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.date
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.impressions
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.clicks
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.cost
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.cost_per_click
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.campaign_bidding_strategy
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.click_through_rate
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.spend
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.add_to_list
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.royalty_qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.purchases_1_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.purchases_7_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.purchases_14_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.purchases_30_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.purchases_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.purchases_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.purchases_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.purchases_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.units_sold_clicks_1_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.units_sold_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.units_sold_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.units_sold_clicks_30_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.sales_1_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.sales_7_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.sales_14_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.sales_30_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.attributed_sales_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.attributed_sales_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.attributed_sales_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.attributed_sales_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.units_sold_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.units_sold_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.units_sold_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.units_sold_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.kindle_edition_normalized_pages_read_14_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view.kindle_edition_normalized_pages_royalties_14_d
#     ✓ Updated description for amazon_ads_thrive.ad_group_level_report_view._fivetran_synced
#   ✅ Successfully updated 39/39 column descriptions for amazon_ads_thrive.ad_group_level_report_view
#   Progress: 2/92 tables completed (2.2%)
#
# [3/92] Updating descriptions for amazon_ads_thrive.ad_group_serving_status_detail_view
#   - Processing 5 columns...
#     ✓ Updated description for amazon_ads_thrive.ad_group_serving_status_detail_view.ad_group_id
#     ✓ Updated description for amazon_ads_thrive.ad_group_serving_status_detail_view.name
#     ✓ Updated description for amazon_ads_thrive.ad_group_serving_status_detail_view.help_url
#     ✓ Updated description for amazon_ads_thrive.ad_group_serving_status_detail_view.message
#     ✓ Updated description for amazon_ads_thrive.ad_group_serving_status_detail_view._fivetran_synced
#   ✅ Successfully updated 5/5 column descriptions for amazon_ads_thrive.ad_group_serving_status_detail_view
#   Progress: 3/92 tables completed (3.3%)
#
# [4/92] Updating descriptions for amazon_ads_thrive.ad_group_suggested_keyword_view
#   - Processing 8 columns...
#     ✓ Updated description for amazon_ads_thrive.ad_group_suggested_keyword_view._fivetran_id
#     ✓ Updated description for amazon_ads_thrive.ad_group_suggested_keyword_view.ad_group_id
#     ✓ Updated description for amazon_ads_thrive.ad_group_suggested_keyword_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.ad_group_suggested_keyword_view.keyword_text
#     ✓ Updated description for amazon_ads_thrive.ad_group_suggested_keyword_view.match_type
#     ✓ Updated description for amazon_ads_thrive.ad_group_suggested_keyword_view.state
#     ✓ Updated description for amazon_ads_thrive.ad_group_suggested_keyword_view._fivetran_deleted
#     ✓ Updated description for amazon_ads_thrive.ad_group_suggested_keyword_view._fivetran_synced
#   ✅ Successfully updated 8/8 column descriptions for amazon_ads_thrive.ad_group_suggested_keyword_view
#   Progress: 4/92 tables completed (4.3%)
#
# [5/92] Updating descriptions for amazon_ads_thrive.advertised_product_report_view
#   - Processing 51 columns...
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.ad_group_id
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.ad_id
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.date
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.impressions
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.clicks
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.cost_per_click
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.cost
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.click_through_rate
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.spend
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.campaign_budget_currency_code
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.campaign_budget_amount
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.campaign_budget_type
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.advertised_asin
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.advertised_sku
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.add_to_list
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.royalty_qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.purchases_1_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.purchases_7_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.purchases_14_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.purchases_30_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.purchases_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.purchases_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.purchases_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.purchases_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.units_sold_clicks_1_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.units_sold_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.units_sold_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.units_sold_clicks_30_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.sales_1_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.sales_7_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.sales_14_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.sales_30_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.attributed_sales_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.attributed_sales_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.attributed_sales_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.attributed_sales_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.sales_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.units_sold_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.units_sold_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.units_sold_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.units_sold_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.units_sold_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.kindle_edition_normalized_pages_read_14_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.kindle_edition_normalized_pages_royalties_14_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.acos_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.acos_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.roas_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view.roas_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.advertised_product_report_view._fivetran_synced
#   ✅ Successfully updated 51/51 column descriptions for amazon_ads_thrive.advertised_product_report_view
#   Progress: 5/92 tables completed (5.4%)
#
# [6/92] Updating descriptions for amazon_ads_thrive.asin_bid_recommendation_value_view
#   - Processing 4 columns...
#     ✓ Updated description for amazon_ads_thrive.asin_bid_recommendation_value_view.parent_id
#     ✓ Updated description for amazon_ads_thrive.asin_bid_recommendation_value_view.index
#     ✓ Updated description for amazon_ads_thrive.asin_bid_recommendation_value_view.suggested_bid
#     ✓ Updated description for amazon_ads_thrive.asin_bid_recommendation_value_view._fivetran_synced
#   ✅ Successfully updated 4/4 column descriptions for amazon_ads_thrive.asin_bid_recommendation_value_view
#   Progress: 6/92 tables completed (6.5%)
#
# [7/92] Updating descriptions for amazon_ads_thrive.asin_suggested_keyword_view
#   - Processing 6 columns...
#     ✓ Updated description for amazon_ads_thrive.asin_suggested_keyword_view._fivetran_id
#     ✓ Updated description for amazon_ads_thrive.asin_suggested_keyword_view.asin
#     ✓ Updated description for amazon_ads_thrive.asin_suggested_keyword_view.keyword_text
#     ✓ Updated description for amazon_ads_thrive.asin_suggested_keyword_view.match_type
#     ✓ Updated description for amazon_ads_thrive.asin_suggested_keyword_view._fivetran_deleted
#     ✓ Updated description for amazon_ads_thrive.asin_suggested_keyword_view._fivetran_synced
#   ✅ Successfully updated 6/6 column descriptions for amazon_ads_thrive.asin_suggested_keyword_view
#   Progress: 7/92 tables completed (7.6%)
#
# [8/92] Updating descriptions for amazon_ads_thrive.asin_theme_based_bid_recommendation_view
#   - Processing 9 columns...
#     ✓ Updated description for amazon_ads_thrive.asin_theme_based_bid_recommendation_view._fivetran_id
#     ✓ Updated description for amazon_ads_thrive.asin_theme_based_bid_recommendation_view.asin
#     ✓ Updated description for amazon_ads_thrive.asin_theme_based_bid_recommendation_view.strategy
#     ✓ Updated description for amazon_ads_thrive.asin_theme_based_bid_recommendation_view.theme
#     ✓ Updated description for amazon_ads_thrive.asin_theme_based_bid_recommendation_view.estimated_impression_upper
#     ✓ Updated description for amazon_ads_thrive.asin_theme_based_bid_recommendation_view.estimated_impression_lower
#     ✓ Updated description for amazon_ads_thrive.asin_theme_based_bid_recommendation_view.profile_id
#     ✓ Updated description for amazon_ads_thrive.asin_theme_based_bid_recommendation_view.targeting_type
#     ✓ Updated description for amazon_ads_thrive.asin_theme_based_bid_recommendation_view._fivetran_synced
#   ✅ Successfully updated 9/9 column descriptions for amazon_ads_thrive.asin_theme_based_bid_recommendation_view
#   Progress: 8/92 tables completed (8.7%)
#
# [9/92] Updating descriptions for amazon_ads_thrive.campaign_history_view
#   - Processing 16 columns...
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.id
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.last_updated_date
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.serving_status
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.creation_date
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.portfolio_id
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.profile_id
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.name
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.targeting_type
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.state
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.bidding_strategy
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.start_date
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.end_date
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.budget_type
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.budget
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view.effective_budget
#     ✓ Updated description for amazon_ads_thrive.campaign_history_view._fivetran_synced
#   ✅ Successfully updated 16/16 column descriptions for amazon_ads_thrive.campaign_history_view
#   Progress: 9/92 tables completed (9.8%)
#
# [10/92] Updating descriptions for amazon_ads_thrive.campaign_level_report_view
#   - Processing 46 columns...
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.date
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.impressions
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.clicks
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.cost
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.cost_per_click
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.campaign_bidding_strategy
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.click_through_rate
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.spend
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.add_to_list
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.royalty_qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.purchases_1_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.purchases_7_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.purchases_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.purchases_30_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.purchases_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.purchases_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.purchases_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.purchases_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.units_sold_clicks_1_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.units_sold_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.units_sold_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.units_sold_clicks_30_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.sales_1_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.sales_7_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.sales_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.sales_30_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.attributed_sales_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.attributed_sales_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.attributed_sales_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.attributed_sales_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.units_sold_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.units_sold_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.units_sold_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.units_sold_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.kindle_edition_normalized_pages_read_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.kindle_edition_normalized_pages_royalties_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.campaign_budget_amount
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.campaign_budget_type
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.campaign_rule_based_budget_amount
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.campaign_applicable_budget_rule_id
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.campaign_applicable_budget_rule_name
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.campaign_budget_currency_code
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view.top_of_search_impression_share
#     ✓ Updated description for amazon_ads_thrive.campaign_level_report_view._fivetran_synced
#   ✅ Successfully updated 46/46 column descriptions for amazon_ads_thrive.campaign_level_report_view
#   Progress: 10/92 tables completed (10.9%)
#
# [11/92] Updating descriptions for amazon_ads_thrive.campaign_negative_keyword_history_view
#   - Processing 9 columns...
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_history_view.id
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_history_view.last_updated_date
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_history_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_history_view.keyword_text
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_history_view.state
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_history_view.match_type
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_history_view.serving_status
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_history_view.creation_date
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_history_view._fivetran_synced
#   ✅ Successfully updated 9/9 column descriptions for amazon_ads_thrive.campaign_negative_keyword_history_view
#   Progress: 11/92 tables completed (12.0%)
#
# [12/92] Updating descriptions for amazon_ads_thrive.campaign_negative_keyword_serving_status_detail_view
#   - Processing 5 columns...
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_serving_status_detail_view.keyword_id
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_serving_status_detail_view.name
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_serving_status_detail_view.help_url
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_serving_status_detail_view.message
#     ✓ Updated description for amazon_ads_thrive.campaign_negative_keyword_serving_status_detail_view._fivetran_synced
#   ✅ Successfully updated 5/5 column descriptions for amazon_ads_thrive.campaign_negative_keyword_serving_status_detail_view
#   Progress: 12/92 tables completed (13.0%)
#
# [13/92] Updating descriptions for amazon_ads_thrive.campaign_placement_bidding_view
#   - Processing 4 columns...
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_bidding_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_bidding_view.placement
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_bidding_view.percentage
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_bidding_view._fivetran_synced
#   ✅ Successfully updated 4/4 column descriptions for amazon_ads_thrive.campaign_placement_bidding_view
#   Progress: 13/92 tables completed (14.1%)
#
# [14/92] Updating descriptions for amazon_ads_thrive.campaign_placement_report_view
#   - Processing 40 columns...
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.date
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.placement
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.impressions
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.clicks
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.cost
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.cost_per_click
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.campaign_bidding_strategy
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.click_through_rate
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.spend
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.add_to_list
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.royalty_qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.purchases_1_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.purchases_7_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.purchases_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.purchases_30_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.purchases_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.purchases_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.purchases_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.purchases_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.units_sold_clicks_1_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.units_sold_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.units_sold_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.units_sold_clicks_30_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.sales_1_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.sales_7_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.sales_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.sales_30_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.attributed_sales_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.attributed_sales_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.attributed_sales_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.attributed_sales_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.units_sold_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.units_sold_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.units_sold_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.units_sold_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.kindle_edition_normalized_pages_read_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view.kindle_edition_normalized_pages_royalties_14_d
#     ✓ Updated description for amazon_ads_thrive.campaign_placement_report_view._fivetran_synced
#   ✅ Successfully updated 40/40 column descriptions for amazon_ads_thrive.campaign_placement_report_view
#   Progress: 14/92 tables completed (15.2%)
#
# [15/92] Updating descriptions for amazon_ads_thrive.campaign_serving_status_detail_view
#   - Processing 5 columns...
#     ✓ Updated description for amazon_ads_thrive.campaign_serving_status_detail_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.campaign_serving_status_detail_view.name
#     ✓ Updated description for amazon_ads_thrive.campaign_serving_status_detail_view.help_url
#     ✓ Updated description for amazon_ads_thrive.campaign_serving_status_detail_view.message
#     ✓ Updated description for amazon_ads_thrive.campaign_serving_status_detail_view._fivetran_synced
#   ✅ Successfully updated 5/5 column descriptions for amazon_ads_thrive.campaign_serving_status_detail_view
#   Progress: 15/92 tables completed (16.3%)
#
# [16/92] Updating descriptions for amazon_ads_thrive.keyword_history_view
#   - Processing 13 columns...
#     ✓ Updated description for amazon_ads_thrive.keyword_history_view.id
#     ✓ Updated description for amazon_ads_thrive.keyword_history_view.last_updated_date
#     ✓ Updated description for amazon_ads_thrive.keyword_history_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.keyword_history_view.keyword_text
#     ✓ Updated description for amazon_ads_thrive.keyword_history_view.state
#     ✓ Updated description for amazon_ads_thrive.keyword_history_view.match_type
#     ✓ Updated description for amazon_ads_thrive.keyword_history_view.serving_status
#     ✓ Updated description for amazon_ads_thrive.keyword_history_view.creation_date
#     ✓ Updated description for amazon_ads_thrive.keyword_history_view.ad_group_id
#     ✓ Updated description for amazon_ads_thrive.keyword_history_view.native_language_keyword
#     ✓ Updated description for amazon_ads_thrive.keyword_history_view.native_language_locale
#     ✓ Updated description for amazon_ads_thrive.keyword_history_view.bid
#     ✓ Updated description for amazon_ads_thrive.keyword_history_view._fivetran_synced
#   ✅ Successfully updated 13/13 column descriptions for amazon_ads_thrive.keyword_history_view
#   Progress: 16/92 tables completed (17.4%)
#
# [17/92] Updating descriptions for amazon_ads_thrive.keyword_serving_status_detail_view
#   - Processing 5 columns...
#     ✓ Updated description for amazon_ads_thrive.keyword_serving_status_detail_view.keyword_id
#     ✓ Updated description for amazon_ads_thrive.keyword_serving_status_detail_view.name
#     ✓ Updated description for amazon_ads_thrive.keyword_serving_status_detail_view.help_url
#     ✓ Updated description for amazon_ads_thrive.keyword_serving_status_detail_view.message
#     ✓ Updated description for amazon_ads_thrive.keyword_serving_status_detail_view._fivetran_synced
#   ✅ Successfully updated 5/5 column descriptions for amazon_ads_thrive.keyword_serving_status_detail_view
#   Progress: 17/92 tables completed (18.5%)
#
# [18/92] Updating descriptions for amazon_ads_thrive.negative_keyword_history_view
#   - Processing 12 columns...
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_history_view.id
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_history_view.last_updated_date
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_history_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_history_view.keyword_text
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_history_view.state
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_history_view.match_type
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_history_view.serving_status
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_history_view.creation_date
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_history_view.ad_group_id
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_history_view.native_language_keyword
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_history_view.native_language_locale
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_history_view._fivetran_synced
#   ✅ Successfully updated 12/12 column descriptions for amazon_ads_thrive.negative_keyword_history_view
#   Progress: 18/92 tables completed (19.6%)
#
# [19/92] Updating descriptions for amazon_ads_thrive.negative_keyword_serving_status_detail_view
#   - Processing 5 columns...
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_serving_status_detail_view.keyword_id
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_serving_status_detail_view.name
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_serving_status_detail_view.help_url
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_serving_status_detail_view.message
#     ✓ Updated description for amazon_ads_thrive.negative_keyword_serving_status_detail_view._fivetran_synced
#   ✅ Successfully updated 5/5 column descriptions for amazon_ads_thrive.negative_keyword_serving_status_detail_view
#   Progress: 19/92 tables completed (20.7%)
#
# [20/92] Updating descriptions for amazon_ads_thrive.negative_targeting_clause_history_view
#   - Processing 9 columns...
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_clause_history_view.last_updated_date
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_clause_history_view.target_id
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_clause_history_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_clause_history_view.ad_group_id
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_clause_history_view.state
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_clause_history_view.expression_type
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_clause_history_view.serving_status
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_clause_history_view.creation_date
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_clause_history_view._fivetran_synced
#   ✅ Successfully updated 9/9 column descriptions for amazon_ads_thrive.negative_targeting_clause_history_view
#   Progress: 20/92 tables completed (21.7%)
#
# [21/92] Updating descriptions for amazon_ads_thrive.negative_targeting_expression_view
#   - Processing 6 columns...
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_expression_view._fivetran_id
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_expression_view.target_id
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_expression_view.value
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_expression_view.type
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_expression_view._fivetran_deleted
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_expression_view._fivetran_synced
#   ✅ Successfully updated 6/6 column descriptions for amazon_ads_thrive.negative_targeting_expression_view
#   Progress: 21/92 tables completed (22.8%)
#
# [22/92] Updating descriptions for amazon_ads_thrive.negative_targeting_resolved_expression_view
#   - Processing 6 columns...
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_resolved_expression_view._fivetran_id
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_resolved_expression_view.target_id
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_resolved_expression_view.value
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_resolved_expression_view.type
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_resolved_expression_view._fivetran_deleted
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_resolved_expression_view._fivetran_synced
#   ✅ Successfully updated 6/6 column descriptions for amazon_ads_thrive.negative_targeting_resolved_expression_view
#   Progress: 22/92 tables completed (23.9%)
#
# [23/92] Updating descriptions for amazon_ads_thrive.negative_targeting_serving_status_detail_view
#   - Processing 5 columns...
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_serving_status_detail_view.target_id
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_serving_status_detail_view.name
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_serving_status_detail_view.help_url
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_serving_status_detail_view.message
#     ✓ Updated description for amazon_ads_thrive.negative_targeting_serving_status_detail_view._fivetran_synced
#   ✅ Successfully updated 5/5 column descriptions for amazon_ads_thrive.negative_targeting_serving_status_detail_view
#   Progress: 23/92 tables completed (25.0%)
#
# [24/92] Updating descriptions for amazon_ads_thrive.portfolio_history_view
#   - Processing 14 columns...
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view.id
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view.last_updated_date
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view.profile_id
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view.name
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view.in_budget
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view.state
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view.serving_status
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view.creation_date
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view.budget_amount
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view.budget_currency_code
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view.budget_policy
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view.budget_start_date
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view.budget_end_date
#     ✓ Updated description for amazon_ads_thrive.portfolio_history_view._fivetran_synced
#   ✅ Successfully updated 14/14 column descriptions for amazon_ads_thrive.portfolio_history_view
#   Progress: 24/92 tables completed (26.1%)
#
# [25/92] Updating descriptions for amazon_ads_thrive.product_ad_history_view
#   - Processing 11 columns...
#     ✓ Updated description for amazon_ads_thrive.product_ad_history_view.id
#     ✓ Updated description for amazon_ads_thrive.product_ad_history_view.last_updated_date
#     ✓ Updated description for amazon_ads_thrive.product_ad_history_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.product_ad_history_view.ad_group_id
#     ✓ Updated description for amazon_ads_thrive.product_ad_history_view.custom_text
#     ✓ Updated description for amazon_ads_thrive.product_ad_history_view.sku
#     ✓ Updated description for amazon_ads_thrive.product_ad_history_view.asin
#     ✓ Updated description for amazon_ads_thrive.product_ad_history_view.state
#     ✓ Updated description for amazon_ads_thrive.product_ad_history_view.serving_status
#     ✓ Updated description for amazon_ads_thrive.product_ad_history_view.creation_date
#     ✓ Updated description for amazon_ads_thrive.product_ad_history_view._fivetran_synced
#   ✅ Successfully updated 11/11 column descriptions for amazon_ads_thrive.product_ad_history_view
#   Progress: 25/92 tables completed (27.2%)
#
# [26/92] Updating descriptions for amazon_ads_thrive.product_ad_serving_status_detail_view
#   - Processing 5 columns...
#     ✓ Updated description for amazon_ads_thrive.product_ad_serving_status_detail_view.product_ad_id
#     ✓ Updated description for amazon_ads_thrive.product_ad_serving_status_detail_view.name
#     ✓ Updated description for amazon_ads_thrive.product_ad_serving_status_detail_view.help_url
#     ✓ Updated description for amazon_ads_thrive.product_ad_serving_status_detail_view.message
#     ✓ Updated description for amazon_ads_thrive.product_ad_serving_status_detail_view._fivetran_synced
#   ✅ Successfully updated 5/5 column descriptions for amazon_ads_thrive.product_ad_serving_status_detail_view
#   Progress: 26/92 tables completed (28.3%)
#
# [27/92] Updating descriptions for amazon_ads_thrive.profile_view
#   - Processing 13 columns...
#     ✓ Updated description for amazon_ads_thrive.profile_view.id
#     ✓ Updated description for amazon_ads_thrive.profile_view.country_code
#     ✓ Updated description for amazon_ads_thrive.profile_view.currency_code
#     ✓ Updated description for amazon_ads_thrive.profile_view.daily_budget
#     ✓ Updated description for amazon_ads_thrive.profile_view.timezone
#     ✓ Updated description for amazon_ads_thrive.profile_view.account_marketplace_string_id
#     ✓ Updated description for amazon_ads_thrive.profile_view.account_id
#     ✓ Updated description for amazon_ads_thrive.profile_view.account_type
#     ✓ Updated description for amazon_ads_thrive.profile_view.account_name
#     ✓ Updated description for amazon_ads_thrive.profile_view.account_sub_type
#     ✓ Updated description for amazon_ads_thrive.profile_view.account_valid_payment_method
#     ✓ Updated description for amazon_ads_thrive.profile_view._fivetran_deleted
#     ✓ Updated description for amazon_ads_thrive.profile_view._fivetran_synced
#   ✅ Successfully updated 13/13 column descriptions for amazon_ads_thrive.profile_view
#   Progress: 27/92 tables completed (29.3%)
#
# [28/92] Updating descriptions for amazon_ads_thrive.purchased_product_keyword_report_view
#   - Processing 39 columns...
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.ad_group_id
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.date
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.keyword_id
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.purchased_asin
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.match_type
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.campaign_budget_currency_code
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.advertised_asin
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.advertised_sku
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.add_to_list
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.royalty_qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.purchases_other_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.purchases_other_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.purchases_other_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.purchases_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.sales_other_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.sales_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.sales_other_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.sales_other_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.units_sold_other_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.units_sold_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.units_sold_other_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.units_sold_other_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.purchases_1_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.purchases_7_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.purchases_14_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.purchases_30_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.units_sold_clicks_1_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.units_sold_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.units_sold_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.units_sold_clicks_30_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.sales_1_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.sales_7_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.sales_14_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.sales_30_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.kindle_edition_normalized_pages_read_14_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view.kindle_edition_normalized_pages_royalties_14_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_keyword_report_view._fivetran_synced
#   ✅ Successfully updated 39/39 column descriptions for amazon_ads_thrive.purchased_product_keyword_report_view
#   Progress: 28/92 tables completed (30.4%)
#
# [29/92] Updating descriptions for amazon_ads_thrive.purchased_product_targeting_report_view
#   - Processing 39 columns...
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.ad_group_id
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.date
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.keyword_id
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.purchased_asin
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.match_type
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.campaign_budget_currency_code
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.advertised_asin
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.advertised_sku
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.add_to_list
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.royalty_qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.purchases_other_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.purchases_other_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.purchases_other_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.purchases_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.sales_other_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.sales_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.sales_other_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.sales_other_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.units_sold_other_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.units_sold_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.units_sold_other_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.purchased_product_targeting_report_view.units_sold_other_sku_30_d
# ...
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.attributed_sales_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.attributed_sales_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.attributed_sales_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.sales_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.units_sold_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.units_sold_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.units_sold_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.units_sold_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.units_sold_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.kindle_edition_normalized_pages_read_14_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.kindle_edition_normalized_pages_royalties_14_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.acos_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.acos_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.roas_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view.roas_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.search_term_targeting_report_view._fivetran_synced
#   ✅ Successfully updated 52/52 column descriptions for amazon_ads_thrive.search_term_targeting_report_view
#   Progress: 86/92 tables completed (93.5%)
#
# [87/92] Updating descriptions for amazon_ads_thrive.targeting_clause_history_view
#   - Processing 10 columns...
#     ✓ Updated description for amazon_ads_thrive.targeting_clause_history_view.last_updated_date
#     ✓ Updated description for amazon_ads_thrive.targeting_clause_history_view.target_id
#     ✓ Updated description for amazon_ads_thrive.targeting_clause_history_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.targeting_clause_history_view.ad_group_id
#     ✓ Updated description for amazon_ads_thrive.targeting_clause_history_view.state
#     ✓ Updated description for amazon_ads_thrive.targeting_clause_history_view.expression_type
#     ✓ Updated description for amazon_ads_thrive.targeting_clause_history_view.serving_status
#     ✓ Updated description for amazon_ads_thrive.targeting_clause_history_view.creation_date
#     ✓ Updated description for amazon_ads_thrive.targeting_clause_history_view.bid
#     ✓ Updated description for amazon_ads_thrive.targeting_clause_history_view._fivetran_synced
#   ✅ Successfully updated 10/10 column descriptions for amazon_ads_thrive.targeting_clause_history_view
#   Progress: 87/92 tables completed (94.6%)
#
# [88/92] Updating descriptions for amazon_ads_thrive.targeting_expression_view
#   - Processing 6 columns...
#     ✓ Updated description for amazon_ads_thrive.targeting_expression_view._fivetran_id
#     ✓ Updated description for amazon_ads_thrive.targeting_expression_view.target_id
#     ✓ Updated description for amazon_ads_thrive.targeting_expression_view.value
#     ✓ Updated description for amazon_ads_thrive.targeting_expression_view.type
#     ✓ Updated description for amazon_ads_thrive.targeting_expression_view._fivetran_deleted
#     ✓ Updated description for amazon_ads_thrive.targeting_expression_view._fivetran_synced
#   ✅ Successfully updated 6/6 column descriptions for amazon_ads_thrive.targeting_expression_view
#   Progress: 88/92 tables completed (95.7%)
#
# [89/92] Updating descriptions for amazon_ads_thrive.targeting_keyword_report_view
#   - Processing 54 columns...
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.ad_group_id
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.date
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.keyword_id
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.ad_keyword_status
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.targeting
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.match_type
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.keyword_type
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.keyword_bid
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.impressions
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.clicks
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.cost_per_click
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.cost
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.click_through_rate
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.campaign_budget_currency_code
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.campaign_budget_amount
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.campaign_budget_type
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.top_of_search_impression_share
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.add_to_list
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.royalty_qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.purchases_1_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.purchases_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.purchases_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.purchases_30_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.purchases_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.purchases_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.purchases_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.purchases_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.units_sold_clicks_1_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.units_sold_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.units_sold_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.units_sold_clicks_30_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.sales_1_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.sales_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.sales_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.sales_30_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.attributed_sales_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.attributed_sales_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.attributed_sales_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.attributed_sales_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.sales_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.units_sold_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.units_sold_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.units_sold_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.units_sold_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.units_sold_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.kindle_edition_normalized_pages_read_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.kindle_edition_normalized_pages_royalties_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.acos_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.acos_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.roas_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view.roas_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_keyword_report_view._fivetran_synced
#   ✅ Successfully updated 54/54 column descriptions for amazon_ads_thrive.targeting_keyword_report_view
#   Progress: 89/92 tables completed (96.7%)
#
# [90/92] Updating descriptions for amazon_ads_thrive.targeting_report_view
#   - Processing 54 columns...
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.ad_group_id
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.campaign_id
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.date
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.keyword_id
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.ad_keyword_status
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.targeting
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.match_type
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.keyword_type
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.keyword_bid
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.impressions
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.clicks
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.cost_per_click
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.cost
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.click_through_rate
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.campaign_budget_currency_code
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.campaign_budget_amount
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.campaign_budget_type
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.top_of_search_impression_share
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.add_to_list
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.royalty_qualified_borrows
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.purchases_1_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.purchases_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.purchases_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.purchases_30_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.purchases_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.purchases_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.purchases_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.purchases_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.units_sold_clicks_1_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.units_sold_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.units_sold_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.units_sold_clicks_30_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.sales_1_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.sales_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.sales_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.sales_30_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.attributed_sales_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.attributed_sales_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.attributed_sales_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.attributed_sales_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.sales_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.units_sold_same_sku_1_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.units_sold_same_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.units_sold_same_sku_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.units_sold_same_sku_30_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.units_sold_other_sku_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.kindle_edition_normalized_pages_read_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.kindle_edition_normalized_pages_royalties_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.acos_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.acos_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.roas_clicks_7_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view.roas_clicks_14_d
#     ✓ Updated description for amazon_ads_thrive.targeting_report_view._fivetran_synced
#   ✅ Successfully updated 54/54 column descriptions for amazon_ads_thrive.targeting_report_view
#   Progress: 90/92 tables completed (97.8%)
#
# [91/92] Updating descriptions for amazon_ads_thrive.targeting_resolved_expression_view
#   - Processing 6 columns...
#     ✓ Updated description for amazon_ads_thrive.targeting_resolved_expression_view._fivetran_id
#     ✓ Updated description for amazon_ads_thrive.targeting_resolved_expression_view.target_id
#     ✓ Updated description for amazon_ads_thrive.targeting_resolved_expression_view.value
#     ✓ Updated description for amazon_ads_thrive.targeting_resolved_expression_view.type
#     ✓ Updated description for amazon_ads_thrive.targeting_resolved_expression_view._fivetran_deleted
#     ✓ Updated description for amazon_ads_thrive.targeting_resolved_expression_view._fivetran_synced
#   ✅ Successfully updated 6/6 column descriptions for amazon_ads_thrive.targeting_resolved_expression_view
#   Progress: 91/92 tables completed (98.9%)
#
# [92/92] Updating descriptions for amazon_ads_thrive.targeting_serving_status_detail_view
#   - Processing 5 columns...
#     ✓ Updated description for amazon_ads_thrive.targeting_serving_status_detail_view.target_id
#     ✓ Updated description for amazon_ads_thrive.targeting_serving_status_detail_view.name
#     ✓ Updated description for amazon_ads_thrive.targeting_serving_status_detail_view.help_url
#     ✓ Updated description for amazon_ads_thrive.targeting_serving_status_detail_view.message
#     ✓ Updated description for amazon_ads_thrive.targeting_serving_status_detail_view._fivetran_synced
#   ✅ Successfully updated 5/5 column descriptions for amazon_ads_thrive.targeting_serving_status_detail_view
#   Progress: 92/92 tables completed (100.0%)
#
# 🎉 All 92 tables processed successfully!

# %%
# Check current user privileges
try:
    with conn.cursor() as cursor:
        cursor.execute("""
            SELECT rolname, rolsuper
            FROM pg_roles
            WHERE rolname = current_user;
        """)
        result = cursor.fetchone()
        if result:
            username, is_superuser = result
            print(f"Current user: {username}")
            print(f"Is superuser: {is_superuser}")
        else:
            print("Could not retrieve current user information")
except Exception as e:
    print(f"Error checking user privileges: {str(e)}")
# Out:
# Current user: postgres
# Is superuser: False

# %%
def get_view_schema_info(conn, schema_name, view_name):
    """
    Get formatted schema information for a specific view including comments.
    
    Args:
        conn: Database connection object
        schema_name: Name of the schema
        view_name: Name of the view
        
    Returns:
        str: Formatted schema information including view definition and column details
    """
    try:
        cursor = conn.cursor()
        
        # Check if view exists
        cursor.execute("""
            SELECT table_name
            FROM information_schema.views
            WHERE table_schema = %s AND table_name = %s;
        """, (schema_name, view_name))
        
        if not cursor.fetchone():
            return f"View '{view_name}' not found in schema '{schema_name}'"
        
        output = []
        output.append(f"View: {schema_name}.{view_name}")
        output.append("=" * 50)
        
        # Get view definition and comment
        cursor.execute("""
            SELECT 
                obj_description(c.oid, 'pg_class') as comment,
                pg_get_viewdef(c.oid, true) as definition
            FROM pg_class c
            JOIN pg_namespace n ON n.oid = c.relnamespace
            WHERE c.relname = %s 
            AND n.nspname = %s 
            AND c.relkind = 'v';
        """, (view_name, schema_name))
        
        view_info = cursor.fetchone()
        if view_info:
            comment, definition = view_info
            if comment:
                output.append(f"Comment: {comment}")
            else:
                output.append("Comment: No comment available")
            
            output.append("\nDefinition:")
            # Truncate very long definitions for readability
            if len(definition) > 1000:
                output.append(definition[:1000] + "...")
            else:
                output.append(definition)
        
        # Get column information with comments
        cursor.execute("""
            SELECT 
                column_name,
                data_type,
                character_maximum_length,
                is_nullable,
                column_default,
                col_description(pgc.oid, a.attnum) as column_comment
            FROM information_schema.columns c
            LEFT JOIN pg_class pgc ON pgc.relname = c.table_name
            LEFT JOIN pg_namespace n ON n.oid = pgc.relnamespace AND n.nspname = c.table_schema
            LEFT JOIN pg_attribute a ON a.attrelid = pgc.oid AND a.attname = c.column_name
            WHERE c.table_name = %s 
            AND c.table_schema = %s
            ORDER BY c.ordinal_position;
        """, (view_name, schema_name))
        
        columns = cursor.fetchall()
        if columns:
            output.append("\nColumns:")
            for col in columns:
                col_name, data_type, max_length, nullable, default, col_comment = col
                
                # Format data type with length if applicable
                type_str = data_type
                if max_length and data_type in ['character varying', 'varchar', 'char']:
                    type_str += f"({max_length})"
                
                output.append(f"  - {col_name} ({type_str})")
                
                if col_comment:
                    output.append(f"    Comment: {col_comment}")
                if default:
                    output.append(f"    Default: {default}")
                if nullable == 'NO':
                    output.append(f"    NOT NULL")
        
        return "\n".join(output)
        
    except Exception as e:
        return f"Error retrieving schema information for view '{view_name}': {str(e)}"

# Example usage:
# Print schema info for a specific view
view_schema_info = get_view_schema_info(conn, "amazon_ads_thrive", "ad_group_history_view")
print(view_schema_info)
# Out:
# View: amazon_ads_thrive.ad_group_history_view
# ==================================================
# Comment: No comment available
#
# Definition:
#  SELECT ad_group_history.id,
#     ad_group_history.last_updated_date,
#     ad_group_history.serving_status,
#     ad_group_history.creation_date,
#     ad_group_history.campaign_id,
#     ad_group_history.name,
#     ad_group_history.default_bid,
#     ad_group_history.state,
#     ad_group_history._fivetran_synced
#    FROM amazon_ads_thrive.ad_group_history;
#
# Columns:
#   - id (character varying(256))
#     Comment: Amazon Advertising ad group identifier (numeric-looking string). Unique per ad group in this table; treat as text when joining. Use as the key to join to ad-group-level metrics or targeting tables and to filter specific ad groups. Example values: '101180574487644', '10228173083157', '102237366048889'.
#   - last_updated_date (timestamp with time zone)
#     Comment: UTC timestamp when this ad group’s settings or status were last updated in Amazon Ads. Useful for incremental loads, change tracking, and filtering by recency. Example values: '2017-01-27 16:16:25+00:00', '2019-04-02 19:58:22+00:00', '2022-11-10 14:17:15.863+00:00'.
#   - serving_status (character varying(256))
#     Comment: Reason-coded serving eligibility from Amazon Ads indicating whether/why the ad group can serve (e.g., campaign paused/archived, portfolio ended/out of budget, or ad group enabled). Useful for filtering to deliverable ad groups and grouping by cause. Example values: 'CAMPAIGN_PAUSED', 'AD_GROUP_STATUS_ENABLED', 'PORTFOLIO_OUT_OF_BUDGET'.
#   - creation_date (timestamp with time zone)
#     Comment: UTC timestamp when the ad group was created. Use to build cohorts by creation month/week or to filter to newly created ad groups. Example values: '2016-01-12 04:26:53+00:00', '2019-01-26 06:47:29+00:00', '2019-11-21 10:25:17+00:00'.
#   - campaign_id (character varying(256))
#     Comment: Amazon Advertising campaign identifier that this ad group belongs to (numeric-looking string). Use to join to campaign-level tables/attributes and to roll up results by campaign. Example values: '249828922192343', '207424676495630', '25490233158169'.
#   - name (character varying(256))
#     Comment: Ad group name defined by the advertiser; not guaranteed to be unique. Useful for human-readable filters, naming convention searches, and grouping; avoid using as a key. Example values: 'AdGroup1', 'Face Wash', 'VIP'.
#   - default_bid (double precision)
#     Comment: Default cost-per-click (CPC) bid set at the ad-group level, in the advertising account’s currency. Numeric; typical values range from about 0.02 to 4.01. Useful for filtering or bucketing ad groups by bid. Example values: 1.0, 0.6, 1.5.
#   - state (character varying(256))
#     Comment: Advertiser-set ad group state: 'ENABLED' (active), 'PAUSED' (not serving by choice), or 'ARCHIVED' (closed). Combine with serving_status to determine actual deliverability. Useful for filtering and grouping. Example values: 'ENABLED', 'PAUSED', 'ARCHIVED'.
#   - _fivetran_synced (timestamp with time zone)
#     Comment: UTC timestamp when this row was last synced by Fivetran (ETL). Indicates data freshness and supports incremental extraction; not a business event time. Example values: '2025-09-01 08:18:26.845+00:00', '2025-09-01 08:16:24.755+00:00'.

# %%
# Run the query from file_context_0 to get column information
cursor = conn.cursor()
cursor.execute("""
    SELECT 
        column_name,
        data_type,
        character_maximum_length,
        is_nullable,
        column_default,
        col_description(pgc.oid, a.attnum) as column_comment
    FROM information_schema.columns c
    LEFT JOIN pg_class pgc ON pgc.relname = c.table_name
    LEFT JOIN pg_namespace n ON n.oid = pgc.relnamespace AND n.nspname = c.table_schema
    LEFT JOIN pg_attribute a ON a.attrelid = pgc.oid AND a.attname = c.column_name
    WHERE c.table_name = 'search_terms_report_daily_view' 
    AND c.table_schema = 'sp_api_thrive_2'
    ORDER BY c.ordinal_position;
""")

results = cursor.fetchall()
for row in results:
    column_name, data_type, max_length, nullable, default, column_comment = row
    print(f"Column: {column_name}, Type: {data_type}, Comment: {column_comment}")
# Out:
# Column: clicked_asin, Type: character varying, Comment: Amazon Standard Identification Number (ASIN) of the product that received clicks for this search term on the given date and marketplace. Exactly 10 characters. Join key to product/ASIN dimensions; filter to a specific product; use with click_share_rank to find the top clicked item per term. Examples: 'B0007QCQGI', 'B0CFGYFCYL', 'B09MQWWP87'.
# Column: department_name, Type: character varying, Comment: Amazon retail site (domain/locale) the data belongs to; pairs with marketplace_id. Useful for filtering or grouping by country/site. Examples: 'Amazon.com' (United States), 'Amazon.com.br' (Brazil).
# Column: end_date, Type: date, Comment: End date (UTC) of the reporting period for this row. For daily data it equals start_date. Use to filter date ranges or join to a date/calendar dimension. Examples: '2025-08-06', '2025-08-08', '2025-08-12'.
# Column: marketplace_id, Type: character varying, Comment: Amazon Marketplace identifier for the country/locale where the search occurred. Use for filtering by market or joining to a marketplace dimension. Examples: 'ATVPDKIKX0DER' (US), 'A2Q3Y263D00KWC' (BR).
# Column: search_frequency_rank, Type: integer, Comment: Popularity rank of the search term within the marketplace and date; 1 is the most-searched term (lower is more popular). Useful for filtering top terms (e.g., <= 1000) or sorting by demand. Examples: 1, 62888, 382094.
# Column: search_term, Type: character varying, Comment: Customer search query text entered on Amazon (multi-language). Use for filtering (ILIKE/regex), grouping, and text analysis. Examples: 'marvel legends', 'tv samsung 65', 'teclado gamer'.
# Column: start_date, Type: date, Comment: Start date (UTC) of the reporting period; for this daily table it equals end_date. Use in date filters, windowing, or joins to a date/calendar table. Examples: '2025-08-06', '2025-08-10', '2025-08-12'.
# Column: click_share_rank, Type: integer, Comment: Rank position (1–3) of this ASIN among the top three clicked products for the search term on that date/marketplace; 1 is the most-clicked. Filter rank = 1 to get the top clicked ASIN per term. Examples: 1, 2, 3.
# Column: click_share, Type: double precision, Comment: Share of clicks the ASIN received among the top three clicked products for the search term in the period; decimal fraction between 0 and 1 (multiply by 100 for percent). Useful for sorting/comparing product interest. Examples: 0.1053, 0.1667, 1.0.
# Column: conversion_share, Type: double precision, Comment: Share of conversions (orders) the ASIN captured among the top three clicked products for the search term; decimal 0–1. Can be null when conversion data is unavailable. Use to find the best-converting ASIN per term or to sort by conversion performance. Examples: 0.0345, 0.1429, 0.0.
# Column: _fivetran_synced, Type: timestamp with time zone, Comment: UTC timestamp when this row was last synced by Fivetran (extract–transform–load). Useful for data freshness/auditing, not for business metrics. Examples: '2025-08-13 23:16:26+00', '2025-08-13 22:36:12+00'.
